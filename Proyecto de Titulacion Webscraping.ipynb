# %%
#!pip install requests

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# # Data de Chevrolet

# %% [markdown]
# ### Chevrolette Ventas

# %%
# Hago la sopa
URL = "https://www.seminuevos.com/usados/-/autos/-/chevrolet/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)

chevrolet_soup1 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los modelos
gm_md1 = chevrolet_soup1.find_all('h4', class_ = 'bold size-h6 left')
gm_modelos1 = list()

for i in gm_md1:
    gm_modelos1.append(i.text.strip())
    
#print(gm_modelos1)

# Scrapeamos la información de venta
gm_inf1 = chevrolet_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
gm_info1 = list()

for i in gm_inf1:
    gm_info1.append(i.text.strip())
    
#print(gm_info1)

# Scrap de precio
chevrolet_soup1 = BeautifulSoup(page.content, "lxml")

gm_pr1 = chevrolet_soup1.find_all('span', {'class' : 'left share-value'})

gm_precio1= list()
for i in gm_pr1:
    gm_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/chevrolet/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
chevrolet_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
gm_md2 = chevrolet_soup2.find_all('h4', class_ = 'bold size-h6 left')
gm_modelos2 = list()
for i in gm_md2:
    gm_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
gm_inf2 = chevrolet_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
gm_info2= list()

for i in gm_inf2:
    gm_info2.append(i.text.strip())
    
# Scrap de precio
chevrolet_soup2 = BeautifulSoup(page.content, "lxml")

gm_pr2 = chevrolet_soup2.find_all('span', {'class' : 'left share-value'})

gm_precio2= list()
for i in gm_pr2:
    gm_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/chevrolet/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mg=="
page = requests.get(URL)
chevrolet_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
gm_md3 = chevrolet_soup3.find_all('h4', class_ = 'bold size-h6 left')
gm_modelos3 = list()
for i in gm_md3:
    gm_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
gm_inf3 = chevrolet_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
gm_info3= list()

for i in gm_inf3:
    gm_info3.append(i.text.strip())
    
# Scrap de precio
chevrolet_soup3 = BeautifulSoup(page.content, "lxml")

gm_pr3 = chevrolet_soup3.find_all('span', {'class' : 'left share-value'})

gm_precio3= list()
for i in gm_pr3:
    gm_precio3.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/chevrolet/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mw=="
page = requests.get(URL)
chevrolet_soup4 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
gm_md4 = chevrolet_soup4.find_all('h4', class_ = 'bold size-h6 left')
gm_modelos4 = list()
for i in gm_md4:
    gm_modelos4.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
gm_inf4 = chevrolet_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
gm_info4= list()

for i in gm_inf4:
    gm_info4.append(i.text.strip())
    
# Scrap de precio
chevrolet_soup4 = BeautifulSoup(page.content, "lxml")

gm_pr4 = chevrolet_soup4.find_all('span', {'class' : 'left share-value'})

gm_precio4= list()
for i in gm_pr4:
    gm_precio4.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/chevrolet/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=NA=="
page = requests.get(URL)
chevrolet_soup5 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
gm_md5 = chevrolet_soup5.find_all('h4', class_ = 'bold size-h6 left')
gm_modelos5 = list()
for i in gm_md5:
    gm_modelos5.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
gm_inf5 = chevrolet_soup5.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
gm_info5= list()

for i in gm_inf5:
    gm_info5.append(i.text.strip())
    
# Scrap de precio
chevrolet_soup5 = BeautifulSoup(page.content, "lxml")

gm_pr5 = chevrolet_soup5.find_all('span', {'class' : 'left share-value'})

gm_precio5= list()
for i in gm_pr5:
    gm_precio5.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/chevrolet/-/2021?type_autos_moderated=moderated&page=NQ==&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
chevrolet_soup6 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
gm_md6 = chevrolet_soup6.find_all('h4', class_ = 'bold size-h6 left')
gm_modelos6 = list()
for i in gm_md6:
    gm_modelos6.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
gm_inf6 = chevrolet_soup6.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
gm_info6= list()

for i in gm_inf6:
    gm_info6.append(i.text.strip())
    
# Scrap de precio
chevrolet_soup6 = BeautifulSoup(page.content, "lxml")

gm_pr6 = chevrolet_soup6.find_all('span', {'class' : 'left share-value'})

gm_precio6= list()
for i in gm_pr6:
    gm_precio6.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/chevrolet/-/2021?type_autos_moderated=moderated&page=Ng==&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
chevrolet_soup7 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
gm_md7 = chevrolet_soup7.find_all('h4', class_ = 'bold size-h6 left')
gm_modelos7 = list()
for i in gm_md7:
    gm_modelos7.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
gm_inf7 = chevrolet_soup7.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
gm_info7= list()

for i in gm_inf7:
    gm_info7.append(i.text.strip())
    
# Scrap de precio
chevrolet_soup7 = BeautifulSoup(page.content, "lxml")

gm_pr7 = chevrolet_soup7.find_all('span', {'class' : 'left share-value'})

gm_precio7= list()
for i in gm_pr7:
    gm_precio7.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/chevrolet/-/2021?type_autos_moderated=moderated&page=Nw==&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
chevrolet_soup8 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
gm_md8 = chevrolet_soup8.find_all('h4', class_ = 'bold size-h6 left')
gm_modelos8 = list()
for i in gm_md8:
    gm_modelos8.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
gm_inf8 = chevrolet_soup8.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
gm_info8= list()

for i in gm_inf8:
    gm_info8.append(i.text.strip())
    
# Scrap de precio
chevrolet_soup8 = BeautifulSoup(page.content, "lxml")

gm_pr8 = chevrolet_soup8.find_all('span', {'class' : 'left share-value'})

gm_precio8= list()
for i in gm_pr8:
    gm_precio8.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/chevrolet/-/2021?type_autos_moderated=moderated&page=OA==&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
chevrolet_soup9 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
gm_md9 = chevrolet_soup9.find_all('h4', class_ = 'bold size-h6 left')
gm_modelos9 = list()
for i in gm_md9:
    gm_modelos9.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
gm_inf9 = chevrolet_soup9.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
gm_info9= list()

for i in gm_inf9:
    gm_info9.append(i.text.strip())
    
# Scrap de precio
chevrolet_soup9 = BeautifulSoup(page.content, "lxml")

gm_pr9 = chevrolet_soup9.find_all('span', {'class' : 'left share-value'})

gm_precio9= list()
for i in gm_pr9:
    gm_precio9.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/chevrolet/-/2021?type_autos_moderated=moderated&page=OQ==&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
chevrolet_soup10 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
gm_md10 = chevrolet_soup10.find_all('h4', class_ = 'bold size-h6 left')
gm_modelos10 = list()
for i in gm_md10:
    gm_modelos10.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
gm_inf10 = chevrolet_soup10.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
gm_info10= list()

for i in gm_inf10:
    gm_info10.append(i.text.strip())
    
# Scrap de precio
chevrolet_soup10 = BeautifulSoup(page.content, "lxml")

gm_pr10 = chevrolet_soup10.find_all('span', {'class' : 'left share-value'})

gm_precio10= list()
for i in gm_pr10:
    gm_precio10.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/chevrolet/-/2021?type_autos_moderated=moderated&page=MTA=&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
chevrolet_soup11 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
gm_md11 = chevrolet_soup11.find_all('h4', class_ = 'bold size-h6 left')
gm_modelos11 = list()
for i in gm_md11:
    gm_modelos11.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
gm_inf11 = chevrolet_soup11.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
gm_info11= list()

for i in gm_inf11:
    gm_info11.append(i.text.strip())
    
# Scrap de precio
chevrolet_soup11 = BeautifulSoup(page.content, "lxml")

gm_pr11 = chevrolet_soup11.find_all('span', {'class' : 'left share-value'})

gm_precio11= list()
for i in gm_pr11:
    gm_precio11.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/chevrolet/-/2021?type_autos_moderated=moderated&page=MTE=&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
chevrolet_soup12 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
gm_md12 = chevrolet_soup12.find_all('h4', class_ = 'bold size-h6 left')
gm_modelos12 = list()
for i in gm_md12:
    gm_modelos12.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
gm_inf12 = chevrolet_soup12.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
gm_info12= list()

for i in gm_inf12:
    gm_info12.append(i.text.strip())
    
# Scrap de precio
chevrolet_soup12 = BeautifulSoup(page.content, "lxml")

gm_pr12 = chevrolet_soup12.find_all('span', {'class' : 'left share-value'})

gm_precio12= list()
for i in gm_pr12:
    gm_precio12.append(i.text.strip())

# %% [markdown]
# ### Hago el DataFrame usando la inforación de las 5 paginas

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(gm_modelos1, gm_info1, gm_precio1))
list_tuples2= list(zip(gm_modelos2, gm_info2, gm_precio2))
list_tuples3= list(zip(gm_modelos3, gm_info3, gm_precio3))
list_tuples4= list(zip(gm_modelos4, gm_info4, gm_precio4))
list_tuples5= list(zip(gm_modelos5, gm_info5, gm_precio5))

# Agrego las tuplas y nombro las columnas
chevrolette_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
chevrolette_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
chevrolette_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
chevrolette_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])
chevrolette_df5 = pd.DataFrame(list_tuples5, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
chevrolette_df = chevrolette_df1.append([chevrolette_df2, chevrolette_df3, chevrolette_df4, chevrolette_df5], ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples6= list(zip(gm_modelos6, gm_info6, gm_precio6))
list_tuples7= list(zip(gm_modelos7, gm_info7, gm_precio7))
list_tuples8= list(zip(gm_modelos8, gm_info8, gm_precio8))
list_tuples9= list(zip(gm_modelos9, gm_info9, gm_precio9))
list_tuples10= list(zip(gm_modelos10, gm_info10, gm_precio10))
list_tuples11= list(zip(gm_modelos11, gm_info11, gm_precio11))
list_tuples12= list(zip(gm_modelos12, gm_info12, gm_precio12))

# Agrego las tuplas y nombro las columnas
chevrolette_df6 = pd.DataFrame(list_tuples6, columns= ['Modelos', 'Información', 'Precio'])
chevrolette_df7 = pd.DataFrame(list_tuples7, columns= ['Modelos', 'Información', 'Precio'])
chevrolette_df8 = pd.DataFrame(list_tuples8, columns= ['Modelos', 'Información', 'Precio'])
chevrolette_df9 = pd.DataFrame(list_tuples9, columns= ['Modelos', 'Información', 'Precio'])
chevrolette_df10 = pd.DataFrame(list_tuples10, columns= ['Modelos', 'Información', 'Precio'])
chevrolette_df11 = pd.DataFrame(list_tuples11, columns= ['Modelos', 'Información', 'Precio'])
chevrolette_df12 = pd.DataFrame(list_tuples12, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
chevrolette_df22 = chevrolette_df6.append([chevrolette_df, chevrolette_df7, chevrolette_df8, chevrolette_df9, chevrolette_df10, chevrolette_df11, chevrolette_df12], ignore_index = True)

# %% [markdown]
# ### Download the DataFrame to a CSV file

# %%
chevrolette_df22.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\Webscrapping\Chevrolet4 Ventas.csv', index = False, header=True)

# %% [markdown]
# # Data de Ford

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/ford/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
ford_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
frd_md1 = ford_soup1.find_all('h4', class_ = 'bold size-h6 left')
frd_modelos1 = list()
for i in frd_md1:
    frd_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
frd_inf1 = ford_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
frd_info1= list()

for i in frd_inf1:
    frd_info1.append(i.text.strip())
    
# Scrap de precio
ford_soup1= BeautifulSoup(page.content, "lxml")

frd_pr1= ford_soup1.find_all('span', {'class' : 'left share-value'})

frd_precio1= list()
for i in frd_pr1:
    frd_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/ford/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
ford_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
frd_md2 = ford_soup2.find_all('h4', class_ = 'bold size-h6 left')
frd_modelos2 = list()
for i in frd_md2:
    frd_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
frd_inf2 = ford_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
frd_info2= list()

for i in frd_inf2:
    frd_info2.append(i.text.strip())
    
# Scrap de precio
ford_soup2 = BeautifulSoup(page.content, "lxml")

frd_pr2 = ford_soup2.find_all('span', {'class' : 'left share-value'})

frd_precio2= list()
for i in frd_pr2:
    frd_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/ford/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mg=="
page = requests.get(URL)
ford_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
frd_md3 = ford_soup3.find_all('h4', class_ = 'bold size-h6 left')
frd_modelos3 = list()
for i in frd_md3:
    frd_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
frd_inf3 = ford_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
frd_info3= list()

for i in frd_inf3:
    frd_info3.append(i.text.strip())
    
# Scrap de precio
ford_soup3 = BeautifulSoup(page.content, "lxml")

frd_pr3 = ford_soup3.find_all('span', {'class' : 'left share-value'})

frd_precio3= list()
for i in frd_pr3:
    frd_precio3.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/ford/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mw=="
page = requests.get(URL)
ford_soup4 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
frd_md4 = ford_soup4.find_all('h4', class_ = 'bold size-h6 left')
frd_modelos4 = list()
for i in frd_md4:
    frd_modelos4.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
frd_inf4 = ford_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
frd_info4= list()

for i in frd_inf4:
    frd_info4.append(i.text.strip())
    
# Scrap de precio
ford_soup4 = BeautifulSoup(page.content, "lxml")

frd_pr4 = ford_soup4.find_all('span', {'class' : 'left share-value'})

frd_precio4= list()
for i in frd_pr4:
    frd_precio4.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/ford/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=NA=="
page = requests.get(URL)
ford_soup5 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
frd_md5 = ford_soup5.find_all('h4', class_ = 'bold size-h6 left')
frd_modelos5 = list()
for i in frd_md5:
    frd_modelos5.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
frd_inf5 = ford_soup5.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
frd_info5= list()

for i in frd_inf5:
    frd_info5.append(i.text.strip())
    
# Scrap de precio
ford_soup5 = BeautifulSoup(page.content, "lxml")

frd_pr5 = ford_soup5.find_all('span', {'class' : 'left share-value'})

frd_precio5= list()
for i in frd_pr5:
    frd_precio5.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/ford/-/2021?type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_moderated=moderated&page=NQ=="
page = requests.get(URL)
ford_soup6 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
frd_md6 = ford_soup6.find_all('h4', class_ = 'bold size-h6 left')
frd_modelos6 = list()
for i in frd_md6:
    frd_modelos6.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
frd_inf6 = ford_soup6.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
frd_info6= list()

for i in frd_inf6:
    frd_info6.append(i.text.strip())
    
# Scrap de precio
ford_soup6 = BeautifulSoup(page.content, "lxml")

frd_pr6 = ford_soup6.find_all('span', {'class' : 'left share-value'})

frd_precio6= list()
for i in frd_pr6:
    frd_precio6.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/ford/-/2021?type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_moderated=moderated&page=Ng=="
page = requests.get(URL)
ford_soup7 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
frd_md7 = ford_soup7.find_all('h4', class_ = 'bold size-h6 left')
frd_modelos7 = list()
for i in frd_md7:
    frd_modelos7.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
frd_inf7 = ford_soup7.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
frd_info7= list()

for i in frd_inf7:
    frd_info7.append(i.text.strip())
    
# Scrap de precio
ford_soup7 = BeautifulSoup(page.content, "lxml")

frd_pr7 = ford_soup7.find_all('span', {'class' : 'left share-value'})

frd_precio7= list()
for i in frd_pr7:
    frd_precio7.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/ford/-/2021?type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_moderated=moderated&page=Nw=="
page = requests.get(URL)
ford_soup8 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
frd_md8 = ford_soup8.find_all('h4', class_ = 'bold size-h6 left')
frd_modelos8 = list()
for i in frd_md8:
    frd_modelos8.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
frd_inf8 = ford_soup8.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
frd_info8= list()

for i in frd_inf8:
    frd_info8.append(i.text.strip())
    
# Scrap de precio
ford_soup8 = BeautifulSoup(page.content, "lxml")

frd_pr8 = ford_soup8.find_all('span', {'class' : 'left share-value'})

frd_precio8= list()
for i in frd_pr8:
    frd_precio8.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/ford/-/2021?type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_moderated=moderated&page=OA=="
page = requests.get(URL)
ford_soup9 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
frd_md9 = ford_soup9.find_all('h4', class_ = 'bold size-h6 left')
frd_modelos9 = list()
for i in frd_md9:
    frd_modelos9.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
frd_inf9 = ford_soup9.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
frd_info9= list()

for i in frd_inf9:
    frd_info9.append(i.text.strip())
    
# Scrap de precio
ford_soup9 = BeautifulSoup(page.content, "lxml")

frd_pr9 = ford_soup9.find_all('span', {'class' : 'left share-value'})

frd_precio9= list()
for i in frd_pr9:
    frd_precio9.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/ford/-/2021?type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_moderated=moderated&page=OQ=="
page = requests.get(URL)
ford_soup10 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
frd_md10 = ford_soup10.find_all('h4', class_ = 'bold size-h6 left')
frd_modelos10 = list()
for i in frd_md10:
    frd_modelos10.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
frd_inf10 = ford_soup10.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
frd_info10= list()

for i in frd_inf10:
    frd_info10.append(i.text.strip())
    
# Scrap de precio
ford_soup10 = BeautifulSoup(page.content, "lxml")

frd_pr10 = ford_soup10.find_all('span', {'class' : 'left share-value'})

frd_precio10= list()
for i in frd_pr10:
    frd_precio10.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/ford/-/2021?type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_moderated=moderated&page=MTA="
page = requests.get(URL)
ford_soup11 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
frd_md11 = ford_soup11.find_all('h4', class_ = 'bold size-h6 left')
frd_modelos11 = list()
for i in frd_md11:
    frd_modelos11.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
frd_inf11 = ford_soup11.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
frd_info11= list()

for i in frd_inf11:
    frd_info11.append(i.text.strip())
    
# Scrap de precio
ford_soup11 = BeautifulSoup(page.content, "lxml")

frd_pr11 = ford_soup11.find_all('span', {'class' : 'left share-value'})

frd_precio11= list()
for i in frd_pr11:
    frd_precio11.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/ford/-/2021?type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_moderated=moderated&page=MTE="
page = requests.get(URL)
ford_soup12 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
frd_md12 = ford_soup12.find_all('h4', class_ = 'bold size-h6 left')
frd_modelos12 = list()
for i in frd_md12:
    frd_modelos12.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
frd_inf12 = ford_soup12.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
frd_info12= list()

for i in frd_inf12:
    frd_info12.append(i.text.strip())
    
# Scrap de precio
ford_soup12 = BeautifulSoup(page.content, "lxml")

frd_pr12 = ford_soup12.find_all('span', {'class' : 'left share-value'})

frd_precio12= list()
for i in frd_pr12:
    frd_precio12.append(i.text.strip())

# %% [markdown]
# ### Hago el DataFrame usando la inforación de las 5 paginas

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(frd_modelos1, frd_info1, frd_precio1))
list_tuples2= list(zip(frd_modelos2, frd_info2, frd_precio2))
list_tuples3= list(zip(frd_modelos3, frd_info3, frd_precio3))
list_tuples4= list(zip(frd_modelos4, frd_info4, frd_precio4))
list_tuples5= list(zip(frd_modelos5, frd_info5, frd_precio5))

# Agrego las tuplas y nombro las columnas
ford_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
ford_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
ford_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
ford_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])
ford_df5 = pd.DataFrame(list_tuples5, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
ford_df = ford_df1.append([ford_df2, ford_df3, ford_df4, ford_df5], ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples6= list(zip(frd_modelos6, frd_info6, frd_precio6))
list_tuples7= list(zip(frd_modelos7, frd_info7, frd_precio7))
list_tuples8= list(zip(frd_modelos8, frd_info8, frd_precio8))
list_tuples9= list(zip(frd_modelos9, frd_info9, frd_precio9))
list_tuples10= list(zip(frd_modelos10, frd_info10, frd_precio10))
list_tuples11= list(zip(frd_modelos11, frd_info11, frd_precio11))
list_tuples12= list(zip(frd_modelos12, frd_info12, frd_precio12))

# Agrego las tuplas y nombro las columnas
ford_df6 = pd.DataFrame(list_tuples6, columns= ['Modelos', 'Información', 'Precio'])
ford_df7 = pd.DataFrame(list_tuples7, columns= ['Modelos', 'Información', 'Precio'])
ford_df8 = pd.DataFrame(list_tuples8, columns= ['Modelos', 'Información', 'Precio'])
ford_df9 = pd.DataFrame(list_tuples9, columns= ['Modelos', 'Información', 'Precio'])
ford_df10 = pd.DataFrame(list_tuples10, columns= ['Modelos', 'Información', 'Precio'])
ford_df11 = pd.DataFrame(list_tuples11, columns= ['Modelos', 'Información', 'Precio'])
ford_df12 = pd.DataFrame(list_tuples12, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
ford_df2 = ford_df6.append([ford_df, ford_df7, ford_df8, ford_df9, ford_df10, ford_df11, ford_df12], ignore_index = True)

# %% [markdown]
# ### Download the DataFrame to a CSV file

# %%
ford_df2.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Ford3 Ventas.csv', index = False, header=False)

# %%
ford_df2.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Ford2 Ventas.csv', index = False, header=True)

# %% [markdown]
# # Data de Acura

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/acura/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
acura_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
acr_md1 = acura_soup1.find_all('h4', class_ = 'bold size-h6 left')
acr_modelos1 = list()
for i in acr_md1:
    acr_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
acr_inf1 = acura_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
acr_info1= list()

for i in acr_inf1:
    acr_info1.append(i.text.strip())
    
# Scrap de precio
acura_soup1 = BeautifulSoup(page.content, "lxml")

acr_pr1 = acura_soup1.find_all('span', {'class' : 'left share-value'})

acr_precio1= list()
for i in acr_pr1:
    acr_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/acura/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
acura_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
acr_md2 = acura_soup2.find_all('h4', class_ = 'bold size-h6 left')
acr_modelos2 = list()
for i in acr_md2:
    acr_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
acr_inf2 = acura_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
acr_info2= list()

for i in acr_inf2:
    acr_info2.append(i.text.strip())
    
# Scrap de precio
acura_soup2 = BeautifulSoup(page.content, "lxml")

acr_pr2 = acura_soup2.find_all('span', {'class' : 'left share-value'})

acr_precio2= list()
for i in acr_pr2:
    acr_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/acura/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
acura_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
acr_md3 = acura_soup3.find_all('h4', class_ = 'bold size-h6 left')
acr_modelos3 = list()
for i in acr_md3:
    acr_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
acr_inf3 = acura_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
acr_info3= list()

for i in acr_inf3:
    acr_info3.append(i.text.strip())
    
# Scrap de precio
acura_soup3 = BeautifulSoup(page.content, "lxml")

acr_pr3 = acura_soup3.find_all('span', {'class' : 'left share-value'})

acr_precio3= list()
for i in acr_pr3:
    acr_precio3.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/acura/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MQ=="
page = requests.get(URL)
acura_soup4 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
acr_md4 = acura_soup4.find_all('h4', class_ = 'bold size-h6 left')
acr_modelos4 = list()
for i in acr_md4:
    acr_modelos4.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
acr_inf4 = acura_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
acr_info4= list()

for i in acr_inf4:
    acr_info4.append(i.text.strip())
    
# Scrap de precio
acura_soup4 = BeautifulSoup(page.content, "lxml")

acr_pr4 = acura_soup4.find_all('span', {'class' : 'left share-value'})

acr_precio4= list()
for i in acr_pr4:
    acr_precio4.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/acura/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Mg=="
page = requests.get(URL)
acura_soup5 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
acr_md5 = acura_soup5.find_all('h4', class_ = 'bold size-h6 left')
acr_modelos5 = list()
for i in acr_md5:
    acr_modelos5.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
acr_inf5 = acura_soup5.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
acr_info5= list()

for i in acr_inf5:
    acr_info5.append(i.text.strip())
    
# Scrap de precio
acura_soup5 = BeautifulSoup(page.content, "lxml")

acr_pr5 = acura_soup5.find_all('span', {'class' : 'left share-value'})

acr_precio5= list()
for i in acr_pr5:
    acr_precio5.append(i.text.strip())

# %% [markdown]
# ### Convierto a DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(acr_modelos1, acr_info1, acr_precio1))
list_tuples2= list(zip(acr_modelos2, acr_info2, acr_precio2))

# Agrego las tuplas y nombro las columnas
acura_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
acura_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
acura_df = acura_df1.append(acura_df2, ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples3= list(zip(acr_modelos3, acr_info3, acr_precio3))
list_tuples4= list(zip(acr_modelos4, acr_info4, acr_precio4))
list_tuples5= list(zip(acr_modelos5, acr_info5, acr_precio5))

# Agrego las tuplas y nombro las columnas
acura_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
acura_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])
acura_df5 = pd.DataFrame(list_tuples5, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
acura_df6 = acura_df3.append([acura_df, acura_df4, acura_df5], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
acura_df6.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Acura3 Ventas.csv', index = False, header=False)

# %%
acura_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Acura2 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Data de Alfa Romero

# %%
#Bajo la información 
URL = "https://www.seminuevos.com/usados/-/autos/-/acura/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
alfarom_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
alfr_md1 = alfarom_soup1.find_all('h4', class_ = 'bold size-h6 left')
alfr_modelos1 = list()
for i in alfr_md1:
    alfr_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
alfr_inf1 = alfarom_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
alfr_info1= list()

for i in alfr_inf1:
    alfr_info1.append(i.text.strip())
    
# Scrap de precio
alfarom_soup1 = BeautifulSoup(page.content, "lxml")

alfr_pr1 = alfarom_soup1.find_all('span', {'class' : 'left share-value'})

alfr_precio1= list()
for i in alfr_pr1:
    alfr_precio1.append(i.text.strip())

# %%
#Bajo la información 
URL = "https://www.seminuevos.com/usados/-/autos/-/alfa+romeo/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
alfarom_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
alfr_md2 = alfarom_soup2.find_all('h4', class_ = 'bold size-h6 left')
alfr_modelos2 = list()
for i in alfr_md2:
    alfr_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
alfr_inf2 = alfarom_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
alfr_info2= list()

for i in alfr_inf2:
    alfr_info2.append(i.text.strip())
    
# Scrap de precio
alfarom_soup2 = BeautifulSoup(page.content, "lxml")

alfr_pr2 = alfarom_soup2.find_all('span', {'class' : 'left share-value'})

alfr_precio2= list()
for i in alfr_pr2:
    alfr_precio2.append(i.text.strip())

# %% [markdown]
# ### Data Frame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(alfr_modelos1, alfr_info1, alfr_precio1))

# Agrego las tuplas y nombro las columnas
alfarom_df = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples2= list(zip(alfr_modelos2, alfr_info2, alfr_precio2))

# Agrego las tuplas y nombro las columnas
alfarom_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])

# Agrego DF
alfarom_df3 = alfarom_df.append([alfarom_df2], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
alfarom_df3.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Alfa Romero3 Ventas.csv', index = False, header=False)

# %%
alfarom_df2.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Alfa Romero2 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Datos de Audi

# %%
# Hago la sopa
URL = "https://www.seminuevos.com/usados/-/autos/-/audi/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)

audi_soup1 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los modelos
ad_md1 = audi_soup1.find_all('h4', class_ = 'bold size-h6 left')
ad_modelos1 = list()

for i in ad_md1:
    ad_modelos1.append(i.text.strip())

# Scrapeamos la información de venta
ad_inf1 = audi_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ad_info1 = list()

for i in ad_inf1:
    ad_info1.append(i.text.strip())

# Scrap de precio
audi_soup1 = BeautifulSoup(page.content, "lxml")

ad_pr1 = audi_soup1.find_all('span', {'class' : 'left share-value'})

ad_precio1= list()
for i in ad_pr1:
    ad_precio1.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://www.seminuevos.com/usados/-/autos/-/audi/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)

audi_soup2 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los modelos
ad_md2 = audi_soup2.find_all('h4', class_ = 'bold size-h6 left')
ad_modelos2 = list()

for i in ad_md2:
    ad_modelos2.append(i.text.strip())

# Scrapeamos la información de venta
ad_inf2 = audi_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ad_info2 = list()

for i in ad_inf2:
    ad_info2.append(i.text.strip())

# Scrap de precio
audi_soup2 = BeautifulSoup(page.content, "lxml")

ad_pr2 = audi_soup2.find_all('span', {'class' : 'left share-value'})

ad_precio2= list()
for i in ad_pr2:
    ad_precio2.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://www.seminuevos.com/usados/-/autos/-/audi/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mg=="
page = requests.get(URL)

audi_soup3 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los modelos
ad_md3 = audi_soup3.find_all('h4', class_ = 'bold size-h6 left')
ad_modelos3 = list()

for i in ad_md3:
    ad_modelos3.append(i.text.strip())

# Scrapeamos la información de venta
ad_inf3 = audi_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ad_info3 = list()

for i in ad_inf3:
    ad_info3.append(i.text.strip())

# Scrap de precio
audi_soup3 = BeautifulSoup(page.content, "lxml")

ad_pr3 = audi_soup3.find_all('span', {'class' : 'left share-value'})

ad_precio3 = list()
for i in ad_pr3:
    ad_precio3.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://www.seminuevos.com/usados/-/autos/-/audi/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mw=="
page = requests.get(URL)

audi_soup4 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los modelos
ad_md4 = audi_soup4.find_all('h4', class_ = 'bold size-h6 left')
ad_modelos4 = list()

for i in ad_md4:
    ad_modelos4.append(i.text.strip())

# Scrapeamos la información de venta
ad_inf4 = audi_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ad_info4 = list()

for i in ad_inf4:
    ad_info4.append(i.text.strip())

# Scrap de precio
audi_soup4 = BeautifulSoup(page.content, "lxml")

ad_pr4 = audi_soup4.find_all('span', {'class' : 'left share-value'})

ad_precio4= list()
for i in ad_pr4:
    ad_precio4.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://www.seminuevos.com/usados/-/autos/-/audi/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mw=="
page = requests.get(URL)

audi_soup5 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los modelos
ad_md5 = audi_soup5.find_all('h4', class_ = 'bold size-h6 left')
ad_modelos5 = list()

for i in ad_md5:
    ad_modelos5.append(i.text.strip())

# Scrapeamos la información de venta
ad_inf5 = audi_soup5.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ad_info5 = list()

for i in ad_inf5:
    ad_info5.append(i.text.strip())

# Scrap de precio
audi_soup5 = BeautifulSoup(page.content, "lxml")

ad_pr5 = audi_soup5.find_all('span', {'class' : 'left share-value'})

ad_precio5= list()
for i in ad_pr5:
    ad_precio5.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://www.seminuevos.com/usados/-/autos/-/audi/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=NQ=="
page = requests.get(URL)

audi_soup6 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los modelos
ad_md6 = audi_soup6.find_all('h4', class_ = 'bold size-h6 left')
ad_modelos6 = list()

for i in ad_md6:
    ad_modelos6.append(i.text.strip())

# Scrapeamos la información de venta
ad_inf6 = audi_soup6.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ad_info6 = list()

for i in ad_inf6:
    ad_info6.append(i.text.strip())

# Scrap de precio
audi_soup6 = BeautifulSoup(page.content, "lxml")

ad_pr6 = audi_soup6.find_all('span', {'class' : 'left share-value'})

ad_precio6= list()
for i in ad_pr6:
    ad_precio6.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://www.seminuevos.com/usados/-/autos/-/audi/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Ng=="
page = requests.get(URL)

audi_soup7 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los modelos
ad_md7 = audi_soup7.find_all('h4', class_ = 'bold size-h6 left')
ad_modelos7 = list()

for i in ad_md7:
    ad_modelos7.append(i.text.strip())

# Scrapeamos la información de venta
ad_inf7 = audi_soup7.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ad_info7 = list()

for i in ad_inf7:
    ad_info7.append(i.text.strip())

# Scrap de precio
audi_soup7 = BeautifulSoup(page.content, "lxml")

ad_pr7 = audi_soup7.find_all('span', {'class' : 'left share-value'})

ad_precio7= list()
for i in ad_pr7:
    ad_precio7.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://www.seminuevos.com/usados/-/autos/-/audi/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Nw=="
page = requests.get(URL)

audi_soup8 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los modelos
ad_md8 = audi_soup8.find_all('h4', class_ = 'bold size-h6 left')
ad_modelos8 = list()

for i in ad_md8:
    ad_modelos8.append(i.text.strip())

# Scrapeamos la información de venta
ad_inf8 = audi_soup8.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ad_info8 = list()

for i in ad_inf8:
    ad_info8.append(i.text.strip())

# Scrap de precio
audi_soup8 = BeautifulSoup(page.content, "lxml")

ad_pr8 = audi_soup8.find_all('span', {'class' : 'left share-value'})

ad_precio8= list()
for i in ad_pr8:
    ad_precio8.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://www.seminuevos.com/usados/-/autos/-/audi/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=OA=="
page = requests.get(URL)

audi_soup9 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los modelos
ad_md9 = audi_soup9.find_all('h4', class_ = 'bold size-h6 left')
ad_modelos9 = list()

for i in ad_md9:
    ad_modelos9.append(i.text.strip())

# Scrapeamos la información de venta
ad_inf9 = audi_soup9.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ad_info9 = list()

for i in ad_inf9:
    ad_info9.append(i.text.strip())

# Scrap de precio
audi_soup9 = BeautifulSoup(page.content, "lxml")

ad_pr9 = audi_soup9.find_all('span', {'class' : 'left share-value'})

ad_precio9= list()
for i in ad_pr9:
    ad_precio9.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://www.seminuevos.com/usados/-/autos/-/audi/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=OQ=="
page = requests.get(URL)

audi_soup10 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los modelos
ad_md10 = audi_soup10.find_all('h4', class_ = 'bold size-h6 left')
ad_modelos10 = list()

for i in ad_md10:
    ad_modelos10.append(i.text.strip())

# Scrapeamos la información de venta
ad_inf10 = audi_soup10.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ad_info10 = list()

for i in ad_inf10:
    ad_info10.append(i.text.strip())

# Scrap de precio
audi_soup10 = BeautifulSoup(page.content, "lxml")

ad_pr10 = audi_soup10.find_all('span', {'class' : 'left share-value'})

ad_precio10= list()
for i in ad_pr10:
    ad_precio10.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://www.seminuevos.com/usados/-/autos/-/audi/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MTA="
page = requests.get(URL)

audi_soup11 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los modelos
ad_md11 = audi_soup11.find_all('h4', class_ = 'bold size-h6 left')
ad_modelos11 = list()

for i in ad_md11:
    ad_modelos11.append(i.text.strip())

# Scrapeamos la información de venta
ad_inf11 = audi_soup11.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ad_info11 = list()

for i in ad_inf11:
    ad_info11.append(i.text.strip())

# Scrap de precio
audi_soup11 = BeautifulSoup(page.content, "lxml")

ad_pr11 = audi_soup11.find_all('span', {'class' : 'left share-value'})

ad_precio11= list()
for i in ad_pr11:
    ad_precio11.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://www.seminuevos.com/usados/-/autos/-/audi/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MTE="
page = requests.get(URL)

audi_soup12 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los modelos
ad_md12 = audi_soup12.find_all('h4', class_ = 'bold size-h6 left')
ad_modelos12 = list()

for i in ad_md12:
    ad_modelos12.append(i.text.strip())

# Scrapeamos la información de venta
ad_inf12 = audi_soup12.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ad_info12 = list()

for i in ad_inf12:
    ad_info12.append(i.text.strip())

# Scrap de precio
audi_soup12 = BeautifulSoup(page.content, "lxml")

ad_pr12 = audi_soup12.find_all('span', {'class' : 'left share-value'})

ad_precio12= list()
for i in ad_pr12:
    ad_precio12.append(i.text.strip())

# %% [markdown]
# ### DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(ad_modelos1, ad_info1, ad_precio1))
list_tuples2= list(zip(ad_modelos2, ad_info2, ad_precio2))
list_tuples3= list(zip(ad_modelos3, ad_info3, ad_precio3))
list_tuples4= list(zip(ad_modelos4, ad_info4, ad_precio4))
list_tuples5= list(zip(ad_modelos5, ad_info5, ad_precio5))

# Agrego las tuplas y nombro las columnas
ad_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
ad_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
ad_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
ad_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])
ad_df5 = pd.DataFrame(list_tuples5, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
audi_df = ad_df1.append([ad_df2, ad_df3, ad_df4, ad_df5], ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples6= list(zip(ad_modelos6, ad_info6, ad_precio6))
list_tuples7= list(zip(ad_modelos7, ad_info7, ad_precio7))
list_tuples8= list(zip(ad_modelos8, ad_info8, ad_precio8))
list_tuples9= list(zip(ad_modelos9, ad_info9, ad_precio9))
list_tuples10= list(zip(ad_modelos10, ad_info10, ad_precio10))
list_tuples11= list(zip(ad_modelos11, ad_info11, ad_precio11))
list_tuples12= list(zip(ad_modelos12, ad_info12, ad_precio12))

# Agrego las tuplas y nombro las columnas
ad_df6 = pd.DataFrame(list_tuples6, columns= ['Modelos', 'Información', 'Precio'])
ad_df7 = pd.DataFrame(list_tuples7, columns= ['Modelos', 'Información', 'Precio'])
ad_df8 = pd.DataFrame(list_tuples8, columns= ['Modelos', 'Información', 'Precio'])
ad_df9 = pd.DataFrame(list_tuples9, columns= ['Modelos', 'Información', 'Precio'])
ad_df10 = pd.DataFrame(list_tuples10, columns= ['Modelos', 'Información', 'Precio'])
ad_df11 = pd.DataFrame(list_tuples11, columns= ['Modelos', 'Información', 'Precio'])
ad_df12 = pd.DataFrame(list_tuples12, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
ad_df13 = ad_df6.append([ad_df7, ad_df8, ad_df9, ad_df10, ad_df11, ad_df12], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
ad_df13.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Audi3 Ventas.csv', index = False, header=False)

# %%
ad_df2.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Audi2 Ventas.csv', index = False, header=False)

# %% [markdown]
# ### Bentley

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/bentley/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
bentley_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
btly_md1 = bentley_soup1.find_all('h4', class_ = 'bold size-h6 left')
btly_modelos1 = list()

for i in btly_md1:
    btly_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
btly_inf1 = bentley_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
btly_info1= list()

for i in btly_inf1:
    btly_info1.append(i.text.strip())
    
# Scrap de precio
bentley_soup1 = BeautifulSoup(page.content, "lxml")

btly_pr1 = bentley_soup1.find_all('span', {'class' : 'left share-value'})

btly_precio1= list()
for i in btly_pr1:
    btly_precio1.append(i.text.strip())

# %% [markdown]
# ### Hago el DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(btly_modelos1, btly_info1, btly_precio1))

# Agrego las tuplas y nombro las columnas
bentley_df = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])

# %% [markdown]
# ### Convierto a CSV

# %%
bentley_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Bentley3 Ventas.csv', index = False, header=False)

# %% [markdown]
# ### BMW

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/bmw/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
bmw_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
bw_md1 = bmw_soup1.find_all('h4', class_ = 'bold size-h6 left')
bw_modelos1 = list()

for i in bw_md1:
    bw_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
bw_inf1 = bmw_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
bw_info1= list()

for i in bw_inf1:
    bw_info1.append(i.text.strip())
    
# Scrap de precio
bmw_soup1 = BeautifulSoup(page.content, "lxml")

bw_pr1 = bmw_soup1.find_all('span', {'class' : 'left share-value'})

bw_precio1= list()
for i in bw_pr1:
    bw_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/bmw/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
bmw_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
bw_md2 = bmw_soup2.find_all('h4', class_ = 'bold size-h6 left')
bw_modelos2 = list()

for i in bw_md2:
    bw_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
bw_inf2 = bmw_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
bw_info2 = list()

for i in bw_inf2:
    bw_info2.append(i.text.strip())
    
# Scrap de precio
bmw_soup2 = BeautifulSoup(page.content, "lxml")

bw_pr2 = bmw_soup2.find_all('span', {'class' : 'left share-value'})

bw_precio2= list()
for i in bw_pr2:
    bw_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/bmw/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
bmw_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
bw_md3 = bmw_soup3.find_all('h4', class_ = 'bold size-h6 left')
bw_modelos3 = list()

for i in bw_md3:
    bw_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
bw_inf3 = bmw_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
bw_info3 = list()

for i in bw_inf3:
    bw_info3.append(i.text.strip())
    
# Scrap de precio
bmw_soup3 = BeautifulSoup(page.content, "lxml")

bw_pr3 = bmw_soup3.find_all('span', {'class' : 'left share-value'})

bw_precio3= list()
for i in bw_pr3:
    bw_precio3.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/bmw/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
bmw_soup4 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
bw_md4 = bmw_soup4.find_all('h4', class_ = 'bold size-h6 left')
bw_modelos4 = list()

for i in bw_md4:
    bw_modelos4.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
bw_inf4 = bmw_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
bw_info4 = list()

for i in bw_inf4:
    bw_info4.append(i.text.strip())
    
# Scrap de precio
bmw_soup4 = BeautifulSoup(page.content, "lxml")

bw_pr4 = bmw_soup4.find_all('span', {'class' : 'left share-value'})

bw_precio4 = list()
for i in bw_pr4:
    bw_precio4.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/bmw/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
bmw_soup5 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
bw_md5 = bmw_soup5.find_all('h4', class_ = 'bold size-h6 left')
bw_modelos5 = list()

for i in bw_md5:
    bw_modelos5.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
bw_inf5 = bmw_soup5.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
bw_info5 = list()

for i in bw_inf5:
    bw_info5.append(i.text.strip())
    
# Scrap de precio
bmw_soup5 = BeautifulSoup(page.content, "lxml")

bw_pr5 = bmw_soup5.find_all('span', {'class' : 'left share-value'})

bw_precio5 = list()
for i in bw_pr5:
    bw_precio5.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/bmw/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=NQ=="
page = requests.get(URL)
bmw_soup6 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
bw_md6 = bmw_soup6.find_all('h4', class_ = 'bold size-h6 left')
bw_modelos6 = list()

for i in bw_md6:
    bw_modelos6.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
bw_inf6 = bmw_soup6.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
bw_info6 = list()

for i in bw_inf6:
    bw_info6.append(i.text.strip())
    
# Scrap de precio
bmw_soup6 = BeautifulSoup(page.content, "lxml")

bw_pr6 = bmw_soup6.find_all('span', {'class' : 'left share-value'})

bw_precio6 = list()
for i in bw_pr6:
    bw_precio6.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/bmw/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Ng=="
page = requests.get(URL)
bmw_soup7 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
bw_md7 = bmw_soup7.find_all('h4', class_ = 'bold size-h6 left')
bw_modelos7 = list()

for i in bw_md7:
    bw_modelos7.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
bw_inf7 = bmw_soup7.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
bw_info7 = list()

for i in bw_inf7:
    bw_info7.append(i.text.strip())
    
# Scrap de precio
bmw_soup7 = BeautifulSoup(page.content, "lxml")

bw_pr7 = bmw_soup7.find_all('span', {'class' : 'left share-value'})

bw_precio7 = list()
for i in bw_pr7:
    bw_precio7.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/bmw/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Nw=="
page = requests.get(URL)
bmw_soup8 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
bw_md8 = bmw_soup8.find_all('h4', class_ = 'bold size-h6 left')
bw_modelos8 = list()

for i in bw_md8:
    bw_modelos8.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
bw_inf8 = bmw_soup8.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
bw_info8 = list()

for i in bw_inf8:
    bw_info8.append(i.text.strip())
    
# Scrap de precio
bmw_soup8 = BeautifulSoup(page.content, "lxml")

bw_pr8 = bmw_soup8.find_all('span', {'class' : 'left share-value'})

bw_precio8 = list()
for i in bw_pr8:
    bw_precio8.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/bmw/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=OA=="
page = requests.get(URL)
bmw_soup9 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
bw_md9 = bmw_soup9.find_all('h4', class_ = 'bold size-h6 left')
bw_modelos9 = list()

for i in bw_md9:
    bw_modelos9.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
bw_inf9 = bmw_soup9.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
bw_info9 = list()

for i in bw_inf9:
    bw_info9.append(i.text.strip())
    
# Scrap de precio
bmw_soup9 = BeautifulSoup(page.content, "lxml")

bw_pr9 = bmw_soup9.find_all('span', {'class' : 'left share-value'})

bw_precio9 = list()
for i in bw_pr9:
    bw_precio9.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/bmw/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=OQ=="
page = requests.get(URL)
bmw_soup10 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
bw_md10 = bmw_soup10.find_all('h4', class_ = 'bold size-h6 left')
bw_modelos10 = list()

for i in bw_md10:
    bw_modelos10.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
bw_inf10 = bmw_soup10.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
bw_info10 = list()

for i in bw_inf10:
    bw_info10.append(i.text.strip())
    
# Scrap de precio
bmw_soup10 = BeautifulSoup(page.content, "lxml")

bw_pr10 = bmw_soup10.find_all('span', {'class' : 'left share-value'})

bw_precio10 = list()
for i in bw_pr10:
    bw_precio10.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/bmw/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MTA="
page = requests.get(URL)
bmw_soup11 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
bw_md11 = bmw_soup11.find_all('h4', class_ = 'bold size-h6 left')
bw_modelos11 = list()

for i in bw_md11:
    bw_modelos11.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
bw_inf11 = bmw_soup11.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
bw_info11 = list()

for i in bw_inf11:
    bw_info11.append(i.text.strip())
    
# Scrap de precio
bmw_soup11 = BeautifulSoup(page.content, "lxml")

bw_pr11 = bmw_soup11.find_all('span', {'class' : 'left share-value'})

bw_precio11 = list()
for i in bw_pr11:
    bw_precio11.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/bmw/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MTE="
page = requests.get(URL)
bmw_soup12 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
bw_md12 = bmw_soup12.find_all('h4', class_ = 'bold size-h6 left')
bw_modelos12 = list()

for i in bw_md12:
    bw_modelos12.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
bw_inf12 = bmw_soup12.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
bw_info12 = list()

for i in bw_info12:
    bw_info12append(i.text.strip())
    
# Scrap de precio
bmw_soup12 = BeautifulSoup(page.content, "lxml")

bw_pr12 = bmw_soup11.find_all('span', {'class' : 'left share-value'})

bw_precio12 = list()
for i in bw_pr12:
    bw_precio12.append(i.text.strip())

# %% [markdown]
# ### Hago el DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(bw_modelos1, bw_info1, bw_precio1))
list_tuples2= list(zip(bw_modelos2, bw_info2, bw_precio2))
list_tuples3= list(zip(bw_modelos3, bw_info3, bw_precio3))
list_tuples4= list(zip(bw_modelos4, bw_info4, bw_precio4))
list_tuples5= list(zip(bw_modelos5, bw_info5, bw_precio5))

# Agrego las tuplas y nombro las columnas
bw_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
bw_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
bw_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
bw_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])
bw_df5 = pd.DataFrame(list_tuples5, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
bw_df = bw_df1.append([bw_df2, bw_df3, bw_df4, bw_df5], ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples6= list(zip(bw_modelos6, bw_info6, bw_precio6))
list_tuples7= list(zip(bw_modelos7, bw_info7, bw_precio7))
list_tuples8= list(zip(bw_modelos8, bw_info8, bw_precio8))
list_tuples9= list(zip(bw_modelos9, bw_info9, bw_precio9))
list_tuples10= list(zip(bw_modelos10, bw_info10, bw_precio10))
list_tuples11= list(zip(bw_modelos11, bw_info11, bw_precio11))
list_tuples12= list(zip(bw_modelos12, bw_info12, bw_precio12))

# Agrego las tuplas y nombro las columnas
bw_df6 = pd.DataFrame(list_tuples6, columns= ['Modelos', 'Información', 'Precio'])
bw_df7 = pd.DataFrame(list_tuples7, columns= ['Modelos', 'Información', 'Precio'])
bw_df8 = pd.DataFrame(list_tuples8, columns= ['Modelos', 'Información', 'Precio'])
bw_df9 = pd.DataFrame(list_tuples9, columns= ['Modelos', 'Información', 'Precio'])
bw_df10 = pd.DataFrame(list_tuples10, columns= ['Modelos', 'Información', 'Precio'])
bw_df11 = pd.DataFrame(list_tuples11, columns= ['Modelos', 'Información', 'Precio'])
bw_df12 = pd.DataFrame(list_tuples12, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
bw_df2 = bw_df6.append([bw_df, bw_df7, bw_df8, bw_df9, bw_df10, bw_df11, bw_df12], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
bw_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\BMW Ventas.csv', index = False, header=False)

# %%
bw_df2.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\BMW3 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Chrysler

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/chrysler/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
chrysler_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
crlr_md1 = chrysler_soup1.find_all('h4', class_ = 'bold size-h6 left')
crlr_modelos1 = list()

for i in crlr_md1:
    crlr_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
crlr_inf1 = chrysler_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
crlr_info1= list()

for i in crlr_inf1:
    crlr_info1.append(i.text.strip())
    
# Scrap de precio
chrysler_soup1 = BeautifulSoup(page.content, "lxml")

crlr_pr1 = chrysler_soup1.find_all('span', {'class' : 'left share-value'})

crlr_precio1= list()
for i in crlr_pr1:
    crlr_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/chrysler/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
chrysler_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
crlr_md2 = chrysler_soup2.find_all('h4', class_ = 'bold size-h6 left')
crlr_modelos2 = list()

for i in crlr_md2:
    crlr_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
crlr_inf2 = chrysler_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
crlr_info2= list()

for i in crlr_inf2:
    crlr_info2.append(i.text.strip())
    
# Scrap de precio
chrysler_soup2 = BeautifulSoup(page.content, "lxml")

crlr_pr2 = chrysler_soup2.find_all('span', {'class' : 'left share-value'})

crlr_precio2= list()
for i in crlr_pr2:
    crlr_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/chrysler/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
chrysler_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
crlr_md3 = chrysler_soup3.find_all('h4', class_ = 'bold size-h6 left')
crlr_modelos3 = list()

for i in crlr_md3:
    crlr_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
crlr_inf3 = chrysler_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
crlr_info3= list()

for i in crlr_inf3:
    crlr_info3.append(i.text.strip())
    
# Scrap de precio
chrysler_soup3 = BeautifulSoup(page.content, "lxml")

crlr_pr3 = chrysler_soup3.find_all('span', {'class' : 'left share-value'})

crlr_precio3= list()
for i in crlr_pr3:
    crlr_precio3.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/chrysler/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MQ=="
page = requests.get(URL)
chrysler_soup4 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
crlr_md4 = chrysler_soup4.find_all('h4', class_ = 'bold size-h6 left')
crlr_modelos4 = list()

for i in crlr_md4:
    crlr_modelos4.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
crlr_inf4 = chrysler_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
crlr_info4= list()

for i in crlr_inf4:
    crlr_info4.append(i.text.strip())
    
# Scrap de precio
chrysler_soup4 = BeautifulSoup(page.content, "lxml")

crlr_pr4 = chrysler_soup4.find_all('span', {'class' : 'left share-value'})

crlr_precio4= list()
for i in crlr_pr4:
    crlr_precio4.append(i.text.strip())

# %% [markdown]
# ### Hago el DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(crlr_modelos1, crlr_info1, crlr_precio1))
list_tuples2= list(zip(crlr_modelos2, crlr_info2, crlr_precio2))

# Agrego las tuplas y nombro las columnas
crlr_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
crlr_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
crlr_df = crlr_df1.append(crlr_df2, ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples3= list(zip(crlr_modelos3, crlr_info3, crlr_precio3))
list_tuples4= list(zip(crlr_modelos4, crlr_info4, crlr_precio4))

# Agrego las tuplas y nombro las columnas
crlr_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
crlr_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
crlr_df5 = crlr_df3.append([crlr_df, crlr_df4], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
crlr_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Chrysler Ventas.csv', index = False, header=False)

# %%
crlr_df5.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Chrysler3 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Fiat

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/fiat/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
fiat_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ft_md1 = fiat_soup1.find_all('h4', class_ = 'bold size-h6 left')
ft_modelos1 = list()

for i in ft_md1:
    ft_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ft_inf1 = fiat_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ft_info1= list()

for i in ft_inf1:
    ft_info1.append(i.text.strip())
    
# Scrap de precio
fiat_soup1 = BeautifulSoup(page.content, "lxml")

ft_pr1 = fiat_soup1.find_all('span', {'class' : 'left share-value'})

ft_precio1= list()
for i in ft_pr1:
    ft_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/fiat/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
fiat_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ft_md2 = fiat_soup2.find_all('h4', class_ = 'bold size-h6 left')
ft_modelos2 = list()

for i in ft_md2:
    ft_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ft_inf2 = fiat_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ft_info2= list()

for i in ft_inf2:
    ft_info2.append(i.text.strip())
    
# Scrap de precio
fiat_soup2 = BeautifulSoup(page.content, "lxml")

ft_pr2 = fiat_soup2.find_all('span', {'class' : 'left share-value'})

ft_precio2= list()
for i in ft_pr2:
    ft_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/fiat/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mg=="
page = requests.get(URL)
fiat_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ft_md3 = fiat_soup3.find_all('h4', class_ = 'bold size-h6 left')
ft_modelos3 = list()

for i in ft_md3:
    ft_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ft_inf3 = fiat_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ft_info3= list()

for i in ft_inf3:
    ft_info3.append(i.text.strip())
    
# Scrap de precio
fiat_soup3 = BeautifulSoup(page.content, "lxml")

ft_pr3 = fiat_soup3.find_all('span', {'class' : 'left share-value'})

ft_precio3= list()
for i in ft_pr3:
    ft_precio3.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/fiat/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mw=="
page = requests.get(URL)
fiat_soup4 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ft_md4 = fiat_soup4.find_all('h4', class_ = 'bold size-h6 left')
ft_modelos4 = list()

for i in ft_md4:
    ft_modelos4.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ft_inf4 = fiat_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ft_info4= list()

for i in ft_inf4:
    ft_info4.append(i.text.strip())
    
# Scrap de precio
fiat_soup4 = BeautifulSoup(page.content, "lxml")

ft_pr4 = fiat_soup4.find_all('span', {'class' : 'left share-value'})

ft_precio4= list()
for i in ft_pr4:
    ft_precio4.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/fiat/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=NA=="
page = requests.get(URL)
fiat_soup5 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ft_md5 = fiat_soup5.find_all('h4', class_ = 'bold size-h6 left')
ft_modelos5 = list()

for i in ft_md5:
    ft_modelos5.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ft_inf5 = fiat_soup5.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ft_info5= list()

for i in ft_inf5:
    ft_info5.append(i.text.strip())
    
# Scrap de precio
fiat_soup5 = BeautifulSoup(page.content, "lxml")

ft_pr5 = fiat_soup5.find_all('span', {'class' : 'left share-value'})

ft_precio5= list()
for i in ft_pr5:
    ft_precio5.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/fiat/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Mg=="
page = requests.get(URL)
fiat_soup6 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ft_md6 = fiat_soup6.find_all('h4', class_ = 'bold size-h6 left')
ft_modelos6 = list()

for i in ft_md6:
    ft_modelos6.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ft_inf6 = fiat_soup6.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ft_info6= list()

for i in ft_inf6:
    ft_info6.append(i.text.strip())
    
# Scrap de precio
fiat_soup6 = BeautifulSoup(page.content, "lxml")

ft_pr6 = fiat_soup6.find_all('span', {'class' : 'left share-value'})

ft_precio6= list()
for i in ft_pr6:
    ft_precio6.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/fiat/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Mw=="
page = requests.get(URL)
fiat_soup7 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ft_md7 = fiat_soup7.find_all('h4', class_ = 'bold size-h6 left')
ft_modelos7 = list()

for i in ft_md7:
    ft_modelos7.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ft_inf7 = fiat_soup7.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ft_info7= list()

for i in ft_inf7:
    ft_info7.append(i.text.strip())
    
# Scrap de precio
fiat_soup7 = BeautifulSoup(page.content, "lxml")

ft_pr7 = fiat_soup7.find_all('span', {'class' : 'left share-value'})

ft_precio7= list()
for i in ft_pr7:
    ft_precio7.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/fiat/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=NA=="
page = requests.get(URL)
fiat_soup8 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ft_md8 = fiat_soup8.find_all('h4', class_ = 'bold size-h6 left')
ft_modelos8 = list()

for i in ft_md8:
    ft_modelos8.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ft_inf8 = fiat_soup8.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ft_info8= list()

for i in ft_inf8:
    ft_info8.append(i.text.strip())
    
# Scrap de precio
fiat_soup8 = BeautifulSoup(page.content, "lxml")

ft_pr8 = fiat_soup8.find_all('span', {'class' : 'left share-value'})

ft_precio8= list()
for i in ft_pr8:
    ft_precio8.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/fiat/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=NQ=="
page = requests.get(URL)
fiat_soup9 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ft_md9 = fiat_soup9.find_all('h4', class_ = 'bold size-h6 left')
ft_modelos9 = list()

for i in ft_md9:
    ft_modelos9.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ft_inf9 = fiat_soup9.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ft_info9 = list()

for i in ft_inf9:
    ft_info9.append(i.text.strip())
    
# Scrap de precio
fiat_soup9 = BeautifulSoup(page.content, "lxml")

ft_pr9 = fiat_soup9.find_all('span', {'class' : 'left share-value'})

ft_precio9= list()
for i in ft_pr9:
    ft_precio9.append(i.text.strip())

# %% [markdown]
# ### Hago el DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(ft_modelos1, ft_info1, ft_precio1))
list_tuples2= list(zip(ft_modelos2, ft_info2, ft_precio2))
list_tuples3= list(zip(ft_modelos3, ft_info3, ft_precio3))
list_tuples4= list(zip(ft_modelos4, ft_info4, ft_precio4))
list_tuples5= list(zip(ft_modelos5, ft_info5, ft_precio5))

# Agrego las tuplas y nombro las columnas
ft_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
ft_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
ft_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
ft_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])
ft_df5 = pd.DataFrame(list_tuples5, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
fiat_df = ft_df1.append([ft_df2, ft_df3, ft_df4, ft_df5], ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples6= list(zip(ft_modelos6, ft_info6, ft_precio6))
list_tuples7= list(zip(ft_modelos7, ft_info7, ft_precio7))
list_tuples8= list(zip(ft_modelos8, ft_info8, ft_precio8))
list_tuples9= list(zip(ft_modelos9, ft_info9, ft_precio9))

# Agrego las tuplas y nombro las columnas
ft_df6 = pd.DataFrame(list_tuples6, columns= ['Modelos', 'Información', 'Precio'])
ft_df7 = pd.DataFrame(list_tuples7, columns= ['Modelos', 'Información', 'Precio'])
ft_df8 = pd.DataFrame(list_tuples8, columns= ['Modelos', 'Información', 'Precio'])
ft_df9 = pd.DataFrame(list_tuples9, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
fiat_df10 = ft_df6.append([fiat_df, ft_df7, ft_df8, ft_df9], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
fiat_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Fiat Ventas.csv', index = False, header=False)

# %%
fiat_df10.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Fiat3 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Honda

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/honda/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
honda_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
hd_md1 = honda_soup1.find_all('h4', class_ = 'bold size-h6 left')
hd_modelos1 = list()

for i in hd_md1:
    hd_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
hd_inf1 = honda_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
hd_info1= list()

for i in hd_inf1:
    hd_info1.append(i.text.strip())
    
# Scrap de precio
honda_soup1 = BeautifulSoup(page.content, "lxml")

hd_pr1 = honda_soup1.find_all('span', {'class' : 'left share-value'})

hd_precio1= list()
for i in hd_pr1:
    hd_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/honda/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
honda_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
hd_md2 = honda_soup2.find_all('h4', class_ = 'bold size-h6 left')
hd_modelos2 = list()

for i in hd_md2:
    hd_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
hd_inf2 = honda_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
hd_info2= list()

for i in hd_inf2:
    hd_info2.append(i.text.strip())
    
# Scrap de precio
honda_soup2 = BeautifulSoup(page.content, "lxml")

hd_pr2 = honda_soup2.find_all('span', {'class' : 'left share-value'})

hd_precio2= list()
for i in hd_pr2:
    hd_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/honda/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mg=="
page = requests.get(URL)
honda_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
hd_md3 = honda_soup3.find_all('h4', class_ = 'bold size-h6 left')
hd_modelos3 = list()

for i in hd_md3:
    hd_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
hd_inf3 = honda_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
hd_info3= list()

for i in hd_inf3:
    hd_info3.append(i.text.strip())
    
# Scrap de precio
honda_soup3 = BeautifulSoup(page.content, "lxml")

hd_pr3 = honda_soup3.find_all('span', {'class' : 'left share-value'})

hd_precio3= list()
for i in hd_pr3:
    hd_precio3.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/honda/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mw=="
page = requests.get(URL)
honda_soup4 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
hd_md4 = honda_soup4.find_all('h4', class_ = 'bold size-h6 left')
hd_modelos4 = list()

for i in hd_md4:
    hd_modelos4.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
hd_inf4 = honda_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
hd_info4= list()

for i in hd_inf4:
    hd_info4.append(i.text.strip())
    
# Scrap de precio
honda_soup4 = BeautifulSoup(page.content, "lxml")

hd_pr4 = honda_soup4.find_all('span', {'class' : 'left share-value'})

hd_precio4= list()
for i in hd_pr4:
    hd_precio4.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/honda/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=NA=="
page = requests.get(URL)
honda_soup5 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
hd_md5 = honda_soup5.find_all('h4', class_ = 'bold size-h6 left')
hd_modelos5 = list()

for i in hd_md5:
    hd_modelos5.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
hd_inf5 = honda_soup5.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
hd_info5= list()

for i in hd_inf5:
    hd_info5.append(i.text.strip())
    
# Scrap de precio
honda_soup5 = BeautifulSoup(page.content, "lxml")

hd_pr5 = honda_soup5.find_all('span', {'class' : 'left share-value'})

hd_precio5= list()
for i in hd_pr5:
    hd_precio5.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/honda/-/2021?type_autos_moderated=moderated&page=NQ==&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
honda_soup6 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
hd_md6 = honda_soup6.find_all('h4', class_ = 'bold size-h6 left')
hd_modelos6 = list()

for i in hd_md6:
    hd_modelos6.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
hd_inf6 = honda_soup6.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
hd_info6= list()

for i in hd_inf6:
    hd_info6.append(i.text.strip())
    
# Scrap de precio
honda_soup6 = BeautifulSoup(page.content, "lxml")

hd_pr6 = honda_soup6.find_all('span', {'class' : 'left share-value'})

hd_precio6 = list()
for i in hd_pr6:
    hd_precio6.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/honda/-/2021?type_autos_moderated=moderated&page=Ng==&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
honda_soup7 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
hd_md7 = honda_soup7.find_all('h4', class_ = 'bold size-h6 left')
hd_modelos7 = list()

for i in hd_md7:
    hd_modelos7.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
hd_inf7 = honda_soup7.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
hd_info7= list()

for i in hd_inf7:
    hd_info7.append(i.text.strip())
    
# Scrap de precio
honda_soup7 = BeautifulSoup(page.content, "lxml")

hd_pr7 = honda_soup7.find_all('span', {'class' : 'left share-value'})

hd_precio7 = list()
for i in hd_pr7:
    hd_precio7.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/honda/-/2021?type_autos_moderated=moderated&page=Nw==&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
honda_soup8 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
hd_md8 = honda_soup8.find_all('h4', class_ = 'bold size-h6 left')
hd_modelos8 = list()

for i in hd_md8:
    hd_modelos8.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
hd_inf8 = honda_soup8.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
hd_info8 = list()

for i in hd_inf8:
    hd_info8.append(i.text.strip())
    
# Scrap de precio
honda_soup8 = BeautifulSoup(page.content, "lxml")

hd_pr8 = honda_soup8.find_all('span', {'class' : 'left share-value'})

hd_precio8 = list()
for i in hd_pr8:
    hd_precio8.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/honda/-/2021?type_autos_moderated=moderated&page=OA==&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
honda_soup9 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
hd_md9 = honda_soup9.find_all('h4', class_ = 'bold size-h6 left')
hd_modelos9 = list()

for i in hd_md9:
    hd_modelos9.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
hd_inf9 = honda_soup9.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
hd_info9 = list()

for i in hd_inf9:
    hd_info9.append(i.text.strip())
    
# Scrap de precio
honda_soup9 = BeautifulSoup(page.content, "lxml")

hd_pr9 = honda_soup9.find_all('span', {'class' : 'left share-value'})

hd_precio9 = list()
for i in hd_pr9:
    hd_precio9.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/honda/-/2021?type_autos_moderated=moderated&page=OQ==&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
honda_soup10 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
hd_md10 = honda_soup10.find_all('h4', class_ = 'bold size-h6 left')
hd_modelos10 = list()

for i in hd_md10:
    hd_modelos10.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
hd_inf10 = honda_soup10.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
hd_info10 = list()

for i in hd_inf10:
    hd_info10.append(i.text.strip())
    
# Scrap de precio
honda_soup10 = BeautifulSoup(page.content, "lxml")

hd_pr10 = honda_soup10.find_all('span', {'class' : 'left share-value'})

hd_precio10 = list()
for i in hd_pr10:
    hd_precio10.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/honda/-/2021?type_autos_moderated=moderated&page=MTA=&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
honda_soup11 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
hd_md11 = honda_soup11.find_all('h4', class_ = 'bold size-h6 left')
hd_modelos11 = list()

for i in hd_md11:
    hd_modelos11.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
hd_inf11 = honda_soup11.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
hd_info11 = list()

for i in hd_inf11:
    hd_info11.append(i.text.strip())
    
# Scrap de precio
honda_soup11 = BeautifulSoup(page.content, "lxml")

hd_pr11 = honda_soup11.find_all('span', {'class' : 'left share-value'})

hd_precio11 = list()
for i in hd_pr11:
    hd_precio11.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/honda/-/2021?type_autos_moderated=moderated&page=MTE=&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
honda_soup12 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
hd_md12 = honda_soup12.find_all('h4', class_ = 'bold size-h6 left')
hd_modelos12 = list()

for i in hd_md12:
    hd_modelos12.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
hd_inf12 = honda_soup12.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
hd_info12 = list()

for i in hd_inf12:
    hd_info12.append(i.text.strip())
    
# Scrap de precio
honda_soup12 = BeautifulSoup(page.content, "lxml")

hd_pr12 = honda_soup12.find_all('span', {'class' : 'left share-value'})

hd_precio12 = list()
for i in hd_pr12:
    hd_precio12.append(i.text.strip())

# %% [markdown]
# ### Hago el DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(hd_modelos1, hd_info1, hd_precio1))
list_tuples2= list(zip(hd_modelos2, hd_info2, hd_precio2))
list_tuples3= list(zip(hd_modelos3, hd_info3, hd_precio3))
list_tuples4= list(zip(hd_modelos4, hd_info4, hd_precio4))
list_tuples5= list(zip(hd_modelos5, hd_info5, hd_precio5))

# Agrego las tuplas y nombro las columnas
hd_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
hd_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
hd_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
hd_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])
hd_df5 = pd.DataFrame(list_tuples5, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
honda_df = hd_df1.append([hd_df2, hd_df3, hd_df4, hd_df5], ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples6= list(zip(hd_modelos6, hd_info6, hd_precio6))
list_tuples7= list(zip(hd_modelos7, hd_info7, hd_precio7))
list_tuples8= list(zip(hd_modelos8, hd_info8, hd_precio8))
list_tuples9= list(zip(hd_modelos9, hd_info9, hd_precio9))
list_tuples10= list(zip(hd_modelos10, hd_info10, hd_precio10))
list_tuples11= list(zip(hd_modelos11, hd_info11, hd_precio11))
list_tuples12= list(zip(hd_modelos12, hd_info12, hd_precio12))

# Agrego las tuplas y nombro las columnas
hd_df6 = pd.DataFrame(list_tuples6, columns= ['Modelos', 'Información', 'Precio'])
hd_df7 = pd.DataFrame(list_tuples7, columns= ['Modelos', 'Información', 'Precio'])
hd_df8 = pd.DataFrame(list_tuples8, columns= ['Modelos', 'Información', 'Precio'])
hd_df9 = pd.DataFrame(list_tuples9, columns= ['Modelos', 'Información', 'Precio'])
hd_df10 = pd.DataFrame(list_tuples10, columns= ['Modelos', 'Información', 'Precio'])
hd_df11 = pd.DataFrame(list_tuples11, columns= ['Modelos', 'Información', 'Precio'])
hd_df12 = pd.DataFrame(list_tuples12, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
honda_df13 = hd_df6.append([honda_df, hd_df7, hd_df8, hd_df9, hd_df10, hd_df11, hd_df12], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
honda_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Honda Ventas.csv', index = False, header=False)

# %%
honda_df13.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Honda3 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Hyundai Ventas

# %% [markdown]
# ### Hyundai Ventas

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/hyundai/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
hyundai_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
hy_md1 = hyundai_soup1.find_all('h4', class_ = 'bold size-h6 left')
hy_modelos1 = list()

for i in hy_md1:
    hy_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
hy_inf1 = hyundai_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
hy_info1= list()

for i in hy_inf1:
    hy_info1.append(i.text.strip())
    
# Scrap de precio
hyundai_soup1 = BeautifulSoup(page.content, "lxml")

hy_pr1 = hyundai_soup1.find_all('span', {'class' : 'left share-value'})

hy_precio1= list()
for i in hy_pr1:
    hy_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/hyundai/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
hyundai_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
hy_md2 = hyundai_soup2.find_all('h4', class_ = 'bold size-h6 left')
hy_modelos2 = list()

for i in hy_md2:
    hy_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
hy_inf2 = hyundai_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
hy_info2= list()

for i in hy_inf2:
    hy_info2.append(i.text.strip())
    
# Scrap de precio
hyundai_soup2 = BeautifulSoup(page.content, "lxml")

hy_pr2= hyundai_soup2.find_all('span', {'class' : 'left share-value'})

hy_precio2= list()
for i in hy_pr2:
    hy_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/hyundai/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mg=="
page = requests.get(URL)
hyundai_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
hy_md3 = hyundai_soup3.find_all('h4', class_ = 'bold size-h6 left')
hy_modelos3 = list()

for i in hy_md3:
    hy_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
hy_inf3 = hyundai_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
hy_info3= list()

for i in hy_inf3:
    hy_info3.append(i.text.strip())
    
# Scrap de precio
hyundai_soup3 = BeautifulSoup(page.content, "lxml")

hy_pr3= hyundai_soup3.find_all('span', {'class' : 'left share-value'})

hy_precio3= list()
for i in hy_pr3:
    hy_precio3.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/hyundai/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mw=="
page = requests.get(URL)
hyundai_soup4 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
hy_md4 = hyundai_soup4.find_all('h4', class_ = 'bold size-h6 left')
hy_modelos4 = list()

for i in hy_md4:
    hy_modelos4.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
hy_inf4 = hyundai_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
hy_info4= list()

for i in hy_inf4:
    hy_info4.append(i.text.strip())
    
# Scrap de precio
hyundai_soup4 = BeautifulSoup(page.content, "lxml")
hy_pr4= hyundai_soup4.find_all('span', {'class' : 'left share-value'})

hy_precio4= list()
for i in hy_pr4:
    hy_precio4.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/hyundai/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mw=="
page = requests.get(URL)
hyundai_soup5 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
hy_md5 = hyundai_soup5.find_all('h4', class_ = 'bold size-h6 left')
hy_modelos5 = list()

for i in hy_md5:
    hy_modelos5.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
hy_inf5 = hyundai_soup5.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
hy_info5= list()

for i in hy_inf5:
    hy_info5.append(i.text.strip())
    
# Scrap de precio
hyundai_soup5 = BeautifulSoup(page.content, "lxml")
hy_pr5= hyundai_soup5.find_all('span', {'class' : 'left share-value'})

hy_precio5= list()
for i in hy_pr5:
    hy_precio5.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/hyundai/-/2021?type_autos_moderated=moderated&page=NQ==&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
hyundai_soup6 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
hy_md6 = hyundai_soup6.find_all('h4', class_ = 'bold size-h6 left')
hy_modelos6 = list()

for i in hy_md6:
    hy_modelos6.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
hy_inf6 = hyundai_soup6.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
hy_info6= list()

for i in hy_inf6:
    hy_info6.append(i.text.strip())
    
# Scrap de precio
hyundai_soup6 = BeautifulSoup(page.content, "lxml")
hy_pr6= hyundai_soup6.find_all('span', {'class' : 'left share-value'})

hy_precio6= list()
for i in hy_pr6:
    hy_precio6.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/hyundai/-/2021?type_autos_moderated=moderated&page=Ng==&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
hyundai_soup7 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
hy_md7 = hyundai_soup7.find_all('h4', class_ = 'bold size-h6 left')
hy_modelos7 = list()

for i in hy_md7:
    hy_modelos7.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
hy_inf7 = hyundai_soup7.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
hy_info7= list()

for i in hy_inf7:
    hy_info7.append(i.text.strip())
    
# Scrap de precio
hyundai_soup7 = BeautifulSoup(page.content, "lxml")
hy_pr7 = hyundai_soup7.find_all('span', {'class' : 'left share-value'})

hy_precio7 = list()
for i in hy_pr7:
    hy_precio7.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/hyundai/-/2021?type_autos_moderated=moderated&page=Nw==&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
hyundai_soup8 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
hy_md8 = hyundai_soup8.find_all('h4', class_ = 'bold size-h6 left')
hy_modelos8 = list()

for i in hy_md8:
    hy_modelos8.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
hy_inf8 = hyundai_soup8.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
hy_info8= list()

for i in hy_inf8:
    hy_info8.append(i.text.strip())
    
# Scrap de precio
hyundai_soup8 = BeautifulSoup(page.content, "lxml")
hy_pr8 = hyundai_soup8.find_all('span', {'class' : 'left share-value'})

hy_precio8 = list()
for i in hy_pr8:
    hy_precio8.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/hyundai/-/2021?type_autos_moderated=moderated&page=OA==&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
hyundai_soup9 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
hy_md9 = hyundai_soup9.find_all('h4', class_ = 'bold size-h6 left')
hy_modelos9 = list()

for i in hy_md9:
    hy_modelos9.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
hy_inf9 = hyundai_soup9.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
hy_info9= list()

for i in hy_inf9:
    hy_info9.append(i.text.strip())
    
# Scrap de precio
hyundai_soup9 = BeautifulSoup(page.content, "lxml")
hy_pr9 = hyundai_soup9.find_all('span', {'class' : 'left share-value'})

hy_precio9 = list()
for i in hy_pr9:
    hy_precio9.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/hyundai/-/2021?type_autos_moderated=moderated&page=OQ==&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
hyundai_soup10 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
hy_md10 = hyundai_soup10.find_all('h4', class_ = 'bold size-h6 left')
hy_modelos10 = list()

for i in hy_md10:
    hy_modelos10.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
hy_inf10 = hyundai_soup10.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
hy_info10= list()

for i in hy_inf10:
    hy_info10.append(i.text.strip())
    
# Scrap de precio
hyundai_soup10 = BeautifulSoup(page.content, "lxml")
hy_pr10 = hyundai_soup10.find_all('span', {'class' : 'left share-value'})

hy_precio10 = list()
for i in hy_pr10:
    hy_precio10.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/hyundai/-/2021?type_autos_moderated=moderated&page=MTA=&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
hyundai_soup11 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
hy_md11 = hyundai_soup11.find_all('h4', class_ = 'bold size-h6 left')
hy_modelos11 = list()

for i in hy_md11:
    hy_modelos11.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
hy_inf11 = hyundai_soup11.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
hy_info11 = list()

for i in hy_inf11:
    hy_info11.append(i.text.strip())
    
# Scrap de precio
hyundai_soup11 = BeautifulSoup(page.content, "lxml")
hy_pr11 = hyundai_soup11.find_all('span', {'class' : 'left share-value'})

hy_precio11 = list()
for i in hy_pr11:
    hy_precio11.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/hyundai/-/2021?type_autos_moderated=moderated&page=MTE=&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
hyundai_soup12 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
hy_md12 = hyundai_soup12.find_all('h4', class_ = 'bold size-h6 left')
hy_modelos12 = list()

for i in hy_md12:
    hy_modelos12.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
hy_inf12 = hyundai_soup12.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
hy_info12 = list()

for i in hy_inf12:
    hy_info12.append(i.text.strip())
    
# Scrap de precio
hyundai_soup12 = BeautifulSoup(page.content, "lxml")
hy_pr12 = hyundai_soup12.find_all('span', {'class' : 'left share-value'})

hy_precio12 = list()
for i in hy_pr12:
    hy_precio12.append(i.text.strip())

# %% [markdown]
# ### Hago el DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(hy_modelos1, hy_info1, hy_precio1))
list_tuples2= list(zip(hy_modelos2, hy_info2, hy_precio2))
list_tuples3= list(zip(hy_modelos3, hy_info3, hy_precio3))
list_tuples4= list(zip(hy_modelos4, hy_info4, hy_precio4))
list_tuples5= list(zip(hy_modelos5, hy_info5, hy_precio5))

# Agrego las tuplas y nombro las columnas
hy_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
hy_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
hy_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
hy_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])
hy_df5 = pd.DataFrame(list_tuples5, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
hyundai_df = hy_df1.append([hy_df2, hy_df3, hy_df4, hy_df5], ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples6= list(zip(hy_modelos6, hy_info6, hy_precio6))
list_tuples7= list(zip(hy_modelos7, hy_info7, hy_precio7))
list_tuples8= list(zip(hy_modelos8, hy_info8, hy_precio8))
list_tuples9= list(zip(hy_modelos9, hy_info9, hy_precio9))
list_tuples10= list(zip(hy_modelos10, hy_info10, hy_precio10))
list_tuples11= list(zip(hy_modelos11, hy_info11, hy_precio11))
list_tuples12= list(zip(hy_modelos12, hy_info12, hy_precio12))

# Agrego las tuplas y nombro las columnas
hy_df6 = pd.DataFrame(list_tuples6, columns= ['Modelos', 'Información', 'Precio'])
hy_df7 = pd.DataFrame(list_tuples7, columns= ['Modelos', 'Información', 'Precio'])
hy_df8 = pd.DataFrame(list_tuples8, columns= ['Modelos', 'Información', 'Precio'])
hy_df9 = pd.DataFrame(list_tuples9, columns= ['Modelos', 'Información', 'Precio'])
hy_df10 = pd.DataFrame(list_tuples10, columns= ['Modelos', 'Información', 'Precio'])
hy_df11 = pd.DataFrame(list_tuples11, columns= ['Modelos', 'Información', 'Precio'])
hy_df12 = pd.DataFrame(list_tuples12, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
hyundai_df13 = hy_df6.append([hyundai_df, hy_df7, hy_df8, hy_df9, hy_df10, hy_df11, hy_df12], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
hyundai_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Hyundai Ventas.csv', index = False, header=False)

# %%
hyundai_df13.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Hyundai3 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Infiniti

# %% [markdown]
# ### Infiniti Ventas

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/infiniti/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
infiniti_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ift_md1 = infiniti_soup1.find_all('h4', class_ = 'bold size-h6 left')
ift_modelos1 = list()

for i in ift_md1:
    ift_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ift_inf1 = infiniti_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ift_info1= list()

for i in ift_inf1:
    ift_info1.append(i.text.strip())
    
# Scrap de precio
infiniti_soup1 = BeautifulSoup(page.content, "lxml")

ift_pr1 = infiniti_soup1.find_all('span', {'class' : 'left share-value'})

ift_precio1= list()
for i in ift_pr1:
    ift_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/infiniti/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
infiniti_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ift_md2 = infiniti_soup2.find_all('h4', class_ = 'bold size-h6 left')
ift_modelos2 = list()

for i in ift_md2:
    ift_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ift_inf2 = infiniti_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ift_info2= list()

for i in ift_inf2:
    ift_info2.append(i.text.strip())
    
# Scrap de precio
infiniti_soup2 = BeautifulSoup(page.content, "lxml")
ift_pr2 = infiniti_soup2.find_all('span', {'class' : 'left share-value'})

ift_precio2= list()
for i in ift_pr2:
    ift_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/infiniti/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mg=="
page = requests.get(URL)
infiniti_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ift_md3 = infiniti_soup3.find_all('h4', class_ = 'bold size-h6 left')
ift_modelos3 = list()

for i in ift_md3:
    ift_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ift_inf3 = infiniti_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ift_info3= list()

for i in ift_inf3:
    ift_info3.append(i.text.strip())
    
# Scrap de precio
infiniti_soup3 = BeautifulSoup(page.content, "lxml")
ift_pr3 = infiniti_soup3.find_all('span', {'class' : 'left share-value'})

ift_precio3= list()
for i in ift_pr3:
    ift_precio3.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/infiniti/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mw=="
page = requests.get(URL)
infiniti_soup4 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ift_md4 = infiniti_soup4.find_all('h4', class_ = 'bold size-h6 left')
ift_modelos4 = list()

for i in ift_md4:
    ift_modelos4.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ift_inf4 = infiniti_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ift_info4= list()

for i in ift_inf4:
    ift_info4.append(i.text.strip())
    
# Scrap de precio
infiniti_soup4 = BeautifulSoup(page.content, "lxml")
ift_pr4 = infiniti_soup4.find_all('span', {'class' : 'left share-value'})

ift_precio4= list()
for i in ift_pr4:
    ift_precio4.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/infiniti/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
infiniti_soup5 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ift_md5 = infiniti_soup5.find_all('h4', class_ = 'bold size-h6 left')
ift_modelos5 = list()

for i in ift_md5:
    ift_modelos5.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ift_inf5 = infiniti_soup5.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ift_info5= list()

for i in ift_inf5:
    ift_info5.append(i.text.strip())
    
# Scrap de precio
infiniti_soup5 = BeautifulSoup(page.content, "lxml")
ift_pr5 = infiniti_soup5.find_all('span', {'class' : 'left share-value'})

ift_precio5 = list()
for i in ift_pr5:
    ift_precio5.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/infiniti/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MQ=="
page = requests.get(URL)
infiniti_soup6 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ift_md6 = infiniti_soup6.find_all('h4', class_ = 'bold size-h6 left')
ift_modelos6 = list()

for i in ift_md6:
    ift_modelos6.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ift_inf6 = infiniti_soup6.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ift_info6= list()

for i in ift_inf6:
    ift_info6.append(i.text.strip())
    
# Scrap de precio
infiniti_soup6 = BeautifulSoup(page.content, "lxml")
ift_pr6 = infiniti_soup6.find_all('span', {'class' : 'left share-value'})

ift_precio6 = list()
for i in ift_pr6:
    ift_precio6.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/infiniti/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Mg=="
page = requests.get(URL)
infiniti_soup7 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ift_md7 = infiniti_soup7.find_all('h4', class_ = 'bold size-h6 left')
ift_modelos7 = list()

for i in ift_md7:
    ift_modelos7.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ift_inf7 = infiniti_soup7.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ift_info7= list()

for i in ift_inf7:
    ift_info7.append(i.text.strip())
    
# Scrap de precio
infiniti_soup7 = BeautifulSoup(page.content, "lxml")
ift_pr7 = infiniti_soup7.find_all('span', {'class' : 'left share-value'})

ift_precio7 = list()
for i in ift_pr7:
    ift_precio7.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/infiniti/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Mw=="
page = requests.get(URL)
infiniti_soup8 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ift_md8 = infiniti_soup8.find_all('h4', class_ = 'bold size-h6 left')
ift_modelos8 = list()

for i in ift_md8:
    ift_modelos8.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ift_inf8 = infiniti_soup8.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ift_info8= list()

for i in ift_inf8:
    ift_info8.append(i.text.strip())
    
# Scrap de precio
infiniti_soup8 = BeautifulSoup(page.content, "lxml")
ift_pr8 = infiniti_soup8.find_all('span', {'class' : 'left share-value'})

ift_precio8 = list()
for i in ift_pr8:
    ift_precio8.append(i.text.strip())

# %% [markdown]
# ### Infiniti DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(ift_modelos1, ift_info1, ift_precio1))
list_tuples2= list(zip(ift_modelos2, ift_info2, ift_precio2))
list_tuples3= list(zip(ift_modelos3, ift_info3, ift_precio3))
list_tuples4= list(zip(ift_modelos4, ift_info4, ift_precio4))

# Agrego las tuplas y nombro las columnas
ift_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
ift_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
ift_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
ift_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
infiniti_df = ift_df1.append([ift_df2, ift_df3, ift_df4], ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples5= list(zip(ift_modelos5, ift_info5, ift_precio5))
list_tuples6= list(zip(ift_modelos6, ift_info6, ift_precio6))
list_tuples7= list(zip(ift_modelos7, ift_info7, ift_precio7))
list_tuples8= list(zip(ift_modelos8, ift_info8, ift_precio8))

# Agrego las tuplas y nombro las columnas
ift_df5 = pd.DataFrame(list_tuples5, columns= ['Modelos', 'Información', 'Precio'])
ift_df6 = pd.DataFrame(list_tuples6, columns= ['Modelos', 'Información', 'Precio'])
ift_df7 = pd.DataFrame(list_tuples7, columns= ['Modelos', 'Información', 'Precio'])
ift_df8 = pd.DataFrame(list_tuples8, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
infiniti_df9 = ift_df5.append([infiniti_df , ift_df6, ift_df7, ift_df8], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
infiniti_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Infiniti Ventas.csv', index = False, header=False)

# %%
infiniti_df9.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Infiniti3 Ventas.csv', index = False, header=False)

# %% [markdown]
# # JAC

# %% [markdown]
# ### JAC Ventas

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/jac/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
jac_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
jc_md1 = jac_soup1.find_all('h4', class_ = 'bold size-h6 left')
jc_modelos1 = list()

for i in jc_md1:
    jc_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
jc_inf1 = jac_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
jc_info1= list()

for i in jc_inf1:
    jc_info1.append(i.text.strip())
    
# Scrap de precio
jac_soup1 = BeautifulSoup(page.content, "lxml")

jc_pr1 = jac_soup1.find_all('span', {'class' : 'left share-value'})

jc_precio1= list()
for i in jc_pr1:
    jc_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/jac/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
jac_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
jc_md2 = jac_soup2.find_all('h4', class_ = 'bold size-h6 left')
jc_modelos2 = list()

for i in jc_md2:
    jc_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
jc_inf2 = jac_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
jc_info2= list()

for i in jc_inf2:
    jc_info2.append(i.text.strip())
    
# Scrap de precio
jac_soup2 = BeautifulSoup(page.content, "lxml")

jc_pr2 = jac_soup2.find_all('span', {'class' : 'left share-value'})

jc_precio2= list()
for i in jc_pr2:
    jc_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/jac/-/2021?type_autos_moderated=moderated&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
jac_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
jc_md3 = jac_soup3.find_all('h4', class_ = 'bold size-h6 left')
jc_modelos3 = list()

for i in jc_md3:
    jc_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
jc_inf3 = jac_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
jc_info3= list()

for i in jc_inf3:
    jc_info3.append(i.text.strip())
    
# Scrap de precio
jac_soup3 = BeautifulSoup(page.content, "lxml")

jc_pr3 = jac_soup3.find_all('span', {'class' : 'left share-value'})

jc_precio3= list()
for i in jc_pr3:
    jc_precio3.append(i.text.strip())

# %% [markdown]
# ### JAC DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(jc_modelos1, jc_info1, jc_precio1))
list_tuples2= list(zip(jc_modelos2, jc_info2, jc_precio2))

# Agrego las tuplas y nombro las columnas
jc_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
jc_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
jac_df = jc_df1.append([jc_df2], ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples3= list(zip(jc_modelos3, jc_info3, jc_precio3))

# Agrego las tuplas y nombro las columnas
jc_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])

# Junto los DF's
jac_df4 = jc_df3.append([jac_df], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
jac_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\JAC Ventas.csv', index = False, header=False)

# %%
jac_df4.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\JAC3 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Jaguar

# %% [markdown]
# ### Jaguar Ventas

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/jaguar/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
jaguar_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
jg_md1 = jaguar_soup1.find_all('h4', class_ = 'bold size-h6 left')
jg_modelos1 = list()

for i in jg_md1:
    jg_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
jg_inf1 = jaguar_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
jg_info1= list()

for i in jg_inf1:
    jg_info1.append(i.text.strip())
    
# Scrap de precio
jaguar_soup1 = BeautifulSoup(page.content, "lxml")

jg_pr1 = jaguar_soup1.find_all('span', {'class' : 'left share-value'})

jg_precio1= list()
for i in jg_pr1:
    jg_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/jaguar/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
jaguar_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
jg_md2 = jaguar_soup2.find_all('h4', class_ = 'bold size-h6 left')
jg_modelos2 = list()

for i in jg_md2:
    jg_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
jg_inf2 = jaguar_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
jg_info2= list()

for i in jg_inf2:
    jg_info2.append(i.text.strip())
    
# Scrap de precio
jaguar_soup2 = BeautifulSoup(page.content, "lxml")

jg_pr2 = jaguar_soup2.find_all('span', {'class' : 'left share-value'})

jg_precio2= list()
for i in jg_pr2:
    jg_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/jaguar/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MQ=="
page = requests.get(URL)
jaguar_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
jg_md3 = jaguar_soup3.find_all('h4', class_ = 'bold size-h6 left')
jg_modelos3 = list()

for i in jg_md3:
    jg_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
jg_inf3 = jaguar_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
jg_info3= list()

for i in jg_inf3:
    jg_info3.append(i.text.strip())
    
# Scrap de precio
jaguar_soup3 = BeautifulSoup(page.content, "lxml")

jg_pr3 = jaguar_soup3.find_all('span', {'class' : 'left share-value'})

jg_precio3= list()
for i in jg_pr3:
    jg_precio3.append(i.text.strip())

# %% [markdown]
# ### Jaguar DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(jg_modelos1, jg_info1, jg_precio1))

# Agrego las tuplas y nombro las columnas
jg_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples2= list(zip(jg_modelos2, jg_info2, jg_precio2))
list_tuples3= list(zip(jg_modelos3, jg_info3, jg_precio3))

# Agrego las tuplas y nombro las columnas
jg_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
jg_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
jg_df4 = jg_df2.append([jg_df1, jg_df3], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
jg_df1.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Jaguar Ventas.csv', index = False, header=False)

# %%
jg_df4.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Jaguar3 Ventas.csv', index = False, header=False)

# %% [markdown]
# # KIA

# %% [markdown]
# ### Ventas Kia

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/kia/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
kia_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ka_md1 = kia_soup1.find_all('h4', class_ = 'bold size-h6 left')
ka_modelos1 = list()

for i in ka_md1:
    ka_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ka_inf1 = kia_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ka_info1= list()

for i in ka_inf1:
    ka_info1.append(i.text.strip())
    
# Scrap de precio
kia_soup1 = BeautifulSoup(page.content, "lxml")
ka_pr1 = kia_soup1.find_all('span', {'class' : 'left share-value'})

ka_precio1= list()
for i in ka_pr1:
    ka_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/kia/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
kia_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ka_md2 = kia_soup2.find_all('h4', class_ = 'bold size-h6 left')
ka_modelos2 = list()

for i in ka_md2:
    ka_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ka_inf2 = kia_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ka_info2= list()

for i in ka_inf2:
    ka_info2.append(i.text.strip())
    
# Scrap de precio
kia_soup2 = BeautifulSoup(page.content, "lxml")
ka_pr2 = kia_soup2.find_all('span', {'class' : 'left share-value'})

ka_precio2= list()
for i in ka_pr2:
    ka_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/kia/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mg=="
page = requests.get(URL)
kia_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ka_md3 = kia_soup3.find_all('h4', class_ = 'bold size-h6 left')
ka_modelos3 = list()

for i in ka_md3:
    ka_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ka_inf3 = kia_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ka_info3= list()

for i in ka_inf3:
    ka_info3.append(i.text.strip())
    
# Scrap de precio
kia_soup3 = BeautifulSoup(page.content, "lxml")
ka_pr3 = kia_soup3.find_all('span', {'class' : 'left share-value'})

ka_precio3= list()
for i in ka_pr3:
    ka_precio3.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/kia/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mw=="
page = requests.get(URL)
kia_soup4 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ka_md4 = kia_soup4.find_all('h4', class_ = 'bold size-h6 left')
ka_modelos4 = list()

for i in ka_md4:
    ka_modelos4.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ka_inf4 = kia_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ka_info4= list()

for i in ka_inf4:
    ka_info4.append(i.text.strip())
    
# Scrap de precio
kia_soup4 = BeautifulSoup(page.content, "lxml")
ka_pr4 = kia_soup4.find_all('span', {'class' : 'left share-value'})

ka_precio4= list()
for i in ka_pr4:
    ka_precio4.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/kia/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=NA=="
page = requests.get(URL)
kia_soup5 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ka_md5 = kia_soup5.find_all('h4', class_ = 'bold size-h6 left')
ka_modelos5 = list()

for i in ka_md5:
    ka_modelos5.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ka_inf5 = kia_soup5.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ka_info5= list()

for i in ka_inf5:
    ka_info5.append(i.text.strip())
    
# Scrap de precio
kia_soup5 = BeautifulSoup(page.content, "lxml")
ka_pr5 = kia_soup5.find_all('span', {'class' : 'left share-value'})

ka_precio5= list()
for i in ka_pr5:
    ka_precio5.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/kia/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=NQ=="
page = requests.get(URL)
kia_soup6 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ka_md6 = kia_soup6.find_all('h4', class_ = 'bold size-h6 left')
ka_modelos6 = list()

for i in ka_md6:
    ka_modelos6.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ka_inf6 = kia_soup6.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ka_info6= list()

for i in ka_inf6:
    ka_info6.append(i.text.strip())
    
# Scrap de precio
kia_soup6 = BeautifulSoup(page.content, "lxml")
ka_pr6 = kia_soup6.find_all('span', {'class' : 'left share-value'})

ka_precio6= list()
for i in ka_pr6:
    ka_precio6.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/kia/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Ng=="
page = requests.get(URL)
kia_soup7 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ka_md7 = kia_soup7.find_all('h4', class_ = 'bold size-h6 left')
ka_modelos7 = list()

for i in ka_md7:
    ka_modelos7.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ka_inf7 = kia_soup7.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ka_info7= list()

for i in ka_inf7:
    ka_info7.append(i.text.strip())
    
# Scrap de precio
kia_soup7 = BeautifulSoup(page.content, "lxml")
ka_pr7 = kia_soup7.find_all('span', {'class' : 'left share-value'})

ka_precio7 = list()
for i in ka_pr7:
    ka_precio7.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/kia/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Nw=="
page = requests.get(URL)
kia_soup8 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ka_md8 = kia_soup8.find_all('h4', class_ = 'bold size-h6 left')
ka_modelos8 = list()

for i in ka_md8:
    ka_modelos8.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ka_inf8 = kia_soup8.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ka_info8 = list()

for i in ka_inf8:
    ka_info8.append(i.text.strip())
    
# Scrap de precio
kia_soup8 = BeautifulSoup(page.content, "lxml")
ka_pr8 = kia_soup8.find_all('span', {'class' : 'left share-value'})

ka_precio8 = list()
for i in ka_pr8:
    ka_precio8.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/kia/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=OA=="
page = requests.get(URL)
kia_soup9 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ka_md9 = kia_soup9.find_all('h4', class_ = 'bold size-h6 left')
ka_modelos9 = list()

for i in ka_md9:
    ka_modelos9.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ka_inf9 = kia_soup9.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ka_info9 = list()

for i in ka_inf9:
    ka_info9.append(i.text.strip())
    
# Scrap de precio
kia_soup9 = BeautifulSoup(page.content, "lxml")
ka_pr9 = kia_soup9.find_all('span', {'class' : 'left share-value'})

ka_precio9 = list()
for i in ka_pr9:
    ka_precio9.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/kia/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=OQ=="
page = requests.get(URL)
kia_soup10 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ka_md10 = kia_soup10.find_all('h4', class_ = 'bold size-h6 left')
ka_modelos10 = list()

for i in ka_md10:
    ka_modelos10.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ka_inf10 = kia_soup10.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ka_info10 = list()

for i in ka_inf10:
    ka_info10.append(i.text.strip())
    
# Scrap de precio
kia_soup10 = BeautifulSoup(page.content, "lxml")
ka_pr10 = kia_soup10.find_all('span', {'class' : 'left share-value'})

ka_precio10 = list()
for i in ka_pr10:
    ka_precio10.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/kia/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MTA="
page = requests.get(URL)
kia_soup11 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ka_md11 = kia_soup11.find_all('h4', class_ = 'bold size-h6 left')
ka_modelos11 = list()

for i in ka_md11:
    ka_modelos11.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ka_inf11 = kia_soup11.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ka_info11 = list()

for i in ka_inf11:
    ka_info11.append(i.text.strip())
    
# Scrap de precio
kia_soup11 = BeautifulSoup(page.content, "lxml")
ka_pr11 = kia_soup11.find_all('span', {'class' : 'left share-value'})

ka_precio11 = list()
for i in ka_pr11:
    ka_precio11.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/kia/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MTE="
page = requests.get(URL)
kia_soup12 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
ka_md12 = kia_soup12.find_all('h4', class_ = 'bold size-h6 left')
ka_modelos12 = list()

for i in ka_md12:
    ka_modelos12.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
ka_inf12 = kia_soup12.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
ka_info12 = list()

for i in ka_inf12:
    ka_info12.append(i.text.strip())
    
# Scrap de precio
kia_soup12 = BeautifulSoup(page.content, "lxml")
ka_pr12 = kia_soup12.find_all('span', {'class' : 'left share-value'})

ka_precio12 = list()
for i in ka_pr12:
    ka_precio12.append(i.text.strip())

# %% [markdown]
# ### Kia DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(ka_modelos1, ka_info1, ka_precio1))
list_tuples2= list(zip(ka_modelos2, ka_info2, ka_precio2))
list_tuples3= list(zip(ka_modelos3, ka_info3, ka_precio3))
list_tuples4= list(zip(ka_modelos4, ka_info4, ka_precio4))
list_tuples5= list(zip(ka_modelos5, ka_info5, ka_precio5))

# Agrego las tuplas y nombro las columnas
ka_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
ka_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
ka_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
ka_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])
ka_df5 = pd.DataFrame(list_tuples5, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
kia_df = ka_df1.append([ka_df2, ka_df3, ka_df4, ka_df5], ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples6= list(zip(ka_modelos6, ka_info6, ka_precio6))
list_tuples7= list(zip(ka_modelos7, ka_info7, ka_precio7))
list_tuples8= list(zip(ka_modelos8, ka_info8, ka_precio8))
list_tuples9= list(zip(ka_modelos9, ka_info9, ka_precio9))
list_tuples10= list(zip(ka_modelos10, ka_info10, ka_precio10))
list_tuples11= list(zip(ka_modelos11, ka_info11, ka_precio11))
list_tuples12= list(zip(ka_modelos12, ka_info12, ka_precio12))

# Agrego las tuplas y nombro las columnas
ka_df6 = pd.DataFrame(list_tuples6, columns= ['Modelos', 'Información', 'Precio'])
ka_df7 = pd.DataFrame(list_tuples7, columns= ['Modelos', 'Información', 'Precio'])
ka_df8 = pd.DataFrame(list_tuples8, columns= ['Modelos', 'Información', 'Precio'])
ka_df9 = pd.DataFrame(list_tuples9, columns= ['Modelos', 'Información', 'Precio'])
ka_df10 = pd.DataFrame(list_tuples10, columns= ['Modelos', 'Información', 'Precio'])
ka_df11 = pd.DataFrame(list_tuples11, columns= ['Modelos', 'Información', 'Precio'])
ka_df12 = pd.DataFrame(list_tuples12, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
ka_df13 = ka_df6.append([kia_df, ka_df7, ka_df8, ka_df9, ka_df10, ka_df11, ka_df12], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
kia_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Kia Ventas.csv', index = False, header=False)

# %%
ka_df13.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Kia3 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Land Rover Aqui me quede

# %% [markdown]
# ### Land Rover Ventas

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/land+rover/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
landrover_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
lr_md1 = landrover_soup1.find_all('h4', class_ = 'bold size-h6 left')
lr_modelos1 = list()

for i in lr_md1:
    lr_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
lr_inf1 = landrover_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
lr_info1= list()

for i in lr_inf1:
    lr_info1.append(i.text.strip())
    
# Scrap de precio
landrover_soup1 = BeautifulSoup(page.content, "lxml")

lr_pr1 = landrover_soup1.find_all('span', {'class' : 'left share-value'})

lr_precio1= list()
for i in lr_pr1:
    lr_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/land+rover/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
landrover_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
lr_md2 = landrover_soup2.find_all('h4', class_ = 'bold size-h6 left')
lr_modelos2 = list()

for i in lr_md2:
    lr_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
lr_inf2 = landrover_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
lr_info2 = list()

for i in lr_inf2:
    lr_info2.append(i.text.strip())
    
# Scrap de precio
landrover_soup2 = BeautifulSoup(page.content, "lxml")

lr_pr2 = landrover_soup2.find_all('span', {'class' : 'left share-value'})

lr_precio2 = list()
for i in lr_pr2:
    lr_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/land+rover/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MQ=="
page = requests.get(URL)
landrover_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
lr_md3 = landrover_soup3.find_all('h4', class_ = 'bold size-h6 left')
lr_modelos3 = list()

for i in lr_md3:
    lr_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
lr_inf3 = landrover_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
lr_info3 = list()

for i in lr_inf3:
    lr_info3.append(i.text.strip())
    
# Scrap de precio
landrover_soup3 = BeautifulSoup(page.content, "lxml")

lr_pr3 = landrover_soup3.find_all('span', {'class' : 'left share-value'})

lr_precio3 = list()
for i in lr_pr3:
    lr_precio3.append(i.text.strip())

# %% [markdown]
# ### Land Rover DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(lr_modelos1, lr_info1, lr_precio1))

# Agrego las tuplas y nombro las columnas
landrover_df = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples2= list(zip(lr_modelos2, lr_info2, lr_precio2))
list_tuples3= list(zip(lr_modelos3, lr_info3, lr_precio3))

# Agrego las tuplas y nombro las columnas
lr_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
lr_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
lr_df4 = lr_df2.append([landrover_df, lr_df3], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
landrover_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Land Rover Ventas.csv', index = False, header=False)

# %%
lr_df4.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Land Rover3 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Lincoln

# %% [markdown]
# ### Lincoln Ventas

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/lincoln/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
lincoln_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
lcn_md1 = lincoln_soup1.find_all('h4', class_ = 'bold size-h6 left')
lcn_modelos1 = list()

for i in lcn_md1:
    lcn_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
lcn_inf1 = lincoln_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
lcn_info1= list()

for i in lcn_inf1:
    lcn_info1.append(i.text.strip())
    
# Scrap de precio
lincoln_soup1 = BeautifulSoup(page.content, "lxml")

lcn_pr1 = lincoln_soup1.find_all('span', {'class' : 'left share-value'})

lcn_precio1= list()
for i in lcn_pr1:
    lcn_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/lincoln/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
lincoln_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
lcn_md2 = lincoln_soup2.find_all('h4', class_ = 'bold size-h6 left')
lcn_modelos2 = list()

for i in lcn_md2:
    lcn_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
lcn_inf2 = lincoln_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
lcn_info2= list()

for i in lcn_inf2:
    lcn_info2.append(i.text.strip())
    
# Scrap de precio
lincoln_soup2 = BeautifulSoup(page.content, "lxml")

lcn_pr2 = lincoln_soup2.find_all('span', {'class' : 'left share-value'})

lcn_precio2= list()
for i in lcn_pr2:
    lcn_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/lincoln/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
lincoln_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
lcn_md2 = lincoln_soup2.find_all('h4', class_ = 'bold size-h6 left')
lcn_modelos2 = list()

for i in lcn_md2:
    lcn_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
lcn_inf2 = lincoln_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
lcn_info2 = list()

for i in lcn_inf2:
    lcn_info2.append(i.text.strip())
    
# Scrap de precio
lincoln_soup2 = BeautifulSoup(page.content, "lxml")

lcn_pr2 = lincoln_soup2.find_all('span', {'class' : 'left share-value'})

lcn_precio2 = list()
for i in lcn_pr2:
    lcn_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/lincoln/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MQ=="
page = requests.get(URL)
lincoln_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
lcn_md3 = lincoln_soup3.find_all('h4', class_ = 'bold size-h6 left')
lcn_modelos3 = list()

for i in lcn_md3:
    lcn_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
lcn_inf3 = lincoln_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
lcn_info3 = list()

for i in lcn_inf3:
    lcn_info3.append(i.text.strip())
    
# Scrap de precio
lincoln_soup3 = BeautifulSoup(page.content, "lxml")

lcn_pr3 = lincoln_soup3.find_all('span', {'class' : 'left share-value'})

lcn_precio3 = list()
for i in lcn_pr3:
    lcn_precio3.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/lincoln/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Mg=="
page = requests.get(URL)
lincoln_soup4 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
lcn_md4 = lincoln_soup4.find_all('h4', class_ = 'bold size-h6 left')
lcn_modelos4 = list()

for i in lcn_md4:
    lcn_modelos4.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
lcn_inf4 = lincoln_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
lcn_info4 = list()

for i in lcn_inf4:
    lcn_info4.append(i.text.strip())
    
# Scrap de precio
lincoln_soup4 = BeautifulSoup(page.content, "lxml")

lcn_pr4 = lincoln_soup4.find_all('span', {'class' : 'left share-value'})

lcn_precio4 = list()
for i in lcn_pr4:
    lcn_precio4.append(i.text.strip())

# %% [markdown]
# ### Lincoln DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(lcn_modelos1, lcn_info1, lcn_precio1))
list_tuples2= list(zip(lcn_modelos2, lcn_info2, lcn_precio2))

# Agrego las tuplas y nombro las columnas
lcn_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
lcn_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
lincoln_df = lcn_df1.append([lcn_df2], ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples2= list(zip(lcn_modelos2, lcn_info2, lcn_precio2))
list_tuples3= list(zip(lcn_modelos3, lcn_info3, lcn_precio3))
list_tuples4= list(zip(lcn_modelos4, lcn_info4, lcn_precio4))

# Agrego las tuplas y nombro las columnas
lcn_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
lcn_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
lcn_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
lincoln_df5 = lcn_df2.append([lincoln_df, lcn_df3, lcn_df4], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
lincoln_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Lincoln Ventas.csv', index = False, header=False)

# %%
lincoln_df5.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Lincoln3 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Mazda

# %% [markdown]
# ### Mazda Ventas

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mazda/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
mazda_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mzd_md1 = mazda_soup1.find_all('h4', class_ = 'bold size-h6 left')
mzd_modelos1 = list()

for i in mzd_md1:
    mzd_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mzd_inf1 = mazda_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mzd_info1= list()

for i in mzd_inf1:
    mzd_info1.append(i.text.strip())
    
# Scrap de precio
mazda_soup1 = BeautifulSoup(page.content, "lxml")
mzd_pr1 = mazda_soup1.find_all('span', {'class' : 'left share-value'})

mzd_precio1= list()
for i in mzd_pr1:
    mzd_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mazda/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
mazda_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mzd_md2 = mazda_soup2.find_all('h4', class_ = 'bold size-h6 left')
mzd_modelos2 = list()

for i in mzd_md2:
    mzd_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mzd_inf2 = mazda_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mzd_info2= list()

for i in mzd_inf2:
    mzd_info2.append(i.text.strip())
    
# Scrap de precio
mazda_soup2 = BeautifulSoup(page.content, "lxml")

mzd_pr2 = mazda_soup2.find_all('span', {'class' : 'left share-value'})

mzd_precio2= list()
for i in mzd_pr2:
    mzd_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mazda/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mg=="
page = requests.get(URL)
mazda_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mzd_md3 = mazda_soup3.find_all('h4', class_ = 'bold size-h6 left')
mzd_modelos3 = list()

for i in mzd_md3:
    mzd_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mzd_inf3 = mazda_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mzd_info3= list()

for i in mzd_inf3:
    mzd_info3.append(i.text.strip())
    
# Scrap de precio
mazda_soup3 = BeautifulSoup(page.content, "lxml")
mzd_pr3 = mazda_soup3.find_all('span', {'class' : 'left share-value'})

mzd_precio3= list()
for i in mzd_pr3:
    mzd_precio3.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mazda/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mw=="
page = requests.get(URL)
mazda_soup4 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mzd_md4 = mazda_soup4.find_all('h4', class_ = 'bold size-h6 left')
mzd_modelos4 = list()

for i in mzd_md4:
    mzd_modelos4.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mzd_inf4 = mazda_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mzd_info4 = list()

for i in mzd_inf4:
    mzd_info4.append(i.text.strip())
    
# Scrap de precio
mazda_soup4 = BeautifulSoup(page.content, "lxml")

mzd_pr4 = mazda_soup4.find_all('span', {'class' : 'left share-value'})

mzd_precio4= list()
for i in mzd_pr4:
    mzd_precio4.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mazda/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=NA=="
page = requests.get(URL)
mazda_soup5 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mzd_md5 = mazda_soup5.find_all('h4', class_ = 'bold size-h6 left')
mzd_modelos5 = list()

for i in mzd_md5:
    mzd_modelos5.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mzd_inf5 = mazda_soup5.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mzd_info5 = list()

for i in mzd_inf5:
    mzd_info5.append(i.text.strip())
    
# Scrap de precio
mazda_soup5 = BeautifulSoup(page.content, "lxml")

mzd_pr5 = mazda_soup5.find_all('span', {'class' : 'left share-value'})

mzd_precio5= list()
for i in mzd_pr5:
    mzd_precio5.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mazda/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=NQ=="
page = requests.get(URL)
mazda_soup6 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mzd_md6 = mazda_soup6.find_all('h4', class_ = 'bold size-h6 left')
mzd_modelos6 = list()

for i in mzd_md6:
    mzd_modelos6.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mzd_inf6 = mazda_soup6.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mzd_info6 = list()

for i in mzd_inf6:
    mzd_info6.append(i.text.strip())
    
# Scrap de precio
mazda_soup6 = BeautifulSoup(page.content, "lxml")

mzd_pr6 = mazda_soup6.find_all('span', {'class' : 'left share-value'})

mzd_precio6 = list()
for i in mzd_pr6:
    mzd_precio6.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mazda/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=NQ=="
page = requests.get(URL)
mazda_soup6 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mzd_md6 = mazda_soup6.find_all('h4', class_ = 'bold size-h6 left')
mzd_modelos6 = list()

for i in mzd_md6:
    mzd_modelos6.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mzd_inf6 = mazda_soup6.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mzd_info6 = list()

for i in mzd_inf6:
    mzd_info6.append(i.text.strip())
    
# Scrap de precio
mazda_soup6 = BeautifulSoup(page.content, "lxml")

mzd_pr6 = mazda_soup6.find_all('span', {'class' : 'left share-value'})

mzd_precio6 = list()
for i in mzd_pr6:
    mzd_precio6.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mazda/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Ng=="
page = requests.get(URL)
mazda_soup7 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mzd_md7 = mazda_soup7.find_all('h4', class_ = 'bold size-h6 left')
mzd_modelos7 = list()

for i in mzd_md7:
    mzd_modelos7.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mzd_inf7 = mazda_soup7.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mzd_info7 = list()

for i in mzd_inf7:
    mzd_info7.append(i.text.strip())
    
# Scrap de precio
mazda_soup7 = BeautifulSoup(page.content, "lxml")

mzd_pr7 = mazda_soup7.find_all('span', {'class' : 'left share-value'})

mzd_precio7 = list()
for i in mzd_pr7:
    mzd_precio7.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mazda/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Nw=="
page = requests.get(URL)
mazda_soup8 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mzd_md8 = mazda_soup8.find_all('h4', class_ = 'bold size-h6 left')
mzd_modelos8 = list()

for i in mzd_md8:
    mzd_modelos8.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mzd_inf8 = mazda_soup8.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mzd_info8 = list()

for i in mzd_inf8:
    mzd_info8.append(i.text.strip())
    
# Scrap de precio
mazda_soup8 = BeautifulSoup(page.content, "lxml")

mzd_pr8 = mazda_soup8.find_all('span', {'class' : 'left share-value'})

mzd_precio8 = list()
for i in mzd_pr8:
    mzd_precio8.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mazda/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=OA=="
page = requests.get(URL)
mazda_soup9 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mzd_md9 = mazda_soup9.find_all('h4', class_ = 'bold size-h6 left')
mzd_modelos9 = list()

for i in mzd_md9:
    mzd_modelos9.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mzd_inf9 = mazda_soup9.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mzd_info9 = list()

for i in mzd_inf9:
    mzd_info9.append(i.text.strip())
    
# Scrap de precio
mazda_soup9 = BeautifulSoup(page.content, "lxml")

mzd_pr9 = mazda_soup9.find_all('span', {'class' : 'left share-value'})

mzd_precio9 = list()
for i in mzd_pr9:
    mzd_precio9.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mazda/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=OQ=="
page = requests.get(URL)
mazda_soup10 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mzd_md10 = mazda_soup10.find_all('h4', class_ = 'bold size-h6 left')
mzd_modelos10 = list()

for i in mzd_md10:
    mzd_modelos10.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mzd_inf10 = mazda_soup10.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mzd_info10 = list()

for i in mzd_inf10:
    mzd_info10.append(i.text.strip())
    
# Scrap de precio
mazda_soup10 = BeautifulSoup(page.content, "lxml")

mzd_pr10 = mazda_soup10.find_all('span', {'class' : 'left share-value'})

mzd_precio10 = list()
for i in mzd_pr10:
    mzd_precio10.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mazda/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MTA="
page = requests.get(URL)
mazda_soup11 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mzd_md11 = mazda_soup11.find_all('h4', class_ = 'bold size-h6 left')
mzd_modelos11 = list()

for i in mzd_md11:
    mzd_modelos11.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mzd_inf11 = mazda_soup11.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mzd_info11 = list()

for i in mzd_inf11:
    mzd_info11.append(i.text.strip())
    
# Scrap de precio
mazda_soup11 = BeautifulSoup(page.content, "lxml")

mzd_pr11 = mazda_soup11.find_all('span', {'class' : 'left share-value'})

mzd_precio11 = list()
for i in mzd_pr11:
    mzd_precio11.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mazda/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MTE="
page = requests.get(URL)
mazda_soup12 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mzd_md12 = mazda_soup12.find_all('h4', class_ = 'bold size-h6 left')
mzd_modelos12 = list()

for i in mzd_md12:
    mzd_modelos12.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mzd_inf12 = mazda_soup12.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mzd_info12 = list()

for i in mzd_inf12:
    mzd_info12.append(i.text.strip())
    
# Scrap de precio
mazda_soup12 = BeautifulSoup(page.content, "lxml")

mzd_pr12 = mazda_soup12.find_all('span', {'class' : 'left share-value'})

mzd_precio12 = list()
for i in mzd_pr12:
    mzd_precio12.append(i.text.strip())

# %% [markdown]
# ### Mazda DataFrames

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(mzd_modelos1, mzd_info1, mzd_precio1))
list_tuples2= list(zip(mzd_modelos2, mzd_info2, mzd_precio2))
list_tuples3= list(zip(mzd_modelos3, mzd_info3, mzd_precio3))
list_tuples4= list(zip(mzd_modelos4, mzd_info4, mzd_precio4))
list_tuples5= list(zip(mzd_modelos5, mzd_info5, mzd_precio5))

# Agrego las tuplas y nombro las columnas
mzd_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
mzd_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
mzd_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
mzd_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])
mzd_df5 = pd.DataFrame(list_tuples5, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
mazda_df = mzd_df1.append([mzd_df2, mzd_df3, mzd_df4, mzd_df5], ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples6= list(zip(mzd_modelos6, mzd_info6, mzd_precio6))
list_tuples7= list(zip(mzd_modelos7, mzd_info7, mzd_precio7))
list_tuples8= list(zip(mzd_modelos8, mzd_info8, mzd_precio8))
list_tuples9= list(zip(mzd_modelos9, mzd_info9, mzd_precio9))
list_tuples10= list(zip(mzd_modelos10, mzd_info10, mzd_precio10))
list_tuples11= list(zip(mzd_modelos11, mzd_info11, mzd_precio11))
list_tuples12= list(zip(mzd_modelos12, mzd_info12, mzd_precio12))

# Agrego las tuplas y nombro las columnas
mzd_df6 = pd.DataFrame(list_tuples6, columns= ['Modelos', 'Información', 'Precio'])
mzd_df7 = pd.DataFrame(list_tuples7, columns= ['Modelos', 'Información', 'Precio'])
mzd_df8 = pd.DataFrame(list_tuples8, columns= ['Modelos', 'Información', 'Precio'])
mzd_df9 = pd.DataFrame(list_tuples9, columns= ['Modelos', 'Información', 'Precio'])
mzd_df10 = pd.DataFrame(list_tuples10, columns= ['Modelos', 'Información', 'Precio'])
mzd_df11 = pd.DataFrame(list_tuples11, columns= ['Modelos', 'Información', 'Precio'])
mzd_df12 = pd.DataFrame(list_tuples12, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
mzd_df13 = mzd_df6.append([mazda_df, mzd_df7, mzd_df8, mzd_df9, mzd_df10, mzd_df11, mzd_df12], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
mzd_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Mazda Ventas.csv', index = False, header=False)

# %%
mzd_df13.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Mazda3 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Mercedez Benz

# %% [markdown]
# ### Mercedez Ventas

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mercedes+benz/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
mercedez_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mrz_md1 = mercedez_soup1.find_all('h4', class_ = 'bold size-h6 left')
mrz_modelos1 = list()

for i in mrz_md1:
    mrz_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mrz_inf1 = mercedez_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mrz_info1= list()

for i in mrz_inf1:
    mrz_info1.append(i.text.strip())
    
# Scrap de precio
mercedez_soup1 = BeautifulSoup(page.content, "lxml")
mrz_pr1 = mercedez_soup1.find_all('span', {'class' : 'left share-value'})

mrz_precio1= list()
for i in mrz_pr1:
    mrz_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mercedes+benz/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
mercedez_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mrz_md2 = mercedez_soup2.find_all('h4', class_ = 'bold size-h6 left')
mrz_modelos2 = list()

for i in mrz_md2:
    mrz_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mrz_inf2 = mercedez_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mrz_info2= list()

for i in mrz_inf2:
    mrz_info2.append(i.text.strip())
    
# Scrap de precio
mercedez_soup2 = BeautifulSoup(page.content, "lxml")
mrz_pr2 = mercedez_soup2.find_all('span', {'class' : 'left share-value'})

mrz_precio2= list()
for i in mrz_pr2:
    mrz_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mercedes+benz/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mg=="
page = requests.get(URL)
mercedez_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mrz_md3 = mercedez_soup3.find_all('h4', class_ = 'bold size-h6 left')
mrz_modelos3 = list()

for i in mrz_md3:
    mrz_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mrz_inf3 = mercedez_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mrz_info3= list()

for i in mrz_inf3:
    mrz_info3.append(i.text.strip())
    
# Scrap de precio
mercedez_soup3 = BeautifulSoup(page.content, "lxml")
mrz_pr3 = mercedez_soup3.find_all('span', {'class' : 'left share-value'})

mrz_precio3= list()
for i in mrz_pr3:
    mrz_precio3.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mercedes+benz/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mw=="
page = requests.get(URL)
mercedez_soup4 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mrz_md4 = mercedez_soup4.find_all('h4', class_ = 'bold size-h6 left')
mrz_modelos4 = list()

for i in mrz_md4:
    mrz_modelos4.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mrz_inf4 = mercedez_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mrz_info4= list()

for i in mrz_inf4:
    mrz_info4.append(i.text.strip())
    
# Scrap de precio
mercedez_soup4 = BeautifulSoup(page.content, "lxml")
mrz_pr4 = mercedez_soup4.find_all('span', {'class' : 'left share-value'})

mrz_precio4= list()
for i in mrz_pr4:
    mrz_precio4.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mercedes+benz/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=NA=="
page = requests.get(URL)
mercedez_soup5 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mrz_md5 = mercedez_soup5.find_all('h4', class_ = 'bold size-h6 left')
mrz_modelos5 = list()

for i in mrz_md5:
    mrz_modelos5.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mrz_inf5 = mercedez_soup5.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mrz_info5= list()

for i in mrz_inf5:
    mrz_info5.append(i.text.strip())
    
# Scrap de precio
mercedez_soup5 = BeautifulSoup(page.content, "lxml")
mrz_pr5 = mercedez_soup5.find_all('span', {'class' : 'left share-value'})

mrz_precio5= list()
for i in mrz_pr5:
    mrz_precio5.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mercedes+benz/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=NQ=="
page = requests.get(URL)
mercedez_soup6 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mrz_md6 = mercedez_soup6.find_all('h4', class_ = 'bold size-h6 left')
mrz_modelos6 = list()

for i in mrz_md6:
    mrz_modelos6.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mrz_inf6 = mercedez_soup6.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mrz_info6 = list()

for i in mrz_inf6:
    mrz_info6.append(i.text.strip())
    
# Scrap de precio
mercedez_soup6 = BeautifulSoup(page.content, "lxml")
mrz_pr6 = mercedez_soup6.find_all('span', {'class' : 'left share-value'})

mrz_precio6 = list()
for i in mrz_pr6:
    mrz_precio6.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mercedes+benz/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Ng=="
page = requests.get(URL)
mercedez_soup7 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mrz_md7 = mercedez_soup7.find_all('h4', class_ = 'bold size-h6 left')
mrz_modelos7 = list()

for i in mrz_md7:
    mrz_modelos7.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mrz_inf7 = mercedez_soup7.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mrz_info7 = list()

for i in mrz_inf7:
    mrz_info7.append(i.text.strip())
    
# Scrap de precio
mercedez_soup7 = BeautifulSoup(page.content, "lxml")
mrz_pr7 = mercedez_soup7.find_all('span', {'class' : 'left share-value'})

mrz_precio7 = list()
for i in mrz_pr7:
    mrz_precio7.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mercedes+benz/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Nw=="
page = requests.get(URL)
mercedez_soup8 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mrz_md8 = mercedez_soup8.find_all('h4', class_ = 'bold size-h6 left')
mrz_modelos8 = list()

for i in mrz_md8:
    mrz_modelos8.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mrz_inf8 = mercedez_soup8.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mrz_info8 = list()

for i in mrz_inf8:
    mrz_info8.append(i.text.strip())
    
# Scrap de precio
mercedez_soup8 = BeautifulSoup(page.content, "lxml")
mrz_pr8 = mercedez_soup8.find_all('span', {'class' : 'left share-value'})

mrz_precio8 = list()
for i in mrz_pr8:
    mrz_precio8.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mercedes+benz/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=OA=="
page = requests.get(URL)
mercedez_soup9 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mrz_md9 = mercedez_soup9.find_all('h4', class_ = 'bold size-h6 left')
mrz_modelos9 = list()

for i in mrz_md9:
    mrz_modelos9.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mrz_inf9 = mercedez_soup9.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mrz_info9 = list()

for i in mrz_inf9:
    mrz_info9.append(i.text.strip())
    
# Scrap de precio
mercedez_soup9 = BeautifulSoup(page.content, "lxml")
mrz_pr9 = mercedez_soup9.find_all('span', {'class' : 'left share-value'})

mrz_precio9 = list()
for i in mrz_pr9:
    mrz_precio9.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mercedes+benz/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=OQ=="
page = requests.get(URL)
mercedez_soup10 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mrz_md10 = mercedez_soup10.find_all('h4', class_ = 'bold size-h6 left')
mrz_modelos10 = list()

for i in mrz_md10:
    mrz_modelos10.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mrz_inf10 = mercedez_soup10.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mrz_info10 = list()

for i in mrz_inf10:
    mrz_info10.append(i.text.strip())
    
# Scrap de precio
mercedez_soup10 = BeautifulSoup(page.content, "lxml")
mrz_pr10 = mercedez_soup10.find_all('span', {'class' : 'left share-value'})

mrz_precio10 = list()
for i in mrz_pr10:
    mrz_precio10.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mercedes+benz/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MTA="
page = requests.get(URL)
mercedez_soup11 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mrz_md11 = mercedez_soup11.find_all('h4', class_ = 'bold size-h6 left')
mrz_modelos11 = list()

for i in mrz_md11:
    mrz_modelos11.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mrz_inf11 = mercedez_soup11.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mrz_info11 = list()

for i in mrz_inf11:
    mrz_info11.append(i.text.strip())
    
# Scrap de precio
mercedez_soup11 = BeautifulSoup(page.content, "lxml")
mrz_pr11 = mercedez_soup11.find_all('span', {'class' : 'left share-value'})

mrz_precio11 = list()
for i in mrz_pr11:
    mrz_precio11.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mercedes+benz/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MTE="
page = requests.get(URL)
mercedez_soup12 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mrz_md12 = mercedez_soup12.find_all('h4', class_ = 'bold size-h6 left')
mrz_modelos12 = list()

for i in mrz_md12:
    mrz_modelos12.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mrz_inf12 = mercedez_soup12.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mrz_info12 = list()

for i in mrz_inf12:
    mrz_info12.append(i.text.strip())
    
# Scrap de precio
mercedez_soup12 = BeautifulSoup(page.content, "lxml")
mrz_pr12 = mercedez_soup12.find_all('span', {'class' : 'left share-value'})

mrz_precio12 = list()
for i in mrz_pr12:
    mrz_precio12.append(i.text.strip())

# %% [markdown]
# ### Mercedez DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(mrz_modelos1, mrz_info1, mrz_precio1))
list_tuples2= list(zip(mrz_modelos2, mrz_info2, mrz_precio2))
list_tuples3= list(zip(mrz_modelos3, mrz_info3, mrz_precio3))
list_tuples4= list(zip(mrz_modelos4, mrz_info4, mrz_precio4))
list_tuples5= list(zip(mrz_modelos5, mrz_info5, mrz_precio5))

# Agrego las tuplas y nombro las columnas
mrz_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
mrz_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
mrz_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
mrz_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])
mrz_df5 = pd.DataFrame(list_tuples5, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
mercedez_df = mrz_df1.append([mrz_df2, mrz_df3, mrz_df4, mrz_df5], ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples6= list(zip(mrz_modelos6, mrz_info6, mrz_precio6))
list_tuples7= list(zip(mrz_modelos7, mrz_info7, mrz_precio7))
list_tuples8= list(zip(mrz_modelos8, mrz_info8, mrz_precio8))
list_tuples9= list(zip(mrz_modelos9, mrz_info9, mrz_precio9))
list_tuples10= list(zip(mrz_modelos10, mrz_info10, mrz_precio10))
list_tuples11= list(zip(mrz_modelos11, mrz_info11, mrz_precio11))
list_tuples12= list(zip(mrz_modelos12, mrz_info12, mrz_precio12))

# Agrego las tuplas y nombro las columnas
mrz_df6 = pd.DataFrame(list_tuples6, columns= ['Modelos', 'Información', 'Precio'])
mrz_df7 = pd.DataFrame(list_tuples7, columns= ['Modelos', 'Información', 'Precio'])
mrz_df8 = pd.DataFrame(list_tuples8, columns= ['Modelos', 'Información', 'Precio'])
mrz_df9 = pd.DataFrame(list_tuples9, columns= ['Modelos', 'Información', 'Precio'])
mrz_df10 = pd.DataFrame(list_tuples10, columns= ['Modelos', 'Información', 'Precio'])
mrz_df11 = pd.DataFrame(list_tuples11, columns= ['Modelos', 'Información', 'Precio'])
mrz_df12 = pd.DataFrame(list_tuples12, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
mrz_df13 = mrz_df6.append([mercedez_df, mrz_df7, mrz_df8, mrz_df9, mrz_df10, mrz_df11, mrz_df12], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
mercedez_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Mercedez Ventas.csv', index = False, header=False)

# %%
mrz_df13.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Mercedez3 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Mini

# %% [markdown]
# ### Ventas Mini

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mini/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
mini_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mn_md1 = mini_soup1.find_all('h4', class_ = 'bold size-h6 left')
mn_modelos1 = list()

for i in mn_md1:
    mn_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mn_inf1 = mini_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mn_info1= list()

for i in mn_inf1:
    mn_info1.append(i.text.strip())
    
# Scrap de precio
mini_soup1 = BeautifulSoup(page.content, "lxml")
mn_pr1 = mini_soup1.find_all('span', {'class' : 'left share-value'})

mn_precio1= list()
for i in mn_pr1:
    mn_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mini/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
mini_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mn_md2 = mini_soup2.find_all('h4', class_ = 'bold size-h6 left')
mn_modelos2 = list()

for i in mn_md2:
    mn_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mn_inf2 = mini_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mn_info2= list()

for i in mn_inf2:
    mn_info2.append(i.text.strip())
    
# Scrap de precio
mini_soup2 = BeautifulSoup(page.content, "lxml")
mn_pr2 = mini_soup2.find_all('span', {'class' : 'left share-value'})

mn_precio2= list()
for i in mn_pr2:
    mn_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mini/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mg=="
page = requests.get(URL)
mini_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mn_md3 = mini_soup3.find_all('h4', class_ = 'bold size-h6 left')
mn_modelos3 = list()

for i in mn_md3:
    mn_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mn_inf3 = mini_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mn_info3= list()

for i in mn_inf3:
    mn_info3.append(i.text.strip())
    
# Scrap de precio
mini_soup3 = BeautifulSoup(page.content, "lxml")
mn_pr3 = mini_soup3.find_all('span', {'class' : 'left share-value'})

mn_precio3= list()
for i in mn_pr3:
    mn_precio3.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mini/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mw=="
page = requests.get(URL)
mini_soup4 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mn_md4 = mini_soup4.find_all('h4', class_ = 'bold size-h6 left')
mn_modelos4 = list()

for i in mn_md4:
    mn_modelos4.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mn_inf4 = mini_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mn_info4= list()

for i in mn_inf4:
    mn_info4.append(i.text.strip())
    
# Scrap de precio
mini_soup4 = BeautifulSoup(page.content, "lxml")
mn_pr4 = mini_soup4.find_all('span', {'class' : 'left share-value'})

mn_precio4= list()
for i in mn_pr4:
    mn_precio4.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mini/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=NA=="
page = requests.get(URL)
mini_soup5 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mn_md5 = mini_soup5.find_all('h4', class_ = 'bold size-h6 left')
mn_modelos5 = list()

for i in mn_md5:
    mn_modelos5.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mn_inf5 = mini_soup5.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mn_info5= list()

for i in mn_inf5:
    mn_info5.append(i.text.strip())
    
# Scrap de precio
mini_soup5 = BeautifulSoup(page.content, "lxml")
mn_pr5 = mini_soup5.find_all('span', {'class' : 'left share-value'})

mn_precio5= list()
for i in mn_pr5:
    mn_precio5.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mini/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=NQ=="
page = requests.get(URL)
mini_soup6 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mn_md6 = mini_soup6.find_all('h4', class_ = 'bold size-h6 left')
mn_modelos6 = list()

for i in mn_md6:
    mn_modelos6.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mn_inf6 = mini_soup6.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mn_info6 = list()

for i in mn_inf6:
    mn_info6.append(i.text.strip())
    
# Scrap de precio
mini_soup6 = BeautifulSoup(page.content, "lxml")
mn_pr6 = mini_soup6.find_all('span', {'class' : 'left share-value'})

mn_precio6 = list()
for i in mn_pr6:
    mn_precio6.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mini/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Ng=="
page = requests.get(URL)
mini_soup7 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mn_md7 = mini_soup7.find_all('h4', class_ = 'bold size-h6 left')
mn_modelos7 = list()

for i in mn_md7:
    mn_modelos7.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mn_inf7 = mini_soup7.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mn_info7 = list()

for i in mn_inf7:
    mn_info7.append(i.text.strip())
    
# Scrap de precio
mini_soup7 = BeautifulSoup(page.content, "lxml")
mn_pr7 = mini_soup7.find_all('span', {'class' : 'left share-value'})

mn_precio7 = list()
for i in mn_pr7:
    mn_precio7.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mini/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Nw=="
page = requests.get(URL)
mini_soup8 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mn_md8 = mini_soup8.find_all('h4', class_ = 'bold size-h6 left')
mn_modelos8 = list()

for i in mn_md8:
    mn_modelos8.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mn_inf8 = mini_soup8.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mn_info8 = list()

for i in mn_inf8:
    mn_info8.append(i.text.strip())
    
# Scrap de precio
mini_soup8 = BeautifulSoup(page.content, "lxml")
mn_pr8 = mini_soup8.find_all('span', {'class' : 'left share-value'})

mn_precio8 = list()
for i in mn_pr8:
    mn_precio8.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mini/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=OA=="
page = requests.get(URL)
mini_soup9 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mn_md9 = mini_soup9.find_all('h4', class_ = 'bold size-h6 left')
mn_modelos9 = list()

for i in mn_md9:
    mn_modelos9.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mn_inf9 = mini_soup9.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mn_info9 = list()

for i in mn_inf9:
    mn_info9.append(i.text.strip())
    
# Scrap de precio
mini_soup9 = BeautifulSoup(page.content, "lxml")
mn_pr9 = mini_soup9.find_all('span', {'class' : 'left share-value'})

mn_precio9 = list()
for i in mn_pr9:
    mn_precio9.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mini/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=OQ=="
page = requests.get(URL)
mini_soup10 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mn_md10 = mini_soup10.find_all('h4', class_ = 'bold size-h6 left')
mn_modelos10 = list()

for i in mn_md10:
    mn_modelos10.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mn_inf10 = mini_soup10.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mn_info10 = list()

for i in mn_inf10:
    mn_info10.append(i.text.strip())
    
# Scrap de precio
mini_soup10 = BeautifulSoup(page.content, "lxml")
mn_pr10 = mini_soup10.find_all('span', {'class' : 'left share-value'})

mn_precio10 = list()
for i in mn_pr10:
    mn_precio10.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mini/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MTA="
page = requests.get(URL)
mini_soup11 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mn_md11 = mini_soup11.find_all('h4', class_ = 'bold size-h6 left')
mn_modelos11 = list()

for i in mn_md11:
    mn_modelos11.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mn_inf11 = mini_soup11.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mn_info11 = list()

for i in mn_inf11:
    mn_info11.append(i.text.strip())
    
# Scrap de precio
mini_soup11 = BeautifulSoup(page.content, "lxml")
mn_pr11 = mini_soup11.find_all('span', {'class' : 'left share-value'})

mn_precio11 = list()
for i in mn_pr11:
    mn_precio11.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mini/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MTE="
page = requests.get(URL)
mini_soup12 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mn_md12 = mini_soup12.find_all('h4', class_ = 'bold size-h6 left')
mn_modelos12 = list()

for i in mn_md12:
    mn_modelos12.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mn_inf12 = mini_soup12.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mn_info12 = list()

for i in mn_inf12:
    mn_info12.append(i.text.strip())
    
# Scrap de precio
mini_soup12 = BeautifulSoup(page.content, "lxml")
mn_pr12 = mini_soup12.find_all('span', {'class' : 'left share-value'})

mn_precio12 = list()
for i in mn_pr12:
    mn_precio12.append(i.text.strip())

# %% [markdown]
# ### Mini DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(mn_modelos1, mn_info1, mn_precio1))
list_tuples2= list(zip(mn_modelos2, mn_info2, mn_precio2))
list_tuples3= list(zip(mn_modelos3, mn_info3, mn_precio3))
list_tuples4= list(zip(mn_modelos4, mn_info4, mn_precio4))
list_tuples5= list(zip(mn_modelos5, mn_info5, mn_precio5))

# Agrego las tuplas y nombro las columnas
mn_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
mn_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
mn_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
mn_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])
mn_df5 = pd.DataFrame(list_tuples5, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
mini_df = mn_df1.append([mn_df2, mn_df3, mn_df4, mn_df5], ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples6= list(zip(mn_modelos6, mn_info6, mn_precio6))
list_tuples7= list(zip(mn_modelos7, mn_info7, mn_precio7))
list_tuples8= list(zip(mn_modelos8, mn_info8, mn_precio8))
list_tuples9= list(zip(mn_modelos9, mn_info9, mn_precio9))
list_tuples10= list(zip(mn_modelos10, mn_info10, mn_precio10))
list_tuples11= list(zip(mn_modelos11, mn_info11, mn_precio11))
list_tuples12= list(zip(mn_modelos12, mn_info12, mn_precio12))

# Agrego las tuplas y nombro las columnas
mn_df6 = pd.DataFrame(list_tuples6, columns= ['Modelos', 'Información', 'Precio'])
mn_df7 = pd.DataFrame(list_tuples7, columns= ['Modelos', 'Información', 'Precio'])
mn_df8 = pd.DataFrame(list_tuples8, columns= ['Modelos', 'Información', 'Precio'])
mn_df9 = pd.DataFrame(list_tuples9, columns= ['Modelos', 'Información', 'Precio'])
mn_df10 = pd.DataFrame(list_tuples10, columns= ['Modelos', 'Información', 'Precio'])
mn_df11 = pd.DataFrame(list_tuples11, columns= ['Modelos', 'Información', 'Precio'])
mn_df12 = pd.DataFrame(list_tuples12, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
mn_df13 = mn_df6.append([mini_df, mn_df7, mn_df8, mn_df9, mn_df10, mn_df11, mn_df12], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
mini_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Mini Cooper Ventas.csv', index = False, header=False)

# %%
mn_df13.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Mini Cooper3 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Mitsubishi

# %% [markdown]
# ### Mitsubishi Ventas

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mitsubishi/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
mitsubishi_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mbh_md1 = mitsubishi_soup1.find_all('h4', class_ = 'bold size-h6 left')
mbh_modelos1 = list()

for i in mbh_md1:
    mbh_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mbh_inf1 = mitsubishi_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mbh_info1= list()

for i in mbh_inf1:
    mbh_info1.append(i.text.strip())
    
# Scrap de precio
mitsubishi_soup1 = BeautifulSoup(page.content, "lxml")
mbh_pr1 = mitsubishi_soup1.find_all('span', {'class' : 'left share-value'})

mbh_precio1= list()
for i in mbh_pr1:
    mbh_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mitsubishi/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
mitsubishi_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mbh_md2 = mitsubishi_soup2.find_all('h4', class_ = 'bold size-h6 left')
mbh_modelos2 = list()

for i in mbh_md2:
    mbh_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mbh_inf2 = mitsubishi_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mbh_info2= list()

for i in mbh_inf2:
    mbh_info2.append(i.text.strip())
    
# Scrap de precio
mitsubishi_soup2 = BeautifulSoup(page.content, "lxml")
mbh_pr2 = mitsubishi_soup2.find_all('span', {'class' : 'left share-value'})

mbh_precio2= list()
for i in mbh_pr2:
    mbh_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mitsubishi/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mg=="
page = requests.get(URL)
mitsubishi_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mbh_md3 = mitsubishi_soup3.find_all('h4', class_ = 'bold size-h6 left')
mbh_modelos3 = list()

for i in mbh_md3:
    mbh_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mbh_inf3 = mitsubishi_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mbh_info3= list()

for i in mbh_inf3:
    mbh_info3.append(i.text.strip())
    
# Scrap de precio
mitsubishi_soup3 = BeautifulSoup(page.content, "lxml")
mbh_pr3 = mitsubishi_soup3.find_all('span', {'class' : 'left share-value'})

mbh_precio3= list()
for i in mbh_pr3:
    mbh_precio3.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mitsubishi/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mw=="
page = requests.get(URL)
mitsubishi_soup4 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mbh_md4 = mitsubishi_soup4.find_all('h4', class_ = 'bold size-h6 left')
mbh_modelos4 = list()

for i in mbh_md4:
    mbh_modelos4.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mbh_inf4 = mitsubishi_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mbh_info4= list()

for i in mbh_inf4:
    mbh_info4.append(i.text.strip())
    
# Scrap de precio
mitsubishi_soup4 = BeautifulSoup(page.content, "lxml")
mbh_pr4 = mitsubishi_soup4.find_all('span', {'class' : 'left share-value'})

mbh_precio4= list()
for i in mbh_pr4:
    mbh_precio4.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mitsubishi/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=NA=="
page = requests.get(URL)
mitsubishi_soup5 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mbh_md5 = mitsubishi_soup5.find_all('h4', class_ = 'bold size-h6 left')
mbh_modelos5 = list()

for i in mbh_md5:
    mbh_modelos5.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mbh_inf5 = mitsubishi_soup5.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mbh_info5= list()

for i in mbh_inf5:
    mbh_info5.append(i.text.strip())
    
# Scrap de precio
mitsubishi_soup5 = BeautifulSoup(page.content, "lxml")
mbh_pr5 = mitsubishi_soup5.find_all('span', {'class' : 'left share-value'})

mbh_precio5= list()
for i in mbh_pr5:
    mbh_precio5.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mitsubishi/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Mw=="
page = requests.get(URL)
mitsubishi_soup6 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mbh_md6 = mitsubishi_soup6.find_all('h4', class_ = 'bold size-h6 left')
mbh_modelos6 = list()

for i in mbh_md6:
    mbh_modelos6.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mbh_inf6 = mitsubishi_soup6.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mbh_info6 = list()

for i in mbh_inf6:
    mbh_info6.append(i.text.strip())
    
# Scrap de precio
mitsubishi_soup6 = BeautifulSoup(page.content, "lxml")
mbh_pr6 = mitsubishi_soup6.find_all('span', {'class' : 'left share-value'})

mbh_precio6 = list()
for i in mbh_pr6:
    mbh_precio6.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mitsubishi/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=NA=="
page = requests.get(URL)
mitsubishi_soup7 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mbh_md7 = mitsubishi_soup7.find_all('h4', class_ = 'bold size-h6 left')
mbh_modelos7 = list()

for i in mbh_md7:
    mbh_modelos7.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mbh_inf7 = mitsubishi_soup7.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mbh_info7 = list()

for i in mbh_inf7:
    mbh_info7.append(i.text.strip())
    
# Scrap de precio
mitsubishi_soup7 = BeautifulSoup(page.content, "lxml")
mbh_pr7 = mitsubishi_soup7.find_all('span', {'class' : 'left share-value'})

mbh_precio7 = list()
for i in mbh_pr7:
    mbh_precio7.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mitsubishi/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=NQ=="
page = requests.get(URL)
mitsubishi_soup8 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mbh_md8 = mitsubishi_soup8.find_all('h4', class_ = 'bold size-h6 left')
mbh_modelos8 = list()

for i in mbh_md8:
    mbh_modelos8.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mbh_inf8 = mitsubishi_soup8.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mbh_info8 = list()

for i in mbh_inf8:
    mbh_info8.append(i.text.strip())
    
# Scrap de precio
mitsubishi_soup8 = BeautifulSoup(page.content, "lxml")
mbh_pr8 = mitsubishi_soup8.find_all('span', {'class' : 'left share-value'})

mbh_precio8 = list()
for i in mbh_pr8:
    mbh_precio8.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mitsubishi/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Ng=="
page = requests.get(URL)
mitsubishi_soup9 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mbh_md9 = mitsubishi_soup9.find_all('h4', class_ = 'bold size-h6 left')
mbh_modelos9 = list()

for i in mbh_md9:
    mbh_modelos9.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mbh_inf9 = mitsubishi_soup9.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mbh_info9 = list()

for i in mbh_inf9:
    mbh_info9.append(i.text.strip())
    
# Scrap de precio
mitsubishi_soup9 = BeautifulSoup(page.content, "lxml")
mbh_pr9 = mitsubishi_soup9.find_all('span', {'class' : 'left share-value'})

mbh_precio9 = list()
for i in mbh_pr9:
    mbh_precio9.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/mitsubishi/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Nw=="
page = requests.get(URL)
mitsubishi_soup10 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
mbh_md10 = mitsubishi_soup10.find_all('h4', class_ = 'bold size-h6 left')
mbh_modelos10 = list()

for i in mbh_md10:
    mbh_modelos10.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
mbh_inf10 = mitsubishi_soup10.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
mbh_info10 = list()

for i in mbh_inf10:
    mbh_info10.append(i.text.strip())
    
# Scrap de precio
mitsubishi_soup10 = BeautifulSoup(page.content, "lxml")
mbh_pr10 = mitsubishi_soup10.find_all('span', {'class' : 'left share-value'})

mbh_precio10 = list()
for i in mbh_pr10:
    mbh_precio10.append(i.text.strip())

# %% [markdown]
# ### Mitsubishi DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(mbh_modelos1, mbh_info1, mbh_precio1))
list_tuples2= list(zip(mbh_modelos2, mbh_info2, mbh_precio2))
list_tuples3= list(zip(mbh_modelos3, mbh_info3, mbh_precio3))
list_tuples4= list(zip(mbh_modelos4, mbh_info4, mbh_precio4))
list_tuples5= list(zip(mbh_modelos5, mbh_info5, mbh_precio5))

# Agrego las tuplas y nombro las columnas
mbh_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
mbh_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
mbh_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
mbh_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])
mbh_df5 = pd.DataFrame(list_tuples5, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
mitsubishi_df = mbh_df1.append([mbh_df2, mbh_df3, mbh_df4, mbh_df5], ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples6= list(zip(mbh_modelos6, mbh_info6, mbh_precio6))
list_tuples7= list(zip(mbh_modelos7, mbh_info7, mbh_precio7))
list_tuples8= list(zip(mbh_modelos8, mbh_info8, mbh_precio8))
list_tuples9= list(zip(mbh_modelos9, mbh_info9, mbh_precio9))
list_tuples10= list(zip(mbh_modelos10, mbh_info10, mbh_precio10))

# Agrego las tuplas y nombro las columnas
mbh_df6 = pd.DataFrame(list_tuples6, columns= ['Modelos', 'Información', 'Precio'])
mbh_df7 = pd.DataFrame(list_tuples7, columns= ['Modelos', 'Información', 'Precio'])
mbh_df8 = pd.DataFrame(list_tuples8, columns= ['Modelos', 'Información', 'Precio'])
mbh_df9 = pd.DataFrame(list_tuples9, columns= ['Modelos', 'Información', 'Precio'])
mbh_df10 = pd.DataFrame(list_tuples10, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
mbh_df11 = mbh_df6.append([mitsubishi_df, mbh_df7, mbh_df8, mbh_df9, mbh_df10], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
mitsubishi_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Mitsubishi Ventas.csv', index = False, header=False)

# %%
mbh_df11.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Mitsubishi3 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Nissan

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/nissan/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
nissan_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
nsn_md1 = nissan_soup1.find_all('h4', class_ = 'bold size-h6 left')
nsn_modelos1 = list()

for i in nsn_md1:
    nsn_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
nsn_inf1 = nissan_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
nsn_info1= list()

for i in nsn_inf1:
    nsn_info1.append(i.text.strip())
    
# Scrap de precio
nissan_soup1 = BeautifulSoup(page.content, "lxml")
nsn_pr1 = nissan_soup1.find_all('span', {'class' : 'left share-value'})

nsn_precio1= list()
for i in nsn_pr1:
    nsn_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/nissan/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
nissan_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
nsn_md2 = nissan_soup2.find_all('h4', class_ = 'bold size-h6 left')
nsn_modelos2 = list()

for i in nsn_md2:
    nsn_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
nsn_inf2 = nissan_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
nsn_info2= list()

for i in nsn_inf2:
    nsn_info2.append(i.text.strip())
    
# Scrap de precio
nissan_soup2 = BeautifulSoup(page.content, "lxml")
nsn_pr2 = nissan_soup2.find_all('span', {'class' : 'left share-value'})

nsn_precio2= list()
for i in nsn_pr2:
    nsn_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/nissan/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mg=="
page = requests.get(URL)
nissan_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
nsn_md3 = nissan_soup3.find_all('h4', class_ = 'bold size-h6 left')
nsn_modelos3 = list()

for i in nsn_md3:
    nsn_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
nsn_inf3 = nissan_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
nsn_info3= list()

for i in nsn_inf3:
    nsn_info3.append(i.text.strip())
    
# Scrap de precio
nissan_soup3 = BeautifulSoup(page.content, "lxml")
nsn_pr3 = nissan_soup3.find_all('span', {'class' : 'left share-value'})

nsn_precio3= list()
for i in nsn_pr3:
    nsn_precio3.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/nissan/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mw=="
page = requests.get(URL)
nissan_soup4 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
nsn_md4 = nissan_soup4.find_all('h4', class_ = 'bold size-h6 left')
nsn_modelos4 = list()

for i in nsn_md4:
    nsn_modelos4.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
nsn_inf4 = nissan_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
nsn_info4 = list()

for i in nsn_inf4:
    nsn_info4.append(i.text.strip())
    
# Scrap de precio
nissan_soup4 = BeautifulSoup(page.content, "lxml")
nsn_pr4 = nissan_soup4.find_all('span', {'class' : 'left share-value'})

nsn_precio4 = list()
for i in nsn_pr4:
    nsn_precio4.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/nissan/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=NA=="
page = requests.get(URL)
nissan_soup5 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
nsn_md5 = nissan_soup5.find_all('h4', class_ = 'bold size-h6 left')
nsn_modelos5 = list()

for i in nsn_md5:
    nsn_modelos5.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
nsn_inf5 = nissan_soup5.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
nsn_info5 = list()

for i in nsn_inf5:
    nsn_info5.append(i.text.strip())
    
# Scrap de precio
nissan_soup5 = BeautifulSoup(page.content, "lxml")
nsn_pr5 = nissan_soup5.find_all('span', {'class' : 'left share-value'})

nsn_precio5 = list()
for i in nsn_pr5:
    nsn_precio5.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/nissan/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=NQ=="
page = requests.get(URL)
nissan_soup6 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
nsn_md6 = nissan_soup6.find_all('h4', class_ = 'bold size-h6 left')
nsn_modelos6 = list()

for i in nsn_md6:
    nsn_modelos6.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
nsn_inf6 = nissan_soup6.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
nsn_info6 = list()

for i in nsn_inf6:
    nsn_info6.append(i.text.strip())
    
# Scrap de precio
nissan_soup6 = BeautifulSoup(page.content, "lxml")
nsn_pr6 = nissan_soup6.find_all('span', {'class' : 'left share-value'})

nsn_precio6 = list()
for i in nsn_pr6:
    nsn_precio6.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/nissan/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Ng=="
page = requests.get(URL)
nissan_soup7 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
nsn_md7 = nissan_soup7.find_all('h4', class_ = 'bold size-h6 left')
nsn_modelos7 = list()

for i in nsn_md7:
    nsn_modelos7.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
nsn_inf7 = nissan_soup7.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
nsn_info7 = list()

for i in nsn_inf7:
    nsn_info7.append(i.text.strip())
    
# Scrap de precio
nissan_soup7 = BeautifulSoup(page.content, "lxml")
nsn_pr7 = nissan_soup7.find_all('span', {'class' : 'left share-value'})

nsn_precio7 = list()
for i in nsn_pr7:
    nsn_precio7.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/nissan/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Nw=="
page = requests.get(URL)
nissan_soup8 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
nsn_md8 = nissan_soup8.find_all('h4', class_ = 'bold size-h6 left')
nsn_modelos8 = list()

for i in nsn_md8:
    nsn_modelos8.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
nsn_inf8 = nissan_soup8.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
nsn_info8 = list()

for i in nsn_inf8:
    nsn_info8.append(i.text.strip())
    
# Scrap de precio
nissan_soup8 = BeautifulSoup(page.content, "lxml")
nsn_pr8 = nissan_soup8.find_all('span', {'class' : 'left share-value'})

nsn_precio8 = list()
for i in nsn_pr8:
    nsn_precio8.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/nissan/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=OA=="
page = requests.get(URL)
nissan_soup9 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
nsn_md9 = nissan_soup9.find_all('h4', class_ = 'bold size-h6 left')
nsn_modelos9 = list()

for i in nsn_md9:
    nsn_modelos9.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
nsn_inf9 = nissan_soup9.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
nsn_info9 = list()

for i in nsn_inf9:
    nsn_info9.append(i.text.strip())
    
# Scrap de precio
nissan_soup9 = BeautifulSoup(page.content, "lxml")
nsn_pr9 = nissan_soup9.find_all('span', {'class' : 'left share-value'})

nsn_precio9 = list()
for i in nsn_pr9:
    nsn_precio9.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/nissan/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=OQ=="
page = requests.get(URL)
nissan_soup10 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
nsn_md10 = nissan_soup10.find_all('h4', class_ = 'bold size-h6 left')
nsn_modelos10 = list()

for i in nsn_md10:
    nsn_modelos10.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
nsn_inf10 = nissan_soup10.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
nsn_info10 = list()

for i in nsn_inf10:
    nsn_info10.append(i.text.strip())
    
# Scrap de precio
nissan_soup10 = BeautifulSoup(page.content, "lxml")
nsn_pr10 = nissan_soup10.find_all('span', {'class' : 'left share-value'})

nsn_precio10 = list()
for i in nsn_pr10:
    nsn_precio10.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/nissan/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MTA="
page = requests.get(URL)
nissan_soup11 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
nsn_md11 = nissan_soup11.find_all('h4', class_ = 'bold size-h6 left')
nsn_modelos11 = list()

for i in nsn_md11:
    nsn_modelos11.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
nsn_inf11 = nissan_soup11.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
nsn_info11 = list()

for i in nsn_inf11:
    nsn_info11.append(i.text.strip())
    
# Scrap de precio
nissan_soup11 = BeautifulSoup(page.content, "lxml")
nsn_pr11 = nissan_soup11.find_all('span', {'class' : 'left share-value'})

nsn_precio11 = list()
for i in nsn_pr11:
    nsn_precio11.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/nissan/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MTE="
page = requests.get(URL)
nissan_soup12 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
nsn_md12 = nissan_soup12.find_all('h4', class_ = 'bold size-h6 left')
nsn_modelos12 = list()

for i in nsn_md12:
    nsn_modelos12.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
nsn_inf12 = nissan_soup12.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
nsn_info12 = list()

for i in nsn_inf12:
    nsn_info12.append(i.text.strip())
    
# Scrap de precio
nissan_soup12 = BeautifulSoup(page.content, "lxml")
nsn_pr12 = nissan_soup12.find_all('span', {'class' : 'left share-value'})

nsn_precio12 = list()
for i in nsn_pr12:
    nsn_precio12.append(i.text.strip())

# %% [markdown]
# ### Nissan DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(nsn_modelos1, nsn_info1, nsn_precio1))
list_tuples2= list(zip(nsn_modelos2, nsn_info2, nsn_precio2))
list_tuples3= list(zip(nsn_modelos3, nsn_info3, nsn_precio3))
list_tuples4= list(zip(nsn_modelos4, nsn_info4, nsn_precio4))
list_tuples5= list(zip(nsn_modelos5, nsn_info5, nsn_precio5))

# Agrego las tuplas y nombro las columnas
nsn_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
nsn_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
nsn_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
nsn_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])
nsn_df5 = pd.DataFrame(list_tuples5, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
nissan_df = nsn_df1.append([nsn_df2, nsn_df3, nsn_df4, nsn_df5], ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples6= list(zip(nsn_modelos6, nsn_info6, nsn_precio6))
list_tuples7= list(zip(nsn_modelos7, nsn_info7, nsn_precio7))
list_tuples8= list(zip(nsn_modelos8, nsn_info8, nsn_precio8))
list_tuples9= list(zip(nsn_modelos9, nsn_info9, nsn_precio9))
list_tuples10= list(zip(nsn_modelos10, nsn_info10, nsn_precio10))
list_tuples11= list(zip(nsn_modelos11, nsn_info11, nsn_precio11))
list_tuples12= list(zip(nsn_modelos12, nsn_info12, nsn_precio12))

# Agrego las tuplas y nombro las columnas
nsn_df6 = pd.DataFrame(list_tuples6, columns= ['Modelos', 'Información', 'Precio'])
nsn_df7 = pd.DataFrame(list_tuples7, columns= ['Modelos', 'Información', 'Precio'])
nsn_df8 = pd.DataFrame(list_tuples8, columns= ['Modelos', 'Información', 'Precio'])
nsn_df9 = pd.DataFrame(list_tuples9, columns= ['Modelos', 'Información', 'Precio'])
nsn_df10 = pd.DataFrame(list_tuples10, columns= ['Modelos', 'Información', 'Precio'])
nsn_df11 = pd.DataFrame(list_tuples11, columns= ['Modelos', 'Información', 'Precio'])
nsn_df12 = pd.DataFrame(list_tuples12, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
nsn_df13 = nsn_df6.append([nissan_df, nsn_df7, nsn_df8, nsn_df9, nsn_df10, nsn_df11, nsn_df12], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
nissan_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Nissan Ventas.csv', index = False, header=False)

# %%
nsn_df13.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\Webscrapping\Nissan4 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Peugot

# %% [markdown]
# ### Peugot Ventas

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/peugeot/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
peugot_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
pgt_md1 = peugot_soup1.find_all('h4', class_ = 'bold size-h6 left')
pgt_modelos1 = list()

for i in pgt_md1:
    pgt_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
pgt_inf1 = peugot_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
pgt_info1= list()

for i in pgt_inf1:
    pgt_info1.append(i.text.strip())
    
# Scrap de precio
peugot_soup1 = BeautifulSoup(page.content, "lxml")
pgt_pr1 = peugot_soup1.find_all('span', {'class' : 'left share-value'})

pgt_precio1= list()
for i in pgt_pr1:
    pgt_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/peugeot/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
peugot_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
pgt_md2 = peugot_soup2.find_all('h4', class_ = 'bold size-h6 left')
pgt_modelos2 = list()

for i in pgt_md2:
    pgt_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
pgt_inf2 = peugot_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
pgt_info2= list()

for i in pgt_inf2:
    pgt_info2.append(i.text.strip())
    
# Scrap de precio
peugot_soup2 = BeautifulSoup(page.content, "lxml")
pgt_pr2 = peugot_soup2.find_all('span', {'class' : 'left share-value'})

pgt_precio2 = list()
for i in pgt_pr2:
    pgt_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/peugeot/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mg=="
page = requests.get(URL)
peugot_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
pgt_md3 = peugot_soup3.find_all('h4', class_ = 'bold size-h6 left')
pgt_modelos3 = list()

for i in pgt_md3:
    pgt_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
pgt_inf3 = peugot_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
pgt_info3= list()

for i in pgt_inf3:
    pgt_info3.append(i.text.strip())
    
# Scrap de precio
peugot_soup3 = BeautifulSoup(page.content, "lxml")
pgt_pr3 = peugot_soup3.find_all('span', {'class' : 'left share-value'})

pgt_precio3 = list()
for i in pgt_pr3:
    pgt_precio3.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/peugeot/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
peugot_soup4 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
pgt_md4 = peugot_soup4.find_all('h4', class_ = 'bold size-h6 left')
pgt_modelos4 = list()

for i in pgt_md4:
    pgt_modelos4.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
pgt_inf4 = peugot_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
pgt_info4 = list()

for i in pgt_inf4:
    pgt_info4.append(i.text.strip())
    
# Scrap de precio
peugot_soup4 = BeautifulSoup(page.content, "lxml")
pgt_pr4 = peugot_soup4.find_all('span', {'class' : 'left share-value'})

pgt_precio4 = list()
for i in pgt_pr4:
    pgt_precio4.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/peugeot/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MQ=="
page = requests.get(URL)
peugot_soup5 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
pgt_md5 = peugot_soup5.find_all('h4', class_ = 'bold size-h6 left')
pgt_modelos5 = list()

for i in pgt_md5:
    pgt_modelos5.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
pgt_inf5 = peugot_soup5.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
pgt_info5 = list()

for i in pgt_inf5:
    pgt_info5.append(i.text.strip())
    
# Scrap de precio
peugot_soup5 = BeautifulSoup(page.content, "lxml")
pgt_pr5 = peugot_soup5.find_all('span', {'class' : 'left share-value'})

pgt_precio5 = list()
for i in pgt_pr5:
    pgt_precio5.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/peugeot/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Mg=="
page = requests.get(URL)
peugot_soup6 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
pgt_md6 = peugot_soup6.find_all('h4', class_ = 'bold size-h6 left')
pgt_modelos6 = list()

for i in pgt_md6:
    pgt_modelos6.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
pgt_inf6 = peugot_soup6.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
pgt_info6 = list()

for i in pgt_inf6:
    pgt_info6.append(i.text.strip())
    
# Scrap de precio
peugot_soup6 = BeautifulSoup(page.content, "lxml")
pgt_pr6 = peugot_soup6.find_all('span', {'class' : 'left share-value'})

pgt_precio6 = list()
for i in pgt_pr6:
    pgt_precio6.append(i.text.strip())

# %% [markdown]
# ### Peugot DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(pgt_modelos1, pgt_info1, pgt_precio1))
list_tuples2= list(zip(pgt_modelos2, pgt_info2, pgt_precio2))
list_tuples3= list(zip(pgt_modelos3, pgt_info3, pgt_precio3))

# Agrego las tuplas y nombro las columnas
pgt_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
pgt_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
pgt_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
peugot_df = pgt_df1.append([pgt_df2, pgt_df3], ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples4= list(zip(pgt_modelos4, pgt_info4, pgt_precio4))
list_tuples5= list(zip(pgt_modelos5, pgt_info5, pgt_precio5))
list_tuples6= list(zip(pgt_modelos6, pgt_info6, pgt_precio6))

# Agrego las tuplas y nombro las columnas
pgt_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])
pgt_df5 = pd.DataFrame(list_tuples5, columns= ['Modelos', 'Información', 'Precio'])
pgt_df6 = pd.DataFrame(list_tuples6, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
peugot_df7 = pgt_df4.append([peugot_df, pgt_df5, pgt_df6], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
peugot_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Peugot Ventas.csv', index = False, header=False)

# %%
peugot_df7.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Peugot3 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Porsche

# %% [markdown]
# ### Ventas Porsche

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/porsche/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
porsche_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
pch_md1 = porsche_soup1.find_all('h4', class_ = 'bold size-h6 left')
pch_modelos1 = list()

for i in pch_md1:
    pch_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
pch_inf1 = porsche_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
pch_info1= list()

for i in pch_inf1:
    pch_info1.append(i.text.strip())
    
# Scrap de precio
porsche_soup1 = BeautifulSoup(page.content, "lxml")
pch_pr1 = porsche_soup1.find_all('span', {'class' : 'left share-value'})

pch_precio1= list()
for i in pch_pr1:
    pch_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/porsche/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
porsche_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
pch_md2 = porsche_soup2.find_all('h4', class_ = 'bold size-h6 left')
pch_modelos2 = list()

for i in pch_md2:
    pch_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
pch_inf2 = porsche_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
pch_info2= list()

for i in pch_inf2:
    pch_info2.append(i.text.strip())
    
# Scrap de precio
porsche_soup2 = BeautifulSoup(page.content, "lxml")
pch_pr2 = porsche_soup2.find_all('span', {'class' : 'left share-value'})

pch_precio2= list()
for i in pch_pr2:
    pch_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/porsche/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
porsche_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
pch_md3 = porsche_soup3.find_all('h4', class_ = 'bold size-h6 left')
pch_modelos3 = list()

for i in pch_md3:
    pch_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
pch_inf3 = porsche_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
pch_info3 = list()

for i in pch_inf3:
    pch_info3.append(i.text.strip())
    
# Scrap de precio
porsche_soup3 = BeautifulSoup(page.content, "lxml")
pch_pr3 = porsche_soup3.find_all('span', {'class' : 'left share-value'})

pch_precio3 = list()
for i in pch_pr3:
    pch_precio3.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/porsche/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MQ=="
page = requests.get(URL)
porsche_soup4 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
pch_md4 = porsche_soup4.find_all('h4', class_ = 'bold size-h6 left')
pch_modelos4 = list()

for i in pch_md4:
    pch_modelos4.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
pch_inf4 = porsche_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
pch_info4 = list()

for i in pch_inf4:
    pch_info4.append(i.text.strip())
    
# Scrap de precio
porsche_soup4 = BeautifulSoup(page.content, "lxml")
pch_pr4 = porsche_soup4.find_all('span', {'class' : 'left share-value'})

pch_precio4 = list()
for i in pch_pr4:
    pch_precio4.append(i.text.strip())

# %% [markdown]
# ### Porsche DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(pch_modelos1, pch_info1, pch_precio1))
list_tuples2= list(zip(pch_modelos2, pch_info2, pch_precio2))

# Agrego las tuplas y nombro las columnas
pch_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
pch_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
porsche_df = pch_df1.append([pch_df2], ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples3= list(zip(pch_modelos3, pch_info3, pch_precio3))
list_tuples4= list(zip(pch_modelos4, pch_info4, pch_precio4))

# Agrego las tuplas y nombro las columnas
pch_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
pch_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
porsche_df2 = pch_df3.append([porsche_df, pch_df4], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
porsche_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Porsche Ventas.csv', index = False, header=False)

# %%
porsche_df2.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Porsche3 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Renault

# %% [markdown]
# ### Renault Ventas

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/renault/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
renault_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
rlt_md1 = renault_soup1.find_all('h4', class_ = 'bold size-h6 left')
rlt_modelos1 = list()

for i in rlt_md1:
    rlt_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
rlt_inf1 = renault_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
rlt_info1= list()

for i in rlt_inf1:
    rlt_info1.append(i.text.strip())
    
# Scrap de precio
renault_soup1 = BeautifulSoup(page.content, "lxml")
rlt_pr1 = renault_soup1.find_all('span', {'class' : 'left share-value'})

rlt_precio1= list()
for i in rlt_pr1:
    rlt_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/renault/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
renault_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
rlt_md2 = renault_soup2.find_all('h4', class_ = 'bold size-h6 left')
rlt_modelos2 = list()

for i in rlt_md2:
    rlt_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
rlt_inf2 = renault_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
rlt_info2 = list()

for i in rlt_inf2:
    rlt_info2.append(i.text.strip())
    
# Scrap de precio
renault_soup2 = BeautifulSoup(page.content, "lxml")
rlt_pr2 = renault_soup2.find_all('span', {'class' : 'left share-value'})

rlt_precio2= list()
for i in rlt_pr2:
    rlt_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/renault/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mg=="
page = requests.get(URL)
renault_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
rlt_md3 = renault_soup3.find_all('h4', class_ = 'bold size-h6 left')
rlt_modelos3 = list()

for i in rlt_md3:
    rlt_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
rlt_inf3 = renault_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
rlt_info3 = list()

for i in rlt_inf3:
    rlt_info3.append(i.text.strip())
    
# Scrap de precio
renault_soup3 = BeautifulSoup(page.content, "lxml")
rlt_pr3 = renault_soup3.find_all('span', {'class' : 'left share-value'})

rlt_precio3= list()
for i in rlt_pr3:
    rlt_precio3.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/renault/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mw=="
page = requests.get(URL)
renault_soup4 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
rlt_md4 = renault_soup4.find_all('h4', class_ = 'bold size-h6 left')
rlt_modelos4 = list()

for i in rlt_md4:
    rlt_modelos4.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
rlt_inf4 = renault_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
rlt_info4 = list()

for i in rlt_inf4:
    rlt_info4.append(i.text.strip())
    
# Scrap de precio
renault_soup4 = BeautifulSoup(page.content, "lxml")
rlt_pr4 = renault_soup4.find_all('span', {'class' : 'left share-value'})

rlt_precio4= list()
for i in rlt_pr4:
    rlt_precio4.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/renault/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=NA=="
page = requests.get(URL)
renault_soup5 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
rlt_md5 = renault_soup5.find_all('h4', class_ = 'bold size-h6 left')
rlt_modelos5 = list()

for i in rlt_md5:
    rlt_modelos5.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
rlt_inf5 = renault_soup5.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
rlt_info5 = list()

for i in rlt_inf5:
    rlt_info5.append(i.text.strip())
    
# Scrap de precio
renault_soup5 = BeautifulSoup(page.content, "lxml")
rlt_pr5 = renault_soup5.find_all('span', {'class' : 'left share-value'})

rlt_precio5= list()
for i in rlt_pr5:
    rlt_precio5.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/renault/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=NA=="
page = requests.get(URL)
renault_soup6 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
rlt_md6 = renault_soup6.find_all('h4', class_ = 'bold size-h6 left')
rlt_modelos6 = list()

for i in rlt_md6:
    rlt_modelos6.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
rlt_inf6 = renault_soup6.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
rlt_info6 = list()

for i in rlt_inf6:
    rlt_info6.append(i.text.strip())
    
# Scrap de precio
renault_soup6 = BeautifulSoup(page.content, "lxml")
rlt_pr6 = renault_soup6.find_all('span', {'class' : 'left share-value'})

rlt_precio6 = list()
for i in rlt_pr6:
    rlt_precio6.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/renault/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Ng=="
page = requests.get(URL)
renault_soup7 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
rlt_md7 = renault_soup7.find_all('h4', class_ = 'bold size-h6 left')
rlt_modelos7 = list()

for i in rlt_md7:
    rlt_modelos7.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
rlt_inf7 = renault_soup7.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
rlt_info7 = list()

for i in rlt_inf7:
    rlt_info7.append(i.text.strip())
    
# Scrap de precio
renault_soup7 = BeautifulSoup(page.content, "lxml")
rlt_pr7 = renault_soup7.find_all('span', {'class' : 'left share-value'})

rlt_precio7 = list()
for i in rlt_pr7:
    rlt_precio7.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/renault/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Nw=="
page = requests.get(URL)
renault_soup8 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
rlt_md8 = renault_soup8.find_all('h4', class_ = 'bold size-h6 left')
rlt_modelos8 = list()

for i in rlt_md8:
    rlt_modelos8.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
rlt_inf8 = renault_soup8.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
rlt_info8 = list()

for i in rlt_inf8:
    rlt_info8.append(i.text.strip())
    
# Scrap de precio
renault_soup8 = BeautifulSoup(page.content, "lxml")
rlt_pr8 = renault_soup8.find_all('span', {'class' : 'left share-value'})

rlt_precio8 = list()
for i in rlt_pr8:
    rlt_precio8.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/renault/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=OA=="
page = requests.get(URL)
renault_soup9 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
rlt_md9 = renault_soup9.find_all('h4', class_ = 'bold size-h6 left')
rlt_modelos9 = list()

for i in rlt_md9:
    rlt_modelos9.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
rlt_inf9 = renault_soup9.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
rlt_info9 = list()

for i in rlt_inf9:
    rlt_info9.append(i.text.strip())
    
# Scrap de precio
renault_soup9 = BeautifulSoup(page.content, "lxml")
rlt_pr9 = renault_soup9.find_all('span', {'class' : 'left share-value'})

rlt_precio9 = list()
for i in rlt_pr9:
    rlt_precio9.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/renault/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=OQ=="
page = requests.get(URL)
renault_soup10 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
rlt_md10 = renault_soup10.find_all('h4', class_ = 'bold size-h6 left')
rlt_modelos10 = list()

for i in rlt_md10:
    rlt_modelos10.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
rlt_inf10 = renault_soup10.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
rlt_info10 = list()

for i in rlt_inf10:
    rlt_info10.append(i.text.strip())
    
# Scrap de precio
renault_soup10 = BeautifulSoup(page.content, "lxml")
rlt_pr10 = renault_soup10.find_all('span', {'class' : 'left share-value'})

rlt_precio10 = list()
for i in rlt_pr10:
    rlt_precio10.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/renault/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MTA="
page = requests.get(URL)
renault_soup11 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
rlt_md11 = renault_soup11.find_all('h4', class_ = 'bold size-h6 left')
rlt_modelos11 = list()

for i in rlt_md11:
    rlt_modelos11.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
rlt_inf11 = renault_soup11.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
rlt_info11 = list()

for i in rlt_inf11:
    rlt_info11.append(i.text.strip())
    
# Scrap de precio
renault_soup11 = BeautifulSoup(page.content, "lxml")
rlt_pr11 = renault_soup11.find_all('span', {'class' : 'left share-value'})

rlt_precio11 = list()
for i in rlt_pr11:
    rlt_precio11.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/renault/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MTE="
page = requests.get(URL)
renault_soup12 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
rlt_md12 = renault_soup12.find_all('h4', class_ = 'bold size-h6 left')
rlt_modelos12 = list()

for i in rlt_md12:
    rlt_modelos12.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
rlt_inf12 = renault_soup12.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
rlt_info12 = list()

for i in rlt_inf12:
    rlt_info12.append(i.text.strip())
    
# Scrap de precio
renault_soup12 = BeautifulSoup(page.content, "lxml")
rlt_pr12 = renault_soup12.find_all('span', {'class' : 'left share-value'})

rlt_precio12 = list()
for i in rlt_pr12:
    rlt_precio12.append(i.text.strip())

# %% [markdown]
# ### Renault DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(rlt_modelos1, rlt_info1, rlt_precio1))
list_tuples2= list(zip(rlt_modelos2, rlt_info2, rlt_precio2))
list_tuples3= list(zip(rlt_modelos3, rlt_info3, rlt_precio3))
list_tuples4= list(zip(rlt_modelos4, rlt_info4, rlt_precio4))
list_tuples5= list(zip(rlt_modelos5, rlt_info5, rlt_precio5))

# Agrego las tuplas y nombro las columnas
rlt_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
rlt_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
rlt_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
rlt_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])
rlt_df5 = pd.DataFrame(list_tuples5, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
renault_df = rlt_df1.append([rlt_df2, rlt_df3, rlt_df4, rlt_df5], ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples6= list(zip(rlt_modelos6, rlt_info6, rlt_precio6))
list_tuples7= list(zip(rlt_modelos7, rlt_info7, rlt_precio7))
list_tuples8= list(zip(rlt_modelos8, rlt_info8, rlt_precio8))
list_tuples9= list(zip(rlt_modelos9, rlt_info9, rlt_precio9))
list_tuples10= list(zip(rlt_modelos10, rlt_info10, rlt_precio10))
list_tuples11= list(zip(rlt_modelos11, rlt_info11, rlt_precio11))
list_tuples12= list(zip(rlt_modelos12, rlt_info12, rlt_precio12))

# Agrego las tuplas y nombro las columnas
rlt_df6 = pd.DataFrame(list_tuples6, columns= ['Modelos', 'Información', 'Precio'])
rlt_df7 = pd.DataFrame(list_tuples7, columns= ['Modelos', 'Información', 'Precio'])
rlt_df8 = pd.DataFrame(list_tuples8, columns= ['Modelos', 'Información', 'Precio'])
rlt_df9 = pd.DataFrame(list_tuples9, columns= ['Modelos', 'Información', 'Precio'])
rlt_df10 = pd.DataFrame(list_tuples10, columns= ['Modelos', 'Información', 'Precio'])
rlt_df11 = pd.DataFrame(list_tuples11, columns= ['Modelos', 'Información', 'Precio'])
rlt_df12 = pd.DataFrame(list_tuples12, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
rlt_df2 = rlt_df6.append([renault_df, rlt_df7, rlt_df8, rlt_df9, rlt_df10, rlt_df11, rlt_df12], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
renault_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Renault Ventas.csv', index = False, header=False)

# %%
rlt_df2.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Renault3 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Seat

# %% [markdown]
# ### Seat Ventas

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/seat/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
seat_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
sat_md1 = seat_soup1.find_all('h4', class_ = 'bold size-h6 left')
sat_modelos1 = list()

for i in sat_md1:
    sat_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
sat_inf1 = seat_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
sat_info1= list()

for i in sat_inf1:
    sat_info1.append(i.text.strip())
    
# Scrap de precio
seat_soup1 = BeautifulSoup(page.content, "lxml")
sat_pr1 = seat_soup1.find_all('span', {'class' : 'left share-value'})

sat_precio1= list()
for i in sat_pr1:
    sat_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/seat/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
seat_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
sat_md2 = seat_soup2.find_all('h4', class_ = 'bold size-h6 left')
sat_modelos2 = list()

for i in sat_md2:
    sat_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
sat_inf2 = seat_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
sat_info2 = list()

for i in sat_inf2:
    sat_info2.append(i.text.strip())
    
# Scrap de precio
seat_soup2 = BeautifulSoup(page.content, "lxml")
sat_pr2 = seat_soup2.find_all('span', {'class' : 'left share-value'})

sat_precio2= list()
for i in sat_pr2:
    sat_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/seat/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mg=="
page = requests.get(URL)
seat_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
sat_md3 = seat_soup3.find_all('h4', class_ = 'bold size-h6 left')
sat_modelos3 = list()

for i in sat_md3:
    sat_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
sat_inf3 = seat_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
sat_info3 = list()

for i in sat_inf3:
    sat_info3.append(i.text.strip())
    
# Scrap de precio
seat_soup3 = BeautifulSoup(page.content, "lxml")
sat_pr3 = seat_soup3.find_all('span', {'class' : 'left share-value'})

sat_precio3= list()
for i in sat_pr3:
    sat_precio3.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/seat/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mw=="
page = requests.get(URL)
seat_soup4 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
sat_md4 = seat_soup4.find_all('h4', class_ = 'bold size-h6 left')
sat_modelos4 = list()

for i in sat_md4:
    sat_modelos4.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
sat_inf4 = seat_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
sat_info4 = list()

for i in sat_inf4:
    sat_info4.append(i.text.strip())
    
# Scrap de precio
seat_soup4 = BeautifulSoup(page.content, "lxml")
sat_pr4 = seat_soup4.find_all('span', {'class' : 'left share-value'})

sat_precio4= list()
for i in sat_pr4:
    sat_precio4.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/seat/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=NA=="
page = requests.get(URL)
seat_soup5 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
sat_md5 = seat_soup5.find_all('h4', class_ = 'bold size-h6 left')
sat_modelos5 = list()

for i in sat_md5:
    sat_modelos5.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
sat_inf5 = seat_soup5.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
sat_info5 = list()

for i in sat_inf5:
    sat_info5.append(i.text.strip())
    
# Scrap de precio
seat_soup5 = BeautifulSoup(page.content, "lxml")
sat_pr5 = seat_soup5.find_all('span', {'class' : 'left share-value'})

sat_precio5= list()
for i in sat_pr5:
    sat_precio5.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/seat/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=NQ=="
page = requests.get(URL)
seat_soup6 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
sat_md6 = seat_soup6.find_all('h4', class_ = 'bold size-h6 left')
sat_modelos6 = list()

for i in sat_md6:
    sat_modelos6.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
sat_inf6 = seat_soup6.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
sat_info6 = list()

for i in sat_inf6:
    sat_info6.append(i.text.strip())
    
# Scrap de precio
seat_soup6 = BeautifulSoup(page.content, "lxml")
sat_pr6 = seat_soup6.find_all('span', {'class' : 'left share-value'})

sat_precio6 = list()
for i in sat_pr6:
    sat_precio6.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/seat/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Ng=="
page = requests.get(URL)
seat_soup7 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
sat_md7 = seat_soup7.find_all('h4', class_ = 'bold size-h6 left')
sat_modelos7 = list()

for i in sat_md7:
    sat_modelos7.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
sat_inf7 = seat_soup7.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
sat_info7 = list()

for i in sat_inf7:
    sat_info7.append(i.text.strip())
    
# Scrap de precio
seat_soup7 = BeautifulSoup(page.content, "lxml")
sat_pr7 = seat_soup7.find_all('span', {'class' : 'left share-value'})

sat_precio7 = list()
for i in sat_pr7:
    sat_precio7.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/seat/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Nw=="
page = requests.get(URL)
seat_soup8 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
sat_md8 = seat_soup8.find_all('h4', class_ = 'bold size-h6 left')
sat_modelos8 = list()

for i in sat_md8:
    sat_modelos8.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
sat_inf8 = seat_soup8.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
sat_info8 = list()

for i in sat_inf8:
    sat_info8.append(i.text.strip())
    
# Scrap de precio
seat_soup8 = BeautifulSoup(page.content, "lxml")
sat_pr8 = seat_soup8.find_all('span', {'class' : 'left share-value'})

sat_precio8 = list()
for i in sat_pr8:
    sat_precio8.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/seat/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=OA=="
page = requests.get(URL)
seat_soup9 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
sat_md9 = seat_soup9.find_all('h4', class_ = 'bold size-h6 left')
sat_modelos9 = list()

for i in sat_md9:
    sat_modelos9.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
sat_inf9 = seat_soup9.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
sat_info9 = list()

for i in sat_inf9:
    sat_info9.append(i.text.strip())
    
# Scrap de precio
seat_soup9 = BeautifulSoup(page.content, "lxml")
sat_pr9 = seat_soup9.find_all('span', {'class' : 'left share-value'})

sat_precio9 = list()
for i in sat_pr9:
    sat_precio9.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/seat/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=OQ=="
page = requests.get(URL)
seat_soup10 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
sat_md10 = seat_soup10.find_all('h4', class_ = 'bold size-h6 left')
sat_modelos10 = list()

for i in sat_md10:
    sat_modelos10.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
sat_inf10 = seat_soup10.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
sat_info10 = list()

for i in sat_inf10:
    sat_info10.append(i.text.strip())
    
# Scrap de precio
seat_soup10 = BeautifulSoup(page.content, "lxml")
sat_pr10 = seat_soup10.find_all('span', {'class' : 'left share-value'})

sat_precio10 = list()
for i in sat_pr10:
    sat_precio10.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/seat/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MTA="
page = requests.get(URL)
seat_soup11 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
sat_md11 = seat_soup11.find_all('h4', class_ = 'bold size-h6 left')
sat_modelos11 = list()

for i in sat_md11:
    sat_modelos11.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
sat_inf11 = seat_soup11.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
sat_info11 = list()

for i in sat_inf11:
    sat_info11.append(i.text.strip())
    
# Scrap de precio
seat_soup11 = BeautifulSoup(page.content, "lxml")
sat_pr11 = seat_soup11.find_all('span', {'class' : 'left share-value'})

sat_precio11 = list()
for i in sat_pr11:
    sat_precio11.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/seat/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MTE="
page = requests.get(URL)
seat_soup12 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
sat_md12 = seat_soup12.find_all('h4', class_ = 'bold size-h6 left')
sat_modelos12 = list()

for i in sat_md12:
    sat_modelos12.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
sat_inf12 = seat_soup12.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
sat_info12 = list()

for i in sat_inf12:
    sat_info12.append(i.text.strip())
    
# Scrap de precio
seat_soup12 = BeautifulSoup(page.content, "lxml")
sat_pr12 = seat_soup12.find_all('span', {'class' : 'left share-value'})

sat_precio12 = list()
for i in sat_pr12:
    sat_precio12.append(i.text.strip())

# %% [markdown]
# ### Seat DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(sat_modelos1, sat_info1, sat_precio1))
list_tuples2= list(zip(sat_modelos2, sat_info2, sat_precio2))
list_tuples3= list(zip(sat_modelos3, sat_info3, sat_precio3))
list_tuples4= list(zip(sat_modelos4, sat_info4, sat_precio4))
list_tuples5= list(zip(sat_modelos5, sat_info5, sat_precio5))

# Agrego las tuplas y nombro las columnas
sat_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
sat_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
sat_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
sat_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])
sat_df5 = pd.DataFrame(list_tuples5, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
seat_df = sat_df1.append([sat_df2, sat_df3, sat_df4, sat_df5], ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples6= list(zip(sat_modelos6, sat_info6, sat_precio6))
list_tuples7= list(zip(sat_modelos7, sat_info7, sat_precio7))
list_tuples8= list(zip(sat_modelos8, sat_info8, sat_precio8))
list_tuples9= list(zip(sat_modelos9, sat_info9, sat_precio9))
list_tuples10= list(zip(sat_modelos10, sat_info10, sat_precio10))
list_tuples11= list(zip(sat_modelos11, sat_info11, sat_precio11))
list_tuples12= list(zip(sat_modelos12, sat_info12, sat_precio12))

# Agrego las tuplas y nombro las columnas
sat_df6 = pd.DataFrame(list_tuples6, columns= ['Modelos', 'Información', 'Precio'])
sat_df7 = pd.DataFrame(list_tuples7, columns= ['Modelos', 'Información', 'Precio'])
sat_df8 = pd.DataFrame(list_tuples8, columns= ['Modelos', 'Información', 'Precio'])
sat_df9 = pd.DataFrame(list_tuples9, columns= ['Modelos', 'Información', 'Precio'])
sat_df10 = pd.DataFrame(list_tuples10, columns= ['Modelos', 'Información', 'Precio'])
sat_df11 = pd.DataFrame(list_tuples11, columns= ['Modelos', 'Información', 'Precio'])
sat_df12 = pd.DataFrame(list_tuples12, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
sat_df13 = sat_df6.append([seat_df, sat_df7, sat_df8, sat_df9, sat_df10, sat_df11, sat_df12], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
seat_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Seat Ventas.csv', index = False, header=False)

# %%
sat_df13.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Seat3 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Smart

# %% [markdown]
# ### Smart Ventas

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/smart/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
smart_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
srt_md1 = smart_soup1.find_all('h4', class_ = 'bold size-h6 left')
srt_modelos1 = list()

for i in srt_md1:
    srt_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
srt_inf1 = smart_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
srt_info1= list()

for i in srt_inf1:
    srt_info1.append(i.text.strip())
    
# Scrap de precio
smart_soup1 = BeautifulSoup(page.content, "lxml")
srt_pr1 = smart_soup1.find_all('span', {'class' : 'left share-value'})

srt_precio1= list()
for i in srt_pr1:
    srt_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/smart/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
smart_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
srt_md2 = smart_soup2.find_all('h4', class_ = 'bold size-h6 left')
srt_modelos2 = list()

for i in srt_md2:
    srt_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
srt_inf2 = smart_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
srt_info2= list()

for i in srt_inf2:
    srt_info2.append(i.text.strip())
    
# Scrap de precio
smart_soup2 = BeautifulSoup(page.content, "lxml")
srt_pr2 = smart_soup2.find_all('span', {'class' : 'left share-value'})

srt_precio2= list()
for i in srt_pr2:
    srt_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/smart/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
smart_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
srt_md3 = smart_soup3.find_all('h4', class_ = 'bold size-h6 left')
srt_modelos3 = list()

for i in srt_md3:
    srt_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
srt_inf3 = smart_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
srt_info3 = list()

for i in srt_inf3:
    srt_info3.append(i.text.strip())
    
# Scrap de precio
smart_soup3 = BeautifulSoup(page.content, "lxml")
srt_pr3 = smart_soup3.find_all('span', {'class' : 'left share-value'})

srt_precio3 = list()
for i in srt_pr3:
    srt_precio3.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/smart/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MQ=="
page = requests.get(URL)
smart_soup4 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
srt_md4 = smart_soup4.find_all('h4', class_ = 'bold size-h6 left')
srt_modelos4 = list()

for i in srt_md4:
    srt_modelos4.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
srt_inf4 = smart_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
srt_info4 = list()

for i in srt_inf4:
    srt_info4.append(i.text.strip())
    
# Scrap de precio
smart_soup4 = BeautifulSoup(page.content, "lxml")
srt_pr4 = smart_soup4.find_all('span', {'class' : 'left share-value'})

srt_precio4 = list()
for i in srt_pr4:
    srt_precio4.append(i.text.strip())

# %% [markdown]
# ### Smart DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(srt_modelos1, srt_info1, srt_precio1))
list_tuples2= list(zip(srt_modelos2, srt_info2, srt_precio2))

# Agrego las tuplas y nombro las columnas
srt_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
srt_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
smart_df = srt_df1.append([srt_df2], ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples3= list(zip(srt_modelos3, srt_info3, srt_precio3))
list_tuples4= list(zip(srt_modelos4, srt_info4, srt_precio4))

# Agrego las tuplas y nombro las columnas
srt_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
srt_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
smart_df5 = srt_df3.append([smart_df, srt_df4], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
smart_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Smart Ventas.csv', index = False, header=False)

# %%
smart_df5.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Smart3 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Subaru

# %% [markdown]
# ### Subaru Ventas

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/subaru/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
subaru_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
sbu_md1 = subaru_soup1.find_all('h4', class_ = 'bold size-h6 left')
sbu_modelos1 = list()

for i in sbu_md1:
    sbu_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
sbu_inf1 = subaru_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
sbu_info1= list()

for i in sbu_inf1:
    sbu_info1.append(i.text.strip())
    
# Scrap de precio
subaru_soup1 = BeautifulSoup(page.content, "lxml")
sbu_pr1 = subaru_soup1.find_all('span', {'class' : 'left share-value'})

sbu_precio1= list()
for i in sbu_pr1:
    sbu_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/subaru/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
subaru_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
sbu_md2 = subaru_soup2.find_all('h4', class_ = 'bold size-h6 left')
sbu_modelos2 = list()

for i in sbu_md2:
    sbu_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
sbu_inf2 = subaru_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
sbu_info2 = list()

for i in sbu_inf2:
    sbu_info2.append(i.text.strip())
    
# Scrap de precio
subaru_soup2 = BeautifulSoup(page.content, "lxml")
sbu_pr2 = subaru_soup2.find_all('span', {'class' : 'left share-value'})

sbu_precio2= list()
for i in sbu_pr2:
    sbu_precio2.append(i.text.strip())

# %% [markdown]
# ### Subaru DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(sbu_modelos1, sbu_info1, sbu_precio1))

# Agrego las tuplas y nombro las columnas
subaru_df = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples2= list(zip(sbu_modelos2, sbu_info2, sbu_precio2))

# Agrego las tuplas y nombro las columnas
subaru_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])

# Agrego DF's
subaru_df3 = subaru_df2.append([subaru_df], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
subaru_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Subaru Ventas.csv', index = False, header=False)

# %%
subaru_df3.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Subaru3 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Suzuki

# %% [markdown]
# ### Ventas Suzuki

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/suzuki/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
suzuki_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
szk_md1 = suzuki_soup1.find_all('h4', class_ = 'bold size-h6 left')
szk_modelos1 = list()

for i in szk_md1:
    szk_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
szk_inf1 = suzuki_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
szk_info1= list()

for i in szk_inf1:
    szk_info1.append(i.text.strip())
    
# Scrap de precio
suzuki_soup1 = BeautifulSoup(page.content, "lxml")
szk_pr1 = suzuki_soup1.find_all('span', {'class' : 'left share-value'})

szk_precio1= list()
for i in szk_pr1:
    szk_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/suzuki/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
suzuki_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
szk_md2 = suzuki_soup2.find_all('h4', class_ = 'bold size-h6 left')
szk_modelos2 = list()

for i in szk_md2:
    szk_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
szk_inf2 = suzuki_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
szk_info2 = list()

for i in szk_inf2:
    szk_info2.append(i.text.strip())
    
# Scrap de precio
suzuki_soup2 = BeautifulSoup(page.content, "lxml")
szk_pr2 = suzuki_soup2.find_all('span', {'class' : 'left share-value'})

szk_precio2= list()
for i in szk_pr2:
    szk_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/suzuki/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mg=="
page = requests.get(URL)
suzuki_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
szk_md3 = suzuki_soup3.find_all('h4', class_ = 'bold size-h6 left')
szk_modelos3 = list()

for i in szk_md3:
    szk_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
szk_inf3 = suzuki_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
szk_info3 = list()

for i in szk_inf3:
    szk_info3.append(i.text.strip())
    
# Scrap de precio
suzuki_soup3 = BeautifulSoup(page.content, "lxml")
szk_pr3 = suzuki_soup3.find_all('span', {'class' : 'left share-value'})

szk_precio3 = list()
for i in szk_pr3:
    szk_precio3.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/suzuki/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mw=="
page = requests.get(URL)
suzuki_soup4 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
szk_md4 = suzuki_soup4.find_all('h4', class_ = 'bold size-h6 left')
szk_modelos4 = list()

for i in szk_md4:
    szk_modelos4.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
szk_inf4 = suzuki_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
szk_info4 = list()

for i in szk_inf4:
    szk_info4.append(i.text.strip())
    
# Scrap de precio
suzuki_soup4 = BeautifulSoup(page.content, "lxml")
szk_pr4 = suzuki_soup4.find_all('span', {'class' : 'left share-value'})

szk_precio4 = list()
for i in szk_pr4:
    szk_precio4.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/suzuki/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=NA=="
page = requests.get(URL)
suzuki_soup5 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
szk_md5 = suzuki_soup5.find_all('h4', class_ = 'bold size-h6 left')
szk_modelos5 = list()

for i in szk_md5:
    szk_modelos5.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
szk_inf5 = suzuki_soup5.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
szk_info5 = list()

for i in szk_inf5:
    szk_info5.append(i.text.strip())
    
# Scrap de precio
suzuki_soup5 = BeautifulSoup(page.content, "lxml")
szk_pr5 = suzuki_soup5.find_all('span', {'class' : 'left share-value'})

szk_precio5 = list()
for i in szk_pr5:
    szk_precio5.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/suzuki/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=NQ=="
page = requests.get(URL)
suzuki_soup6 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
szk_md6 = suzuki_soup6.find_all('h4', class_ = 'bold size-h6 left')
szk_modelos6 = list()

for i in szk_md6:
    szk_modelos6.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
szk_inf6 = suzuki_soup6.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
szk_info6 = list()

for i in szk_inf6:
    szk_info6.append(i.text.strip())
    
# Scrap de precio
suzuki_soup6 = BeautifulSoup(page.content, "lxml")
szk_pr6 = suzuki_soup6.find_all('span', {'class' : 'left share-value'})

szk_precio6 = list()
for i in szk_pr6:
    szk_precio6.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/suzuki/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Ng=="
page = requests.get(URL)
suzuki_soup7 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
szk_md7 = suzuki_soup7.find_all('h4', class_ = 'bold size-h6 left')
szk_modelos7 = list()

for i in szk_md7:
    szk_modelos7.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
szk_inf7 = suzuki_soup7.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
szk_info7 = list()

for i in szk_inf7:
    szk_info7.append(i.text.strip())
    
# Scrap de precio
suzuki_soup7 = BeautifulSoup(page.content, "lxml")
szk_pr7 = suzuki_soup7.find_all('span', {'class' : 'left share-value'})

szk_precio7 = list()
for i in szk_pr7:
    szk_precio7.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/suzuki/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Nw=="
page = requests.get(URL)
suzuki_soup8 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
szk_md8 = suzuki_soup8.find_all('h4', class_ = 'bold size-h6 left')
szk_modelos8 = list()

for i in szk_md8:
    szk_modelos8.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
szk_inf8 = suzuki_soup8.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
szk_info8 = list()

for i in szk_inf8:
    szk_info8.append(i.text.strip())
    
# Scrap de precio
suzuki_soup8 = BeautifulSoup(page.content, "lxml")
szk_pr8 = suzuki_soup8.find_all('span', {'class' : 'left share-value'})

szk_precio8 = list()
for i in szk_pr8:
    szk_precio8.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/suzuki/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=OA=="
page = requests.get(URL)
suzuki_soup9 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
szk_md9 = suzuki_soup9.find_all('h4', class_ = 'bold size-h6 left')
szk_modelos9 = list()

for i in szk_md9:
    szk_modelos9.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
szk_inf9 = suzuki_soup9.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
szk_info9 = list()

for i in szk_inf9:
    szk_info9.append(i.text.strip())
    
# Scrap de precio
suzuki_soup9 = BeautifulSoup(page.content, "lxml")
szk_pr9 = suzuki_soup9.find_all('span', {'class' : 'left share-value'})

szk_precio9 = list()
for i in szk_pr9:
    szk_precio9.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/suzuki/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=OQ=="
page = requests.get(URL)
suzuki_soup10 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
szk_md10 = suzuki_soup10.find_all('h4', class_ = 'bold size-h6 left')
szk_modelos10 = list()

for i in szk_md10:
    szk_modelos10.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
szk_inf10 = suzuki_soup10.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
szk_info10 = list()

for i in szk_inf10:
    szk_info10.append(i.text.strip())
    
# Scrap de precio
suzuki_soup10 = BeautifulSoup(page.content, "lxml")
szk_pr10 = suzuki_soup10.find_all('span', {'class' : 'left share-value'})

szk_precio10 = list()
for i in szk_pr10:
    szk_precio10.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/suzuki/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MTA="
page = requests.get(URL)
suzuki_soup11 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
szk_md11 = suzuki_soup11.find_all('h4', class_ = 'bold size-h6 left')
szk_modelos11 = list()

for i in szk_md11:
    szk_modelos11.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
szk_inf11 = suzuki_soup11.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
szk_info11 = list()

for i in szk_inf11:
    szk_info11.append(i.text.strip())
    
# Scrap de precio
suzuki_soup11 = BeautifulSoup(page.content, "lxml")
szk_pr11 = suzuki_soup11.find_all('span', {'class' : 'left share-value'})

szk_precio11 = list()
for i in szk_pr11:
    szk_precio11.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/suzuki/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MTE="
page = requests.get(URL)
suzuki_soup12 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
szk_md12 = suzuki_soup12.find_all('h4', class_ = 'bold size-h6 left')
szk_modelos12 = list()

for i in szk_md12:
    szk_modelos12.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
szk_inf12 = suzuki_soup12.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
szk_info12 = list()

for i in szk_inf12:
    szk_info12.append(i.text.strip())
    
# Scrap de precio
suzuki_soup12 = BeautifulSoup(page.content, "lxml")
szk_pr12 = suzuki_soup12.find_all('span', {'class' : 'left share-value'})

szk_precio12 = list()
for i in szk_pr12:
    szk_precio12.append(i.text.strip())

# %% [markdown]
# ### Suzuki DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(szk_modelos1, szk_info1, szk_precio1))
list_tuples2= list(zip(szk_modelos2, szk_info2, szk_precio2))
list_tuples3= list(zip(szk_modelos3, szk_info3, szk_precio3))
list_tuples4= list(zip(szk_modelos4, szk_info4, szk_precio4))
list_tuples5= list(zip(szk_modelos5, szk_info5, szk_precio5))

# Agrego las tuplas y nombro las columnas
szk_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
szk_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
szk_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
szk_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])
szk_df5 = pd.DataFrame(list_tuples5, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
suzuki_df = szk_df1.append([szk_df2, szk_df3, szk_df4, szk_df5], ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples6= list(zip(szk_modelos6, szk_info6, szk_precio6))
list_tuples7= list(zip(szk_modelos7, szk_info7, szk_precio7))
list_tuples8= list(zip(szk_modelos8, szk_info8, szk_precio8))
list_tuples9= list(zip(szk_modelos9, szk_info9, szk_precio9))
list_tuples10= list(zip(szk_modelos10, szk_info10, szk_precio10))
list_tuples11= list(zip(szk_modelos11, szk_info11, szk_precio11))
list_tuples12= list(zip(szk_modelos12, szk_info12, szk_precio12))

# Agrego las tuplas y nombro las columnas
szk_df6 = pd.DataFrame(list_tuples6, columns= ['Modelos', 'Información', 'Precio'])
szk_df7 = pd.DataFrame(list_tuples7, columns= ['Modelos', 'Información', 'Precio'])
szk_df8 = pd.DataFrame(list_tuples8, columns= ['Modelos', 'Información', 'Precio'])
szk_df9 = pd.DataFrame(list_tuples9, columns= ['Modelos', 'Información', 'Precio'])
szk_df10 = pd.DataFrame(list_tuples10, columns= ['Modelos', 'Información', 'Precio'])
szk_df11 = pd.DataFrame(list_tuples11, columns= ['Modelos', 'Información', 'Precio'])
szk_df12 = pd.DataFrame(list_tuples12, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
szk_df13 = szk_df6.append([suzuki_df, szk_df7, szk_df8, szk_df9, szk_df10, szk_df11, szk_df12], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
suzuki_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Suzuki Ventas.csv', index = False, header=False)

# %%
szk_df13.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Suzuki3 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Toyota

# %% [markdown]
# ### Ventas Toyota

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/toyota/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
toyota_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
tyt_md1 = toyota_soup1.find_all('h4', class_ = 'bold size-h6 left')
tyt_modelos1 = list()

for i in tyt_md1:
    tyt_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
tyt_inf1 = toyota_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
tyt_info1 = list()

for i in tyt_inf1:
    tyt_info1.append(i.text.strip())
    
# Scrap de precio
toyota_soup1 = BeautifulSoup(page.content, "lxml")
tyt_pr1 = toyota_soup1.find_all('span', {'class' : 'left share-value'})

tyt_precio1 = list()
for i in tyt_pr1:
    tyt_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/toyota/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
toyota_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
tyt_md2 = toyota_soup2.find_all('h4', class_ = 'bold size-h6 left')
tyt_modelos2 = list()

for i in tyt_md2:
    tyt_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
tyt_inf2 = toyota_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
tyt_info2 = list()

for i in tyt_inf2:
    tyt_info2.append(i.text.strip())
    
# Scrap de precio
toyota_soup2 = BeautifulSoup(page.content, "lxml")
tyt_pr2 = toyota_soup2.find_all('span', {'class' : 'left share-value'})

tyt_precio2= list()
for i in tyt_pr2:
    tyt_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/toyota/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mg=="
page = requests.get(URL)
toyota_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
tyt_md3 = toyota_soup3.find_all('h4', class_ = 'bold size-h6 left')
tyt_modelos3 = list()

for i in tyt_md3:
    tyt_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
tyt_inf3 = toyota_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
tyt_info3 = list()

for i in tyt_inf3:
    tyt_info3.append(i.text.strip())
    
# Scrap de precio
toyota_soup3 = BeautifulSoup(page.content, "lxml")
tyt_pr3 = toyota_soup3.find_all('span', {'class' : 'left share-value'})

tyt_precio3 = list()
for i in tyt_pr3:
    tyt_precio3.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/toyota/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mw=="
page = requests.get(URL)
toyota_soup4 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
tyt_md4 = toyota_soup4.find_all('h4', class_ = 'bold size-h6 left')
tyt_modelos4 = list()

for i in tyt_md4:
    tyt_modelos4.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
tyt_inf4 = toyota_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
tyt_info4 = list()

for i in tyt_inf4:
    tyt_info4.append(i.text.strip())
    
# Scrap de precio
toyota_soup4 = BeautifulSoup(page.content, "lxml")
tyt_pr4 = toyota_soup4.find_all('span', {'class' : 'left share-value'})

tyt_precio4 = list()
for i in tyt_pr4:
    tyt_precio4.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/toyota/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=NA=="
page = requests.get(URL)
toyota_soup5 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
tyt_md5 = toyota_soup5.find_all('h4', class_ = 'bold size-h6 left')
tyt_modelos5 = list()

for i in tyt_md5:
    tyt_modelos5.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
tyt_inf5 = toyota_soup5.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
tyt_info5 = list()

for i in tyt_inf5:
    tyt_info5.append(i.text.strip())
    
# Scrap de precio
toyota_soup5 = BeautifulSoup(page.content, "lxml")
tyt_pr5 = toyota_soup5.find_all('span', {'class' : 'left share-value'})

tyt_precio5 = list()
for i in tyt_pr5:
    tyt_precio5.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/toyota/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=NQ=="
page = requests.get(URL)
toyota_soup6 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
tyt_md6 = toyota_soup6.find_all('h4', class_ = 'bold size-h6 left')
tyt_modelos6 = list()

for i in tyt_md6:
    tyt_modelos6.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
tyt_inf6 = toyota_soup6.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
tyt_info6 = list()

for i in tyt_inf6:
    tyt_info6.append(i.text.strip())
    
# Scrap de precio
toyota_soup6 = BeautifulSoup(page.content, "lxml")
tyt_pr6 = toyota_soup6.find_all('span', {'class' : 'left share-value'})

tyt_precio6 = list()
for i in tyt_pr6:
    tyt_precio6.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/toyota/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Ng=="
page = requests.get(URL)
toyota_soup7 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
tyt_md7 = toyota_soup7.find_all('h4', class_ = 'bold size-h6 left')
tyt_modelos7 = list()

for i in tyt_md7:
    tyt_modelos7.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
tyt_inf7 = toyota_soup7.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
tyt_info7 = list()

for i in tyt_inf7:
    tyt_info7.append(i.text.strip())
    
# Scrap de precio
toyota_soup7 = BeautifulSoup(page.content, "lxml")
tyt_pr7 = toyota_soup7.find_all('span', {'class' : 'left share-value'})

tyt_precio7 = list()
for i in tyt_pr7:
    tyt_precio7.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/toyota/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Nw=="
page = requests.get(URL)
toyota_soup8 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
tyt_md8 = toyota_soup8.find_all('h4', class_ = 'bold size-h6 left')
tyt_modelos8 = list()

for i in tyt_md8:
    tyt_modelos8.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
tyt_inf8 = toyota_soup8.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
tyt_info8 = list()

for i in tyt_inf8:
    tyt_info8.append(i.text.strip())
    
# Scrap de precio
toyota_soup8 = BeautifulSoup(page.content, "lxml")
tyt_pr8 = toyota_soup8.find_all('span', {'class' : 'left share-value'})

tyt_precio8 = list()
for i in tyt_pr8:
    tyt_precio8.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/toyota/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=OA=="
page = requests.get(URL)
toyota_soup9 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
tyt_md9 = toyota_soup9.find_all('h4', class_ = 'bold size-h6 left')
tyt_modelos9 = list()

for i in tyt_md9:
    tyt_modelos9.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
tyt_inf9 = toyota_soup9.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
tyt_info9 = list()

for i in tyt_inf9:
    tyt_info9.append(i.text.strip())
    
# Scrap de precio
toyota_soup9 = BeautifulSoup(page.content, "lxml")
tyt_pr9 = toyota_soup9.find_all('span', {'class' : 'left share-value'})

tyt_precio9 = list()
for i in tyt_pr9:
    tyt_precio9.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/toyota/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=OQ=="
page = requests.get(URL)
toyota_soup10 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
tyt_md10 = toyota_soup10.find_all('h4', class_ = 'bold size-h6 left')
tyt_modelos10 = list()

for i in tyt_md10:
    tyt_modelos10.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
tyt_inf10 = toyota_soup10.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
tyt_info10 = list()

for i in tyt_inf10:
    tyt_info10.append(i.text.strip())
    
# Scrap de precio
toyota_soup10 = BeautifulSoup(page.content, "lxml")
tyt_pr10 = toyota_soup10.find_all('span', {'class' : 'left share-value'})

tyt_precio10 = list()
for i in tyt_pr10:
    tyt_precio10.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/toyota/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MTA="
page = requests.get(URL)
toyota_soup11 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
tyt_md11 = toyota_soup11.find_all('h4', class_ = 'bold size-h6 left')
tyt_modelos11 = list()

for i in tyt_md11:
    tyt_modelos11.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
tyt_inf11 = toyota_soup11.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
tyt_info11 = list()

for i in tyt_inf11:
    tyt_info11.append(i.text.strip())
    
# Scrap de precio
toyota_soup11 = BeautifulSoup(page.content, "lxml")
tyt_pr11 = toyota_soup11.find_all('span', {'class' : 'left share-value'})

tyt_precio11 = list()
for i in tyt_pr11:
    tyt_precio11.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/toyota/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MTE="
page = requests.get(URL)
toyota_soup12 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
tyt_md12 = toyota_soup12.find_all('h4', class_ = 'bold size-h6 left')
tyt_modelos12 = list()

for i in tyt_md12:
    tyt_modelos12.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
tyt_inf12 = toyota_soup12.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
tyt_info12 = list()

for i in tyt_inf12:
    tyt_info12.append(i.text.strip())
    
# Scrap de precio
toyota_soup12 = BeautifulSoup(page.content, "lxml")
tyt_pr12 = toyota_soup12.find_all('span', {'class' : 'left share-value'})

tyt_precio12 = list()
for i in tyt_pr12:
    tyt_precio12.append(i.text.strip())

# %% [markdown]
# ### Toyota DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(tyt_modelos1, tyt_info1, tyt_precio1))
list_tuples2= list(zip(tyt_modelos2, tyt_info2, tyt_precio2))
list_tuples3= list(zip(tyt_modelos3, tyt_info3, tyt_precio3))
list_tuples4= list(zip(tyt_modelos4, tyt_info4, tyt_precio4))
list_tuples5= list(zip(tyt_modelos5, tyt_info5, tyt_precio5))

# Agrego las tuplas y nombro las columnas
tyt_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
tyt_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
tyt_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
tyt_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])
tyt_df5 = pd.DataFrame(list_tuples5, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
toyota_df = tyt_df1.append([tyt_df2, tyt_df3, tyt_df4, tyt_df5], ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples6= list(zip(tyt_modelos6, tyt_info6, tyt_precio6))
list_tuples7= list(zip(tyt_modelos7, tyt_info7, tyt_precio7))
list_tuples8= list(zip(tyt_modelos8, tyt_info8, tyt_precio8))
list_tuples9= list(zip(tyt_modelos9, tyt_info9, tyt_precio9))
list_tuples10= list(zip(tyt_modelos10, tyt_info10, tyt_precio10))
list_tuples11= list(zip(tyt_modelos11, tyt_info11, tyt_precio11))
list_tuples12= list(zip(tyt_modelos12, tyt_info12, tyt_precio12))

# Agrego las tuplas y nombro las columnas
tyt_df6 = pd.DataFrame(list_tuples6, columns= ['Modelos', 'Información', 'Precio'])
tyt_df7 = pd.DataFrame(list_tuples7, columns= ['Modelos', 'Información', 'Precio'])
tyt_df8 = pd.DataFrame(list_tuples8, columns= ['Modelos', 'Información', 'Precio'])
tyt_df9 = pd.DataFrame(list_tuples9, columns= ['Modelos', 'Información', 'Precio'])
tyt_df10 = pd.DataFrame(list_tuples10, columns= ['Modelos', 'Información', 'Precio'])
tyt_df11 = pd.DataFrame(list_tuples11, columns= ['Modelos', 'Información', 'Precio'])
tyt_df12 = pd.DataFrame(list_tuples12, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
tyt_df13 = tyt_df6.append([toyota_df, tyt_df7, tyt_df8, tyt_df9, tyt_df10, tyt_df11, tyt_df12], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
toyota_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Toyota Ventas.csv', index = False, header=False)

# %%
tyt_df13.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Toyota3 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Volkswagen

# %% [markdown]
# ### Ventas Volkswagen

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/volkswagen/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
volks_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
vks_md1 = volks_soup1.find_all('h4', class_ = 'bold size-h6 left')
vks_modelos1 = list()

for i in vks_md1:
    vks_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
vks_inf1 = volks_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
vks_info1 = list()

for i in vks_inf1:
    vks_info1.append(i.text.strip())
    
# Scrap de precio
volks_soup1 = BeautifulSoup(page.content, "lxml")
vks_pr1 = volks_soup1.find_all('span', {'class' : 'left share-value'})

vks_precio1 = list()
for i in vks_pr1:
    vks_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/volkswagen/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=MQ=="
page = requests.get(URL)
volks_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
vks_md2 = volks_soup2.find_all('h4', class_ = 'bold size-h6 left')
vks_modelos2 = list()

for i in vks_md2:
    vks_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
vks_inf2 = volks_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
vks_info2 = list()

for i in vks_inf2:
    vks_info2.append(i.text.strip())
    
# Scrap de precio
volks_soup2 = BeautifulSoup(page.content, "lxml")
vks_pr2 = volks_soup2.find_all('span', {'class' : 'left share-value'})

vks_precio2 = list()
for i in vks_pr2:
    vks_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/volkswagen/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mg=="
page = requests.get(URL)
volks_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
vks_md3 = volks_soup3.find_all('h4', class_ = 'bold size-h6 left')
vks_modelos3 = list()

for i in vks_md3:
    vks_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
vks_inf3 = volks_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
vks_info3 = list()

for i in vks_inf3:
    vks_info3.append(i.text.strip())
    
# Scrap de precio
volks_soup3 = BeautifulSoup(page.content, "lxml")
vks_pr3 = volks_soup3.find_all('span', {'class' : 'left share-value'})

vks_precio3 = list()
for i in vks_pr3:
    vks_precio3.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/volkswagen/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=Mw=="
page = requests.get(URL)
volks_soup4 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
vks_md4 = volks_soup4.find_all('h4', class_ = 'bold size-h6 left')
vks_modelos4 = list()

for i in vks_md4:
    vks_modelos4.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
vks_inf4 = volks_soup4.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
vks_info4 = list()

for i in vks_inf4:
    vks_info4.append(i.text.strip())
    
# Scrap de precio
volks_soup4 = BeautifulSoup(page.content, "lxml")
vks_pr4 = volks_soup4.find_all('span', {'class' : 'left share-value'})

vks_precio4 = list()
for i in vks_pr4:
    vks_precio4.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/volkswagen/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated&page=NA=="
page = requests.get(URL)
volks_soup5 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
vks_md5 = volks_soup5.find_all('h4', class_ = 'bold size-h6 left')
vks_modelos5 = list()

for i in vks_md5:
    vks_modelos5.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
vks_inf5 = volks_soup5.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
vks_info5 = list()

for i in vks_inf5:
    vks_info5.append(i.text.strip())
    
# Scrap de precio
volks_soup5 = BeautifulSoup(page.content, "lxml")
vks_pr5 = volks_soup5.find_all('span', {'class' : 'left share-value'})

vks_precio5 = list()
for i in vks_pr5:
    vks_precio5.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/volkswagen/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=NQ=="
page = requests.get(URL)
volks_soup6 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
vks_md6 = volks_soup6.find_all('h4', class_ = 'bold size-h6 left')
vks_modelos6 = list()

for i in vks_md6:
    vks_modelos6.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
vks_inf6 = volks_soup6.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
vks_info6 = list()

for i in vks_inf6:
    vks_info6.append(i.text.strip())
    
# Scrap de precio
volks_soup6 = BeautifulSoup(page.content, "lxml")
vks_pr6 = volks_soup6.find_all('span', {'class' : 'left share-value'})

vks_precio6 = list()
for i in vks_pr6:
    vks_precio6.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/volkswagen/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Ng=="
page = requests.get(URL)
volks_soup7 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
vks_md7 = volks_soup7.find_all('h4', class_ = 'bold size-h6 left')
vks_modelos7 = list()

for i in vks_md7:
    vks_modelos7.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
vks_inf7 = volks_soup7.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
vks_info7 = list()

for i in vks_inf7:
    vks_info7.append(i.text.strip())
    
# Scrap de precio
volks_soup7 = BeautifulSoup(page.content, "lxml")
vks_pr7 = volks_soup7.find_all('span', {'class' : 'left share-value'})

vks_precio7 = list()
for i in vks_pr7:
    vks_precio7.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/volkswagen/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=Nw=="
page = requests.get(URL)
volks_soup8 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
vks_md8 = volks_soup8.find_all('h4', class_ = 'bold size-h6 left')
vks_modelos8 = list()

for i in vks_md8:
    vks_modelos8.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
vks_inf8 = volks_soup8.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
vks_info8 = list()

for i in vks_inf8:
    vks_info8.append(i.text.strip())
    
# Scrap de precio
volks_soup8 = BeautifulSoup(page.content, "lxml")
vks_pr8 = volks_soup8.find_all('span', {'class' : 'left share-value'})

vks_precio8 = list()
for i in vks_pr8:
    vks_precio8.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/volkswagen/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=OA=="
page = requests.get(URL)
volks_soup9 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
vks_md9 = volks_soup9.find_all('h4', class_ = 'bold size-h6 left')
vks_modelos9 = list()

for i in vks_md9:
    vks_modelos9.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
vks_inf9 = volks_soup9.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
vks_info9 = list()

for i in vks_inf9:
    vks_info9.append(i.text.strip())
    
# Scrap de precio
volks_soup9 = BeautifulSoup(page.content, "lxml")
vks_pr9 = volks_soup9.find_all('span', {'class' : 'left share-value'})

vks_precio9 = list()
for i in vks_pr9:
    vks_precio9.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/volkswagen/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=OQ=="
page = requests.get(URL)
volks_soup10 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
vks_md10 = volks_soup10.find_all('h4', class_ = 'bold size-h6 left')
vks_modelos10 = list()

for i in vks_md10:
    vks_modelos10.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
vks_inf10 = volks_soup10.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
vks_info10 = list()

for i in vks_inf10:
    vks_info10.append(i.text.strip())
    
# Scrap de precio
volks_soup10 = BeautifulSoup(page.content, "lxml")
vks_pr10 = volks_soup10.find_all('span', {'class' : 'left share-value'})

vks_precio10 = list()
for i in vks_pr10:
    vks_precio10.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/volkswagen/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MTA="
page = requests.get(URL)
volks_soup11 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
vks_md11 = volks_soup11.find_all('h4', class_ = 'bold size-h6 left')
vks_modelos11 = list()

for i in vks_md11:
    vks_modelos11.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
vks_inf11 = volks_soup11.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
vks_info11 = list()

for i in vks_inf11:
    vks_info11.append(i.text.strip())
    
# Scrap de precio
volks_soup11 = BeautifulSoup(page.content, "lxml")
vks_pr11 = volks_soup11.find_all('span', {'class' : 'left share-value'})

vks_precio11 = list()
for i in vks_pr11:
    vks_precio11.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/volkswagen/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MTE="
page = requests.get(URL)
volks_soup12 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
vks_md12 = volks_soup12.find_all('h4', class_ = 'bold size-h6 left')
vks_modelos12 = list()

for i in vks_md12:
    vks_modelos12.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
vks_inf12 = volks_soup12.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
vks_info12 = list()

for i in vks_inf12:
    vks_info12.append(i.text.strip())
    
# Scrap de precio
volks_soup12 = BeautifulSoup(page.content, "lxml")
vks_pr12 = volks_soup12.find_all('span', {'class' : 'left share-value'})

vks_precio12 = list()
for i in vks_pr12:
    vks_precio12.append(i.text.strip())

# %% [markdown]
# ### Volkswagen

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(vks_modelos1, vks_info1, vks_precio1))
list_tuples2= list(zip(vks_modelos2, vks_info2, vks_precio2))
list_tuples3= list(zip(vks_modelos3, vks_info3, vks_precio3))
list_tuples4= list(zip(vks_modelos4, vks_info4, vks_precio4))
list_tuples5= list(zip(vks_modelos5, vks_info5, vks_precio5))

# Agrego las tuplas y nombro las columnas
vks_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
vks_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
vks_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
vks_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])
vks_df5 = pd.DataFrame(list_tuples5, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
volks_df = vks_df1.append([vks_df2, vks_df3, vks_df4, vks_df5], ignore_index = True)

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples6= list(zip(vks_modelos6, vks_info6, vks_precio6))
list_tuples7= list(zip(vks_modelos7, vks_info7, vks_precio7))
list_tuples8= list(zip(vks_modelos8, vks_info8, vks_precio8))
list_tuples9= list(zip(vks_modelos9, vks_info9, vks_precio9))
list_tuples10= list(zip(vks_modelos10, vks_info10, vks_precio10))
list_tuples11= list(zip(vks_modelos11, vks_info11, vks_precio11))
list_tuples12= list(zip(vks_modelos12, vks_info12, vks_precio12))

# Agrego las tuplas y nombro las columnas
vks_df6 = pd.DataFrame(list_tuples6, columns= ['Modelos', 'Información', 'Precio'])
vks_df7 = pd.DataFrame(list_tuples7, columns= ['Modelos', 'Información', 'Precio'])
vks_df8 = pd.DataFrame(list_tuples8, columns= ['Modelos', 'Información', 'Precio'])
vks_df9 = pd.DataFrame(list_tuples9, columns= ['Modelos', 'Información', 'Precio'])
vks_df10 = pd.DataFrame(list_tuples10, columns= ['Modelos', 'Información', 'Precio'])
vks_df11 = pd.DataFrame(list_tuples11, columns= ['Modelos', 'Información', 'Precio'])
vks_df12 = pd.DataFrame(list_tuples12, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
vks_df13 = vks_df6.append([volks_df, vks_df7, vks_df8, vks_df9, vks_df10, vks_df11, vks_df12], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
volks_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Volkswagen Ventas.csv', index = False, header=False)

# %%
vks_df13.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\Webscrapping\Volkswagen4 Ventas.csv', index = False, header=False)

# %% [markdown]
# # Volvo

# %% [markdown]
# ### Volvo Ventas

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/volvo/-/2022?type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&type_autos_year=2021&type_autos_moderated=moderated"
page = requests.get(URL)
volvo_soup1 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
vlv_md1 = volvo_soup1.find_all('h4', class_ = 'bold size-h6 left')
vlv_modelos1 = list()

for i in vlv_md1:
    vlv_modelos1.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
vlv_inf1 = volvo_soup1.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
vlv_info1 = list()

for i in vlv_inf1:
    vlv_info1.append(i.text.strip())
    
# Scrap de precio
volvo_soup1 = BeautifulSoup(page.content, "lxml")
vlv_pr1 = volvo_soup1.find_all('span', {'class' : 'left share-value'})

vlv_precio1 = list()
for i in vlv_pr1:
    vlv_precio1.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/volvo/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020"
page = requests.get(URL)
volvo_soup2 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
vlv_md2 = volvo_soup2.find_all('h4', class_ = 'bold size-h6 left')
vlv_modelos2 = list()

for i in vlv_md2:
    vlv_modelos2.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
vlv_inf2 = volvo_soup2.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
vlv_info2 = list()

for i in vlv_inf2:
    vlv_info2.append(i.text.strip())
    
# Scrap de precio
volvo_soup2 = BeautifulSoup(page.content, "lxml")
vlv_pr2 = volvo_soup2.find_all('span', {'class' : 'left share-value'})

vlv_precio2 = list()
for i in vlv_pr2:
    vlv_precio2.append(i.text.strip())

# %%
#Bajo la información
URL = "https://www.seminuevos.com/usados/-/autos/-/volvo/-/2021?type_autos_moderated=moderated&type_autos_year=2016&type_autos_year=2017&type_autos_year=2018&type_autos_year=2019&type_autos_year=2020&page=MQ=="
page = requests.get(URL)
volvo_soup3 = BeautifulSoup(page.content, "html.parser")

#Consigo la información de modelos
vlv_md3 = volvo_soup3.find_all('h4', class_ = 'bold size-h6 left')
vlv_modelos3 = list()

for i in vlv_md3:
    vlv_modelos3.append(i.text.strip())

#Información de año, modelo, y ciudad de venta
vlv_inf3 = volvo_soup3.find_all('div', class_ = 'latam-secondary-text text-lighten-2 left vehicle-highlight')
vlv_info3 = list()

for i in vlv_inf3:
    vlv_info3.append(i.text.strip())
    
# Scrap de precio
volvo_soup3 = BeautifulSoup(page.content, "lxml")
vlv_pr3 = volvo_soup3.find_all('span', {'class' : 'left share-value'})

vlv_precio3 = list()
for i in vlv_pr3:
    vlv_precio3.append(i.text.strip())

# %% [markdown]
# ### Volvo DataFrame

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(vlv_modelos1, vlv_info1, vlv_precio1))

# Agrego las tuplas y nombro las columnas
vlv_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples2= list(zip(vlv_modelos2, vlv_info2, vlv_precio2))
list_tuples3= list(zip(vlv_modelos3, vlv_info3, vlv_precio3))

# Agrego las tuplas y nombro las columnas
vlv_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
vlv_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])

# Agrego las tuplas y nombro las columnas
vlv_df4 = vlv_df2.append([vlv_df1, vlv_df3], ignore_index = True)

# %% [markdown]
# ### Convierto a CSV

# %%
vlv_df1.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Volvo Ventas.csv', index = False, header=False)

# %%
vlv_df4.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Volvo3 Ventas.csv', index = False, header=False)
