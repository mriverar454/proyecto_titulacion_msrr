# %% [markdown]
# ## Paqueteria

# %%
# Descargo la paqueteria necesaria
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# ## Automexico.com

# %% [markdown]
# ### Chevrolet

# %%
# Hago la sopa
URL = "https://automexico.com/autos-chevrolet"
page = requests.get(URL)

chevrolet_soup1 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
gm_md1 = chevrolet_soup1.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
gm_modelos1 = list()

for i in gm_md1:
    gm_modelos1.append(i.text.strip())
    
# Scrapeamos el precio
gm_pr1 = chevrolet_soup1.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
gm_precios1 = list()

for p in gm_pr1:
    gm_precios1.append(p.text.strip())
    
# Scrapeamos la informacion
chevrolet_soup1 = BeautifulSoup(page.content, "lxml")

gm_inf1 = chevrolet_soup1.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
gm_info1 = list()

for i in gm_inf1:
    gm_info1.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-chevrolet/p2"
page = requests.get(URL)

chevrolet_soup2 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
gm_md2 = chevrolet_soup2.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
gm_modelos2 = list()

for i in gm_md2:
    gm_modelos2.append(i.text.strip())
    
# Scrapeamos el precio
gm_pr2 = chevrolet_soup2.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
gm_precios2 = list()

for p in gm_pr2:
    gm_precios2.append(p.text.strip())
    
# Scrapeamos la informacion
chevrolet_soup2 = BeautifulSoup(page.content, "lxml")

gm_inf2 = chevrolet_soup2.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
gm_info2 = list()

for i in gm_inf2:
    gm_info2.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-chevrolet/p3"
page = requests.get(URL)

chevrolet_soup3 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
gm_md3 = chevrolet_soup3.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
gm_modelos3 = list()

for i in gm_md3:
    gm_modelos3.append(i.text.strip())
    
# Scrapeamos el precio
gm_pr3 = chevrolet_soup3.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
gm_precios3 = list()

for p in gm_pr3:
    gm_precios3.append(p.text.strip())
    
# Scrapeamos la informacion
chevrolet_soup3 = BeautifulSoup(page.content, "lxml")

gm_inf3 = chevrolet_soup3.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
gm_info3 = list()

for i in gm_inf3:
    gm_info3.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-chevrolet/p4"
page = requests.get(URL)

chevrolet_soup4 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
gm_md4 = chevrolet_soup4.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
gm_modelos4 = list()

for i in gm_md4:
    gm_modelos4.append(i.text.strip())
    
# Scrapeamos el precio
gm_pr4 = chevrolet_soup4.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
gm_precios4 = list()

for p in gm_pr4:
    gm_precios4.append(p.text.strip())
    
# Scrapeamos la informacion
chevrolet_soup4 = BeautifulSoup(page.content, "lxml")

gm_inf4 = chevrolet_soup4.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
gm_info4 = list()

for i in gm_inf4:
    gm_info4.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-chevrolet/p5"
page = requests.get(URL)

chevrolet_soup5 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
gm_md5 = chevrolet_soup5.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
gm_modelos5 = list()

for i in gm_md5:
    gm_modelos5.append(i.text.strip())
    
# Scrapeamos el precio
gm_pr5 = chevrolet_soup5.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
gm_precios5 = list()

for p in gm_pr5:
    gm_precios5.append(p.text.strip())
    
# Scrapeamos la informacion
chevrolet_soup5 = BeautifulSoup(page.content, "lxml")

gm_inf5 = chevrolet_soup5.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
gm_info5 = list()

for i in gm_inf5:
    gm_info5.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-chevrolet/p6"
page = requests.get(URL)

chevrolet_soup6 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
gm_md6 = chevrolet_soup6.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
gm_modelos6 = list()

for i in gm_md6:
    gm_modelos6.append(i.text.strip())
    
# Scrapeamos el precio
gm_pr6 = chevrolet_soup6.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
gm_precios6 = list()

for p in gm_pr6:
    gm_precios6.append(p.text.strip())
    
# Scrapeamos la informacion
chevrolet_soup6 = BeautifulSoup(page.content, "lxml")

gm_inf6 = chevrolet_soup6.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
gm_info6 = list()

for i in gm_inf6:
    gm_info6.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-chevrolet/p7"
page = requests.get(URL)

chevrolet_soup7 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
gm_md7 = chevrolet_soup7.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
gm_modelos7 = list()

for i in gm_md7:
    gm_modelos7.append(i.text.strip())
    
# Scrapeamos el precio
gm_pr7 = chevrolet_soup7.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
gm_precios7 = list()

for p in gm_pr7:
    gm_precios7.append(p.text.strip())
    
# Scrapeamos la informacion
chevrolet_soup7 = BeautifulSoup(page.content, "lxml")

gm_inf7 = chevrolet_soup7.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
gm_info7 = list()

for i in gm_inf7:
    gm_info7.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-chevrolet/p8"
page = requests.get(URL)

chevrolet_soup8 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
gm_md8 = chevrolet_soup8.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
gm_modelos8 = list()

for i in gm_md8:
    gm_modelos8.append(i.text.strip())
    
# Scrapeamos el precio
gm_pr8 = chevrolet_soup8.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
gm_precios8 = list()

for p in gm_pr8:
    gm_precios8.append(p.text.strip())
    
# Scrapeamos la informacion
chevrolet_soup8 = BeautifulSoup(page.content, "lxml")

gm_inf8 = chevrolet_soup8.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
gm_info8 = list()

for i in gm_inf8:
    gm_info8.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-chevrolet/p9"
page = requests.get(URL)

chevrolet_soup9 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
gm_md9 = chevrolet_soup9.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
gm_modelos9 = list()

for i in gm_md9:
    gm_modelos9.append(i.text.strip())
    
# Scrapeamos el precio
gm_pr9 = chevrolet_soup9.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
gm_precios9 = list()

for p in gm_pr9:
    gm_precios9.append(p.text.strip())
    
# Scrapeamos la informacion
chevrolet_soup9 = BeautifulSoup(page.content, "lxml")

gm_inf9 = chevrolet_soup9.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
gm_info9 = list()

for i in gm_inf9:
    gm_info9.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-chevrolet/p10"
page = requests.get(URL)

chevrolet_soup10 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
gm_md10 = chevrolet_soup10.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
gm_modelos10 = list()

for i in gm_md10:
    gm_modelos10.append(i.text.strip())
    
# Scrapeamos el precio
gm_pr10 = chevrolet_soup10.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
gm_precios10 = list()

for p in gm_pr10:
    gm_precios10.append(p.text.strip())
    
# Scrapeamos la informacion
chevrolet_soup10 = BeautifulSoup(page.content, "lxml")

gm_inf10 = chevrolet_soup10.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
gm_info10 = list()

for i in gm_inf10:
    gm_info10.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-chevrolet/p11"
page = requests.get(URL)

chevrolet_soup11 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
gm_md11 = chevrolet_soup11.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
gm_modelos11 = list()

for i in gm_md11:
    gm_modelos11.append(i.text.strip())
    
# Scrapeamos el precio
gm_pr11 = chevrolet_soup11.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
gm_precios11 = list()

for p in gm_pr11:
    gm_precios11.append(p.text.strip())
    
# Scrapeamos la informacion
chevrolet_soup11 = BeautifulSoup(page.content, "lxml")

gm_inf11 = chevrolet_soup11.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
gm_info11 = list()

for i in gm_inf11:
    gm_info11.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-chevrolet/p12"
page = requests.get(URL)

chevrolet_soup12 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
gm_md12 = chevrolet_soup12.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
gm_modelos12 = list()

for i in gm_md12:
    gm_modelos12.append(i.text.strip())
    
# Scrapeamos el precio
gm_pr12 = chevrolet_soup12.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
gm_precios12 = list()

for p in gm_pr12:
    gm_precios12.append(p.text.strip())
    
# Scrapeamos la informacion
chevrolet_soup12 = BeautifulSoup(page.content, "lxml")

gm_inf12 = chevrolet_soup12.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
gm_info12 = list()

for i in gm_inf12:
    gm_info12.append(i.text.strip())

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(gm_modelos1, gm_info1, gm_precios1))
list_tuples2= list(zip(gm_modelos2, gm_info2, gm_precios2))
list_tuples3= list(zip(gm_modelos3, gm_info3, gm_precios3))
list_tuples4= list(zip(gm_modelos4, gm_info4, gm_precios4))
list_tuples5= list(zip(gm_modelos5, gm_info5, gm_precios5))
list_tuples6= list(zip(gm_modelos6, gm_info6, gm_precios6))
list_tuples7= list(zip(gm_modelos7, gm_info7, gm_precios7))
list_tuples8= list(zip(gm_modelos8, gm_info8, gm_precios8))
list_tuples9= list(zip(gm_modelos9, gm_info9, gm_precios9))
list_tuples10= list(zip(gm_modelos10, gm_info10, gm_precios10))
list_tuples11= list(zip(gm_modelos11, gm_info11, gm_precios11))
list_tuples12= list(zip(gm_modelos12, gm_info12, gm_precios12))

# Agrego las tuplas y nombro las columnas
chevrolette_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información','Precio'])
chevrolette_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información','Precio'])
chevrolette_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información','Precio'])
chevrolette_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información','Precio'])
chevrolette_df5 = pd.DataFrame(list_tuples5, columns= ['Modelos', 'Información','Precio'])
chevrolette_df6 = pd.DataFrame(list_tuples6, columns= ['Modelos', 'Información','Precio'])
chevrolette_df7 = pd.DataFrame(list_tuples7, columns= ['Modelos', 'Información','Precio'])
chevrolette_df8 = pd.DataFrame(list_tuples8, columns= ['Modelos', 'Información','Precio'])
chevrolette_df9 = pd.DataFrame(list_tuples9, columns= ['Modelos', 'Información','Precio'])
chevrolette_df10 = pd.DataFrame(list_tuples10, columns= ['Modelos', 'Información','Precio'])
chevrolette_df11 = pd.DataFrame(list_tuples11, columns= ['Modelos', 'Información','Precio'])
chevrolette_df12 = pd.DataFrame(list_tuples12, columns= ['Modelos', 'Información','Precio'])

# Agrego los otros DataFrames 
chevrolet_df = chevrolette_df1.append([chevrolette_df2, chevrolette_df3, chevrolette_df4, chevrolette_df5, chevrolette_df6, chevrolette_df7, chevrolette_df8, chevrolette_df9, chevrolette_df10, chevrolette_df11, chevrolette_df12], ignore_index = True)

# %%
chevrolet_df.to_csv(r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Chevrolet_automexico Ventas.csv', index = False, header=True)

# %% [markdown]
# ### Volkswagen

# %%
# Hago la sopa
URL = "https://automexico.com/autos-volkswagen"
page = requests.get(URL)

volkswagen_soup1 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
vk_md1 = volkswagen_soup1.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
vk_modelos1 = list()

for i in vk_md1:
    vk_modelos1.append(i.text.strip())
    
# Scrapeamos el precio
vk_pr1 = volkswagen_soup1.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
vk_precios1 = list()

for p in vk_pr1:
    vk_precios1.append(p.text.strip())
    
# Scrapeamos la informacion
volkswagen_soup1 = BeautifulSoup(page.content, "lxml")

vk_inf1 = volkswagen_soup1.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
vk_info1 = list()

for i in vk_inf1:
    vk_info1.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-volkswagen/p2"
page = requests.get(URL)

volkswagen_soup2 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
vk_md2 = volkswagen_soup2.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
vk_modelos2 = list()

for i in vk_md2:
    vk_modelos2.append(i.text.strip())
    
# Scrapeamos el precio
vk_pr2 = volkswagen_soup2.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
vk_precios2 = list()

for p in vk_pr2:
    vk_precios2.append(p.text.strip())
    
# Scrapeamos la informacion
volkswagen_soup2 = BeautifulSoup(page.content, "lxml")

vk_inf2 = volkswagen_soup2.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
vk_info2 = list()

for i in vk_inf2:
    vk_info2.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-volkswagen/p3"
page = requests.get(URL)

volkswagen_soup3 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
vk_md3 = volkswagen_soup3.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
vk_modelos3 = list()

for i in vk_md3:
    vk_modelos3.append(i.text.strip())
    
# Scrapeamos el precio
vk_pr3 = volkswagen_soup3.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
vk_precios3 = list()

for p in vk_pr3:
    vk_precios3.append(p.text.strip())
    
# Scrapeamos la informacion
volkswagen_soup3 = BeautifulSoup(page.content, "lxml")

vk_inf3 = volkswagen_soup3.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
vk_info3 = list()

for i in vk_inf3:
    vk_info3.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-volkswagen/p4"
page = requests.get(URL)

volkswagen_soup4 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
vk_md4 = volkswagen_soup4.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
vk_modelos4 = list()

for i in vk_md4:
    vk_modelos4.append(i.text.strip())
    
# Scrapeamos el precio
vk_pr4 = volkswagen_soup4.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
vk_precios4 = list()

for p in vk_pr4:
    vk_precios3.append(p.text.strip())
    
# Scrapeamos la informacion
volkswagen_soup4 = BeautifulSoup(page.content, "lxml")

vk_inf4 = volkswagen_soup4.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
vk_info4 = list()

for i in vk_inf4:
    vk_info4.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-volkswagen/p5"
page = requests.get(URL)

volkswagen_soup5 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
vk_md5 = volkswagen_soup5.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
vk_modelos5 = list()

for i in vk_md5:
    vk_modelos5.append(i.text.strip())
    
# Scrapeamos el precio
vk_pr5 = volkswagen_soup5.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
vk_precios5 = list()

for p in vk_pr5:
    vk_precios5.append(p.text.strip())
    
# Scrapeamos la informacion
volkswagen_soup5 = BeautifulSoup(page.content, "lxml")

vk_inf5 = volkswagen_soup5.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
vk_info5 = list()

for i in vk_inf5:
    vk_info5.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-volkswagen/p6"
page = requests.get(URL)

volkswagen_soup6 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
vk_md6 = volkswagen_soup6.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
vk_modelos6 = list()

for i in vk_md6:
    vk_modelos6.append(i.text.strip())
    
# Scrapeamos el precio
vk_pr6 = volkswagen_soup6.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
vk_precios6 = list()

for p in vk_pr6:
    vk_precios6.append(p.text.strip())
    
# Scrapeamos la informacion
volkswagen_soup6 = BeautifulSoup(page.content, "lxml")

vk_inf6 = volkswagen_soup6.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
vk_info6 = list()

for i in vk_inf6:
    vk_info6.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-volkswagen/p7"
page = requests.get(URL)

volkswagen_soup7 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
vk_md7 = volkswagen_soup7.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
vk_modelos7 = list()

for i in vk_md7:
    vk_modelos7.append(i.text.strip())
    
# Scrapeamos el precio
vk_pr7 = volkswagen_soup7.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
vk_precios7 = list()

for p in vk_pr7:
    vk_precios7.append(p.text.strip())
    
# Scrapeamos la informacion
volkswagen_soup7 = BeautifulSoup(page.content, "lxml")

vk_inf7 = volkswagen_soup7.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
vk_info7 = list()

for i in vk_inf7:
    vk_info7.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-volkswagen/p8"
page = requests.get(URL)

volkswagen_soup8 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
vk_md8 = volkswagen_soup8.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
vk_modelos8 = list()

for i in vk_md8:
    vk_modelos8.append(i.text.strip())
    
# Scrapeamos el precio
vk_pr8 = volkswagen_soup8.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
vk_precios8 = list()

for p in vk_pr8:
    vk_precios8.append(p.text.strip())
    
# Scrapeamos la informacion
volkswagen_soup8 = BeautifulSoup(page.content, "lxml")

vk_inf8 = volkswagen_soup8.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
vk_info8 = list()

for i in vk_inf8:
    vk_info8.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-volkswagen/p9"
page = requests.get(URL)

volkswagen_soup9 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
vk_md9 = volkswagen_soup9.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
vk_modelos9 = list()

for i in vk_md9:
    vk_modelos9.append(i.text.strip())
    
# Scrapeamos el precio
vk_pr9 = volkswagen_soup9.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
vk_precios9 = list()

for p in vk_pr9:
    vk_precios9.append(p.text.strip())
    
# Scrapeamos la informacion
volkswagen_soup9 = BeautifulSoup(page.content, "lxml")

vk_inf9 = volkswagen_soup9.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
vk_info9 = list()

for i in vk_inf9:
    vk_info9.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-volkswagen/p10"
page = requests.get(URL)

volkswagen_soup10 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
vk_md10 = volkswagen_soup10.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
vk_modelos10 = list()

for i in vk_md10:
    vk_modelos10.append(i.text.strip())
    
# Scrapeamos el precio
vk_pr10 = volkswagen_soup10.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
vk_precios10 = list()

for p in vk_pr10:
    vk_precios10.append(p.text.strip())
    
# Scrapeamos la informacion
volkswagen_soup10 = BeautifulSoup(page.content, "lxml")

vk_inf10 = volkswagen_soup10.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
vk_info10 = list()

for i in vk_inf10:
    vk_info10.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-volkswagen/p11"
page = requests.get(URL)

volkswagen_soup11 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
vk_md11 = volkswagen_soup11.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
vk_modelos11 = list()

for i in vk_md11:
    vk_modelos11.append(i.text.strip())
    
# Scrapeamos el precio
vk_pr11 = volkswagen_soup11.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
vk_precios11 = list()

for p in vk_pr11:
    vk_precios11.append(p.text.strip())
    
# Scrapeamos la informacion
volkswagen_soup11 = BeautifulSoup(page.content, "lxml")

vk_inf11 = volkswagen_soup11.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
vk_info11 = list()

for i in vk_inf11:
    vk_info11.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-volkswagen/p12"
page = requests.get(URL)

volkswagen_soup12 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
vk_md12 = volkswagen_soup12.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
vk_modelos12 = list()

for i in vk_md12:
    vk_modelos12.append(i.text.strip())
    
# Scrapeamos el precio
vk_pr12 = volkswagen_soup12.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
vk_precios12 = list()

for p in vk_pr12:
    vk_precios12.append(p.text.strip())
    
# Scrapeamos la informacion
volkswagen_soup12 = BeautifulSoup(page.content, "lxml")

vk_inf12 = volkswagen_soup12.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
vk_info12 = list()

for i in vk_inf12:
    vk_info12.append(i.text.strip())

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(vk_modelos1, vk_info1, vk_precios1))
list_tuples2= list(zip(vk_modelos2, vk_info2, vk_precios2))
list_tuples3= list(zip(vk_modelos3, vk_info3, vk_precios3))
list_tuples4= list(zip(vk_modelos4, vk_info4, vk_precios4))
list_tuples5= list(zip(vk_modelos5, vk_info5, vk_precios5))
list_tuples6= list(zip(vk_modelos6, vk_info6, vk_precios6))
list_tuples7= list(zip(vk_modelos7, vk_info7, vk_precios7))
list_tuples8= list(zip(vk_modelos8, vk_info8, vk_precios8))
list_tuples9= list(zip(vk_modelos9, vk_info9, vk_precios9))
list_tuples10= list(zip(vk_modelos10, vk_info10, vk_precios10))
list_tuples11= list(zip(vk_modelos11, vk_info11, vk_precios11))
list_tuples12= list(zip(vk_modelos12, vk_info12, vk_precios12))

# Agrego las tuplas y nombro las columnas
volkswagen_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
volkswagen_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
volkswagen_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
volkswagen_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])
volkswagen_df5 = pd.DataFrame(list_tuples5, columns= ['Modelos', 'Información', 'Precio'])
volkswagen_df6 = pd.DataFrame(list_tuples6, columns= ['Modelos', 'Información', 'Precio'])
volkswagen_df7 = pd.DataFrame(list_tuples7, columns= ['Modelos', 'Información', 'Precio'])
volkswagen_df8 = pd.DataFrame(list_tuples8, columns= ['Modelos', 'Información', 'Precio'])
volkswagen_df9 = pd.DataFrame(list_tuples9, columns= ['Modelos', 'Información', 'Precio'])
volkswagen_df10 = pd.DataFrame(list_tuples10, columns= ['Modelos', 'Información', 'Precio'])
volkswagen_df11 = pd.DataFrame(list_tuples11, columns= ['Modelos', 'Información', 'Precio'])
volkswagen_df12 = pd.DataFrame(list_tuples12, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
volkswagen_df = volkswagen_df1.append([volkswagen_df2, volkswagen_df3, volkswagen_df4, volkswagen_df5, volkswagen_df6, volkswagen_df7, volkswagen_df8, volkswagen_df9, volkswagen_df10, volkswagen_df11, volkswagen_df12], ignore_index = True)

# %%
volkswagen_df.to_csv(r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Volkswagen_automexico Ventas.csv', index = False, header=True)

# %% [markdown]
# ### Nissan

# %%
# Hago la sopa
URL = "https://automexico.com/autos-nissan"
page = requests.get(URL)

nissan_soup1 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
ns_md1 = nissan_soup1.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
ns_modelos1 = list()

for i in ns_md1:
    ns_modelos1.append(i.text.strip())
    
# Scrapeamos el precio
ns_pr1 = nissan_soup1.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
ns_precios1 = list()

for p in ns_pr1:
    ns_precios1.append(p.text.strip())
    
# Scrapeamos la informacion
nissan_soup1 = BeautifulSoup(page.content, "lxml")

ns_inf1 = nissan_soup1.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
ns_info1 = list()

for i in ns_inf1:
    ns_info1.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-nissan/p2"
page = requests.get(URL)

nissan_soup2 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
ns_md2 = nissan_soup2.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
ns_modelos2 = list()

for i in ns_md2:
    ns_modelos2.append(i.text.strip())
    
# Scrapeamos el precio
ns_pr2 = nissan_soup2.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
ns_precios2 = list()

for p in ns_pr2:
    ns_precios2.append(p.text.strip())
    
# Scrapeamos la informacion
nissan_soup2 = BeautifulSoup(page.content, "lxml")

ns_inf2 = nissan_soup2.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
ns_info2 = list()

for i in ns_inf2:
    ns_info2.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-nissan/p3"
page = requests.get(URL)

nissan_soup3 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
ns_md3 = nissan_soup3.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
ns_modelos3 = list()

for i in ns_md3:
    ns_modelos3.append(i.text.strip())
    
# Scrapeamos el precio
ns_pr3 = nissan_soup3.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
ns_precios3 = list()

for p in ns_pr3:
    ns_precios3.append(p.text.strip())
    
# Scrapeamos la informacion
nissan_soup3 = BeautifulSoup(page.content, "lxml")

ns_inf3 = nissan_soup3.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
ns_info3 = list()

for i in ns_inf3:
    ns_info3.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-nissan/p4"
page = requests.get(URL)

nissan_soup4 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
ns_md4 = nissan_soup4.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
ns_modelos4 = list()

for i in ns_md4:
    ns_modelos4.append(i.text.strip())
    
# Scrapeamos el precio
ns_pr4 = nissan_soup4.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
ns_precios4 = list()

for p in ns_pr4:
    ns_precios4.append(p.text.strip())
    
# Scrapeamos la informacion
nissan_soup4 = BeautifulSoup(page.content, "lxml")

ns_inf4 = nissan_soup4.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
ns_info4 = list()

for i in ns_inf4:
    ns_info4.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-nissan/p5"
page = requests.get(URL)

nissan_soup5 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
ns_md5 = nissan_soup5.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
ns_modelos5 = list()

for i in ns_md5:
    ns_modelos5.append(i.text.strip())
    
# Scrapeamos el precio
ns_pr5 = nissan_soup5.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
ns_precios5 = list()

for p in ns_pr5:
    ns_precios5.append(p.text.strip())
    
# Scrapeamos la informacion
nissan_soup5 = BeautifulSoup(page.content, "lxml")

ns_inf5 = nissan_soup5.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
ns_info5 = list()

for i in ns_inf5:
    ns_info5.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-nissan/p6"
page = requests.get(URL)

nissan_soup6 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
ns_md6 = nissan_soup6.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
ns_modelos6 = list()

for i in ns_md6:
    ns_modelos6.append(i.text.strip())
    
# Scrapeamos el precio
ns_pr6 = nissan_soup6.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
ns_precios6 = list()

for p in ns_pr6:
    ns_precios6.append(p.text.strip())
    
# Scrapeamos la informacion
nissan_soup6 = BeautifulSoup(page.content, "lxml")

ns_inf6 = nissan_soup6.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
ns_info6 = list()

for i in ns_inf6:
    ns_info6.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-nissan/p7"
page = requests.get(URL)

nissan_soup7 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
ns_md7 = nissan_soup7.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
ns_modelos7 = list()

for i in ns_md7:
    ns_modelos7.append(i.text.strip())
    
# Scrapeamos el precio
ns_pr7 = nissan_soup7.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
ns_precios7 = list()

for p in ns_pr7:
    ns_precios7.append(p.text.strip())
    
# Scrapeamos la informacion
nissan_soup7 = BeautifulSoup(page.content, "lxml")

ns_inf7 = nissan_soup7.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
ns_info7 = list()

for i in ns_inf7:
    ns_info7.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-nissan/p8"
page = requests.get(URL)

nissan_soup8 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
ns_md8 = nissan_soup8.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
ns_modelos8 = list()

for i in ns_md8:
    ns_modelos8.append(i.text.strip())
    
# Scrapeamos el precio
ns_pr8 = nissan_soup8.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
ns_precios8 = list()

for p in ns_pr8:
    ns_precios8.append(p.text.strip())
    
# Scrapeamos la informacion
nissan_soup8 = BeautifulSoup(page.content, "lxml")

ns_inf8 = nissan_soup8.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
ns_info8 = list()

for i in ns_inf8:
    ns_info8.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://automexico.com/autos-nissan/p9"
page = requests.get(URL)

nissan_soup9 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
ns_md9 = nissan_soup9.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
ns_modelos9 = list()

for i in ns_md9:
    ns_modelos9.append(i.text.strip())
    
# Scrapeamos el precio
ns_pr9 = nissan_soup9.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
ns_precios9 = list()

for p in ns_pr9:
    ns_precios9.append(p.text.strip())
    
# Scrapeamos la informacion
nissan_soup9 = BeautifulSoup(page.content, "lxml")

ns_inf9 = nissan_soup9.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
ns_info9 = list()

for i in ns_inf9:
    ns_info9.append(i.text.strip())

# %%
#Hago la sopa
URL = "https://automexico.com/autos-nissan/p10"
page = requests.get(URL)

nissan_soup10 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
ns_md10 = nissan_soup10.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
ns_modelos10 = list()

for i in ns_md10:
    ns_modelos10.append(i.text.strip())
    
# Scrapeamos el precio
ns_pr10 = nissan_soup10.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
ns_precios10 = list()

for p in ns_pr10:
    ns_precios10.append(p.text.strip())
    
# Scrapeamos la informacion
nissan_soup10 = BeautifulSoup(page.content, "lxml")

ns_inf10 = nissan_soup10.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
ns_info10 = list()

for i in ns_inf10:
    ns_info10.append(i.text.strip())

# %%
#Hago la sopa
URL = "https://automexico.com/autos-nissan/p11"
page = requests.get(URL)

nissan_soup11 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
ns_md11 = nissan_soup11.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
ns_modelos11 = list()

for i in ns_md11:
    ns_modelos11.append(i.text.strip())
    
# Scrapeamos el precio
ns_pr11 = nissan_soup11.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
ns_precios11 = list()

for p in ns_pr11:
    ns_precios11.append(p.text.strip())
    
# Scrapeamos la informacion
nissan_soup11 = BeautifulSoup(page.content, "lxml")

ns_inf11 = nissan_soup11.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
ns_info11 = list()

for i in ns_inf11:
    ns_info11.append(i.text.strip())

# %%
#Hago la sopa
URL = "https://automexico.com/autos-nissan/p12"
page = requests.get(URL)

nissan_soup12 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos los nombres de los modelos
ns_md12 = nissan_soup12.find_all('h3', class_ = 'ellipsis_title ellipsis_title1 full-width-p pull-left')
ns_modelos12 = list()

for i in ns_md12:
    ns_modelos12.append(i.text.strip())
    
# Scrapeamos el precio
ns_pr12 = nissan_soup12.find_all('p', attrs={'class':'price fs-22 nunito-bold'})
ns_precios12 = list()

for p in ns_pr12:
    ns_precios12.append(p.text.strip())
    
# Scrapeamos la informacion
nissan_soup12 = BeautifulSoup(page.content, "lxml")

ns_inf12 = nissan_soup12.find_all('span', {'class' : 'a-car display-bl w-auto pd-right-15'})
ns_info12 = list()

for i in ns_inf12:
    ns_info12.append(i.text.strip())

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(ns_modelos1, ns_info1, ns_precios1))
list_tuples2= list(zip(ns_modelos2, ns_info2, ns_precios2))
list_tuples3= list(zip(ns_modelos3, ns_info3, ns_precios3))
list_tuples4= list(zip(ns_modelos4, ns_info4, ns_precios4))
list_tuples5= list(zip(ns_modelos5, ns_info5, ns_precios5))
list_tuples6= list(zip(ns_modelos6, ns_info6, ns_precios6))
list_tuples7= list(zip(ns_modelos7, ns_info7, ns_precios7))
list_tuples8= list(zip(ns_modelos8, ns_info8, ns_precios8))
list_tuples9= list(zip(ns_modelos9, ns_info9, ns_precios9))
list_tuples10= list(zip(ns_modelos10, ns_info10, ns_precios10))
list_tuples11= list(zip(ns_modelos11, ns_info11, ns_precios11))
list_tuples12= list(zip(ns_modelos12, ns_info12, ns_precios12))

# Agrego las tuplas y nombro las columnas
nissan_df1 = pd.DataFrame(list_tuples1, columns= ['Modelos', 'Información', 'Precio'])
nissan_df2 = pd.DataFrame(list_tuples2, columns= ['Modelos', 'Información', 'Precio'])
nissan_df3 = pd.DataFrame(list_tuples3, columns= ['Modelos', 'Información', 'Precio'])
nissan_df4 = pd.DataFrame(list_tuples4, columns= ['Modelos', 'Información', 'Precio'])
nissan_df5 = pd.DataFrame(list_tuples5, columns= ['Modelos', 'Información', 'Precio'])
nissan_df6 = pd.DataFrame(list_tuples6, columns= ['Modelos', 'Información', 'Precio'])
nissan_df7 = pd.DataFrame(list_tuples7, columns= ['Modelos', 'Información', 'Precio'])
nissan_df8 = pd.DataFrame(list_tuples8, columns= ['Modelos', 'Información', 'Precio'])
nissan_df9 = pd.DataFrame(list_tuples9, columns= ['Modelos', 'Información', 'Precio'])
nissan_df10 = pd.DataFrame(list_tuples10, columns= ['Modelos', 'Información', 'Precio'])
nissan_df11 = pd.DataFrame(list_tuples11, columns= ['Modelos', 'Información', 'Precio'])
nissan_df12 = pd.DataFrame(list_tuples12, columns= ['Modelos', 'Información', 'Precio'])

# Agrego los otros DataFrames 
nissan_df = nissan_df1.append([nissan_df2, nissan_df3, nissan_df4, nissan_df5, nissan_df6, nissan_df7, nissan_df8, nissan_df9, nissan_df10, nissan_df11, nissan_df12], ignore_index = True)

# %%
nissan_df.to_csv(r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Nissan_automexico Ventas.csv', index = False, header=True)

# %% [markdown]
# ## Mercadolibre.com.mx

# %% [markdown]
# ### Chevrolet

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/chevrolet/#applied_filter_id%3DBRAND%26applied_filter_name%3DMarca%26applied_filter_order%3D4%26applied_value_id%3D58955%26applied_value_name%3DChevrolet%26applied_value_order%3D9%26applied_value_results%3D6738%26is_custom%3Dfalse"
page = requests.get(URL)

chevrolet_soup1 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
gm_prc1 = chevrolet_soup1.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
gm_precio1 = list()

for i in gm_prc1:
    gm_precio1.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
gm_inf1 = chevrolet_soup1.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
gm_info1 = list()

for i in gm_inf1:
    gm_info1.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
gm_mdl1 = chevrolet_soup1.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
gm_modelo1 = list()

for i in gm_mdl1:
    gm_modelo1.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
chevrolet_soup1 = BeautifulSoup(page.content, "lxml")

gm_cd1 = chevrolet_soup1.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
gm_ciudad1 = list()

for i in gm_cd1:
    gm_ciudad1.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/chevrolet/_Desde_49_NoIndex_True"
page = requests.get(URL)

chevrolet_soup2 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
gm_prc2 = chevrolet_soup2.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
gm_precio2 = list()

for i in gm_prc2:
    gm_precio2.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
gm_inf2 = chevrolet_soup2.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
gm_info2 = list()

for i in gm_inf2:
    gm_info2.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
gm_mdl2 = chevrolet_soup2.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
gm_modelo2 = list()

for i in gm_mdl2:
    gm_modelo2.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
chevrolet_soup2 = BeautifulSoup(page.content, "lxml")

gm_cd2 = chevrolet_soup2.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
gm_ciudad2 = list()

for i in gm_cd2:
    gm_ciudad2.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/chevrolet/_Desde_97_NoIndex_True"
page = requests.get(URL)

chevrolet_soup3 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
gm_prc3 = chevrolet_soup3.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
gm_precio3 = list()

for i in gm_prc3:
    gm_precio3.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
gm_inf3 = chevrolet_soup3.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
gm_info3 = list()

for i in gm_inf3:
    gm_info3.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
gm_mdl3 = chevrolet_soup3.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
gm_modelo3 = list()

for i in gm_mdl3:
    gm_modelo3.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
chevrolet_soup3 = BeautifulSoup(page.content, "lxml")

gm_cd3 = chevrolet_soup3.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
gm_ciudad3 = list()

for i in gm_cd3:
    gm_ciudad3.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/chevrolet/_Desde_145_NoIndex_True"
page = requests.get(URL)

chevrolet_soup4 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
gm_prc4 = chevrolet_soup4.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
gm_precio4 = list()

for i in gm_prc4:
    gm_precio4.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
gm_inf4 = chevrolet_soup4.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
gm_info4 = list()

for i in gm_inf4:
    gm_info4.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
gm_mdl4 = chevrolet_soup4.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
gm_modelo4 = list()

for i in gm_mdl4:
    gm_modelo4.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
chevrolet_soup4 = BeautifulSoup(page.content, "lxml")

gm_cd4 = chevrolet_soup4.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
gm_ciudad4 = list()

for i in gm_cd4:
    gm_ciudad4.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/chevrolet/_Desde_193_NoIndex_True"
page = requests.get(URL)

chevrolet_soup5 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
gm_prc5 = chevrolet_soup5.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
gm_precio5 = list()

for i in gm_prc5:
    gm_precio5.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
gm_inf5 = chevrolet_soup5.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
gm_info5 = list()

for i in gm_inf5:
    gm_info5.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
gm_mdl5 = chevrolet_soup5.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
gm_modelo5 = list()

for i in gm_mdl5:
    gm_modelo5.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
chevrolet_soup5 = BeautifulSoup(page.content, "lxml")

gm_cd5 = chevrolet_soup5.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
gm_ciudad5 = list()

for i in gm_cd5:
    gm_ciudad5.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/chevrolet/_Desde_241_NoIndex_True"
page = requests.get(URL)

chevrolet_soup6 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
gm_prc6 = chevrolet_soup6.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
gm_precio6 = list()

for i in gm_prc6:
    gm_precio6.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
gm_inf6 = chevrolet_soup6.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
gm_info6 = list()

for i in gm_inf6:
    gm_info6.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
gm_mdl6 = chevrolet_soup6.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
gm_modelo6 = list()

for i in gm_mdl6:
    gm_modelo6.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
chevrolet_soup6 = BeautifulSoup(page.content, "lxml")

gm_cd6 = chevrolet_soup6.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
gm_ciudad6 = list()

for i in gm_cd6:
    gm_ciudad6.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/chevrolet/_Desde_289_NoIndex_True"
page = requests.get(URL)

chevrolet_soup7 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
gm_prc7 = chevrolet_soup7.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
gm_precio7 = list()

for i in gm_prc7:
    gm_precio7.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
gm_inf7 = chevrolet_soup7.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
gm_info7 = list()

for i in gm_inf7:
    gm_info7.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
gm_mdl7 = chevrolet_soup7.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
gm_modelo7 = list()

for i in gm_mdl7:
    gm_modelo7.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
chevrolet_soup7 = BeautifulSoup(page.content, "lxml")

gm_cd7 = chevrolet_soup7.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
gm_ciudad7 = list()

for i in gm_cd7:
    gm_ciudad7.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/chevrolet/_Desde_337_NoIndex_True"
page = requests.get(URL)

chevrolet_soup8 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
gm_prc8 = chevrolet_soup8.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
gm_precio8 = list()

for i in gm_prc8:
    gm_precio8.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
gm_inf8 = chevrolet_soup8.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
gm_info8 = list()

for i in gm_inf8:
    gm_info8.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
gm_mdl8 = chevrolet_soup8.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
gm_modelo8 = list()

for i in gm_mdl8:
    gm_modelo8.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
chevrolet_soup8 = BeautifulSoup(page.content, "lxml")

gm_cd8 = chevrolet_soup8.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
gm_ciudad8 = list()

for i in gm_cd8:
    gm_ciudad8.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/chevrolet/_Desde_385_NoIndex_True"
page = requests.get(URL)

chevrolet_soup9 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
gm_prc9 = chevrolet_soup9.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
gm_precio9 = list()

for i in gm_prc9:
    gm_precio9.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
gm_inf9 = chevrolet_soup9.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
gm_info9 = list()

for i in gm_inf9:
    gm_info9.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
gm_mdl9 = chevrolet_soup9.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
gm_modelo9 = list()

for i in gm_mdl9:
    gm_modelo9.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
chevrolet_soup9 = BeautifulSoup(page.content, "lxml")

gm_cd9 = chevrolet_soup9.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
gm_ciudad9 = list()

for i in gm_cd9:
    gm_ciudad9.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/chevrolet/_Desde_433_NoIndex_True"
page = requests.get(URL)

chevrolet_soup10 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
gm_prc10 = chevrolet_soup10.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
gm_precio10 = list()

for i in gm_prc10:
    gm_precio10.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
gm_inf10 = chevrolet_soup10.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
gm_info10 = list()

for i in gm_inf10:
    gm_info10.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
gm_mdl10 = chevrolet_soup10.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
gm_modelo10 = list()

for i in gm_mdl10:
    gm_modelo10.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
chevrolet_soup10 = BeautifulSoup(page.content, "lxml")

gm_cd10 = chevrolet_soup10.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
gm_ciudad10 = list()

for i in gm_cd10:
    gm_ciudad10.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/chevrolet/_Desde_481_NoIndex_True"
page = requests.get(URL)

chevrolet_soup11 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
gm_prc11 = chevrolet_soup11.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
gm_precio11 = list()

for i in gm_prc11:
    gm_precio11.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
gm_inf11 = chevrolet_soup11.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
gm_info11 = list()

for i in gm_inf11:
    gm_info11.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
gm_mdl11 = chevrolet_soup11.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
gm_modelo11 = list()

for i in gm_mdl11:
    gm_modelo11.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
chevrolet_soup11 = BeautifulSoup(page.content, "lxml")

gm_cd11 = chevrolet_soup11.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
gm_ciudad11 = list()

for i in gm_cd11:
    gm_ciudad11.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/chevrolet/_Desde_529_NoIndex_True"
page = requests.get(URL)

chevrolet_soup12 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
gm_prc12 = chevrolet_soup12.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
gm_precio12 = list()

for i in gm_prc12:
    gm_precio12.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
gm_inf12 = chevrolet_soup12.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
gm_info12 = list()

for i in gm_inf12:
    gm_info12.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
gm_mdl12 = chevrolet_soup12.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
gm_modelo12 = list()

for i in gm_mdl12:
    gm_modelo12.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
chevrolet_soup12 = BeautifulSoup(page.content, "lxml")

gm_cd12 = chevrolet_soup12.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
gm_ciudad12 = list()

for i in gm_cd12:
    gm_ciudad12.append(i.text.strip())

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(gm_precio1, gm_info1, gm_modelo1, gm_ciudad1))
list_tuples2= list(zip(gm_precio2, gm_info2, gm_modelo2, gm_ciudad2))
list_tuples3= list(zip(gm_precio3, gm_info3, gm_modelo3, gm_ciudad3))
list_tuples4= list(zip(gm_precio4, gm_info4, gm_modelo4, gm_ciudad4))
list_tuples5= list(zip(gm_precio5, gm_info5, gm_modelo5, gm_ciudad5))
list_tuples6= list(zip(gm_precio6, gm_info6, gm_modelo6, gm_ciudad6))
list_tuples7= list(zip(gm_precio7, gm_info7, gm_modelo7, gm_ciudad7))
list_tuples8= list(zip(gm_precio8, gm_info8, gm_modelo8, gm_ciudad8))
list_tuples9= list(zip(gm_precio9, gm_info9, gm_modelo9, gm_ciudad9))
list_tuples10= list(zip(gm_precio10, gm_info10, gm_modelo10, gm_ciudad10))
list_tuples11= list(zip(gm_precio11, gm_info11, gm_modelo11, gm_ciudad11))
list_tuples12= list(zip(gm_precio12, gm_info12, gm_modelo12, gm_ciudad12))


# Agrego las tuplas y nombro las columnas
chevrolet_df1 = pd.DataFrame(list_tuples1, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
chevrolet_df2 = pd.DataFrame(list_tuples2, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
chevrolet_df3 = pd.DataFrame(list_tuples3, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
chevrolet_df4 = pd.DataFrame(list_tuples4, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
chevrolet_df5 = pd.DataFrame(list_tuples5, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
chevrolet_df6 = pd.DataFrame(list_tuples6, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
chevrolet_df7 = pd.DataFrame(list_tuples7, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
chevrolet_df8 = pd.DataFrame(list_tuples8, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
chevrolet_df9 = pd.DataFrame(list_tuples9, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
chevrolet_df10 = pd.DataFrame(list_tuples10, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
chevrolet_df11 = pd.DataFrame(list_tuples11, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
chevrolet_df12 = pd.DataFrame(list_tuples12, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])

# Agrego los otros DataFrames 
chevrolet_df = chevrolet_df1.append([chevrolet_df2, chevrolet_df3, chevrolet_df4, chevrolet_df5, chevrolet_df6, chevrolet_df7, chevrolet_df8, chevrolet_df9, chevrolet_df10, chevrolet_df11, chevrolet_df12], ignore_index = True)

# %%
chevrolet_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Chevrolet_mercadolibre Ventas.csv', index = False, header=True)

# %% [markdown]
# ### Volkswagen

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/volkswagen/#applied_filter_id%3DBRAND%26applied_filter_name%3DMarca%26applied_filter_order%3D4%26applied_value_id%3D60249%26applied_value_name%3DVolkswagen%26applied_value_order%3D44%26applied_value_results%3D6318%26is_custom%3Dfalse"
page = requests.get(URL)

volkswagen_soup1 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
vk_prc1 = volkswagen_soup1.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
vk_precio1 = list()

for i in vk_prc1:
    vk_precio1.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
vk_inf1 = volkswagen_soup1.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
vk_info1 = list()

for i in vk_inf1:
    vk_info1.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
vk_mdl1 = volkswagen_soup1.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
vk_modelo1 = list()

for i in vk_mdl1:
    vk_modelo1.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
volkswagen_soup1 = BeautifulSoup(page.content, "lxml")

vk_cd1 = volkswagen_soup1.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
vk_ciudad1 = list()

for i in vk_cd1:
    vk_ciudad1.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/volkswagen/_Desde_49_NoIndex_True"
page = requests.get(URL)

volkswagen_soup2 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
vk_prc2 = volkswagen_soup2.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
vk_precio2 = list()

for i in vk_prc2:
    vk_precio2.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
vk_inf2 = volkswagen_soup2.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
vk_info2 = list()

for i in vk_inf2:
    vk_info2.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
vk_mdl2 = volkswagen_soup2.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
vk_modelo2 = list()

for i in vk_mdl2:
    vk_modelo2.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
volkswagen_soup2 = BeautifulSoup(page.content, "lxml")

vk_cd2 = volkswagen_soup2.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
vk_ciudad2 = list()

for i in vk_cd2:
    vk_ciudad2.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/volkswagen/_Desde_97_NoIndex_True"
page = requests.get(URL)

volkswagen_soup3 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
vk_prc3 = volkswagen_soup3.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
vk_precio3 = list()

for i in vk_prc3:
    vk_precio3.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
vk_inf3 = volkswagen_soup3.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
vk_info3 = list()

for i in vk_inf3:
    vk_info3.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
vk_mdl3 = volkswagen_soup3.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
vk_modelo3 = list()

for i in vk_mdl3:
    vk_modelo3.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
volkswagen_soup3 = BeautifulSoup(page.content, "lxml")

vk_cd3 = volkswagen_soup3.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
vk_ciudad3 = list()

for i in vk_cd3:
    vk_ciudad3.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/volkswagen/_Desde_145_NoIndex_True"
page = requests.get(URL)

volkswagen_soup4 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
vk_prc4 = volkswagen_soup4.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
vk_precio4 = list()

for i in vk_prc4:
    vk_precio4.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
vk_inf4 = volkswagen_soup4.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
vk_info4 = list()

for i in vk_inf4:
    vk_info4.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
vk_mdl4 = volkswagen_soup4.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
vk_modelo4 = list()

for i in vk_mdl4:
    vk_modelo4.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
volkswagen_soup4 = BeautifulSoup(page.content, "lxml")

vk_cd4 = volkswagen_soup4.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
vk_ciudad4 = list()

for i in vk_cd4:
    vk_ciudad4.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/volkswagen/_Desde_193_NoIndex_True"
page = requests.get(URL)

volkswagen_soup5 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
vk_prc5 = volkswagen_soup5.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
vk_precio5 = list()

for i in vk_prc5:
    vk_precio5.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
vk_inf5 = volkswagen_soup5.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
vk_info5 = list()

for i in vk_inf5:
    vk_info5.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
vk_mdl5 = volkswagen_soup5.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
vk_modelo5 = list()

for i in vk_mdl5:
    vk_modelo5.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
volkswagen_soup5 = BeautifulSoup(page.content, "lxml")

vk_cd5 = volkswagen_soup5.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
vk_ciudad5 = list()

for i in vk_cd5:
    vk_ciudad5.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/volkswagen/_Desde_241_NoIndex_True"
page = requests.get(URL)

volkswagen_soup6 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
vk_prc6 = volkswagen_soup6.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
vk_precio6 = list()

for i in vk_prc6:
    vk_precio6.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
vk_inf6 = volkswagen_soup6.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
vk_info6 = list()

for i in vk_inf6:
    vk_info6.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
vk_mdl6 = volkswagen_soup6.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
vk_modelo6 = list()

for i in vk_mdl6:
    vk_modelo6.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
volkswagen_soup6 = BeautifulSoup(page.content, "lxml")

vk_cd6 = volkswagen_soup6.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
vk_ciudad6 = list()

for i in vk_cd6:
    vk_ciudad6.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/volkswagen/_Desde_289_NoIndex_True"
page = requests.get(URL)

volkswagen_soup7 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
vk_prc7 = volkswagen_soup7.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
vk_precio7 = list()

for i in vk_prc7:
    vk_precio7.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
vk_inf7 = volkswagen_soup7.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
vk_info7 = list()

for i in vk_inf7:
    vk_info7.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
vk_mdl7 = volkswagen_soup7.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
vk_modelo7 = list()

for i in vk_mdl7:
    vk_modelo7.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
volkswagen_soup7 = BeautifulSoup(page.content, "lxml")

vk_cd7 = volkswagen_soup7.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
vk_ciudad7 = list()

for i in vk_cd7:
    vk_ciudad7.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/volkswagen/_Desde_337_NoIndex_True"
page = requests.get(URL)

volkswagen_soup8 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
vk_prc8 = volkswagen_soup8.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
vk_precio8 = list()

for i in vk_prc8:
    vk_precio8.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
vk_inf8 = volkswagen_soup8.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
vk_info8 = list()

for i in vk_inf8:
    vk_info8.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
vk_mdl8 = volkswagen_soup8.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
vk_modelo8 = list()

for i in vk_mdl8:
    vk_modelo8.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
volkswagen_soup8 = BeautifulSoup(page.content, "lxml")

vk_cd8 = volkswagen_soup8.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
vk_ciudad8 = list()

for i in vk_cd8:
    vk_ciudad8.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/volkswagen/_Desde_385_NoIndex_True"
page = requests.get(URL)

volkswagen_soup9 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
vk_prc9 = volkswagen_soup9.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
vk_precio9 = list()

for i in vk_prc9:
    vk_precio9.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
vk_inf9 = volkswagen_soup9.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
vk_info9 = list()

for i in vk_inf9:
    vk_info9.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
vk_mdl9 = volkswagen_soup9.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
vk_modelo9 = list()

for i in vk_mdl9:
    vk_modelo9.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
volkswagen_soup9 = BeautifulSoup(page.content, "lxml")

vk_cd9 = volkswagen_soup9.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
vk_ciudad9 = list()

for i in vk_cd9:
    vk_ciudad9.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/volkswagen/_Desde_433_NoIndex_True"
page = requests.get(URL)

volkswagen_soup10 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
vk_prc10 = volkswagen_soup10.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
vk_precio10 = list()

for i in vk_prc10:
    vk_precio10.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
vk_inf10 = volkswagen_soup10.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
vk_info10 = list()

for i in vk_inf10:
    vk_info10.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
vk_mdl10 = volkswagen_soup10.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
vk_modelo10 = list()

for i in vk_mdl10:
    vk_modelo10.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
volkswagen_soup10 = BeautifulSoup(page.content, "lxml")

vk_cd10 = volkswagen_soup10.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
vk_ciudad10 = list()

for i in vk_cd10:
    vk_ciudad10.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/volkswagen/_Desde_481_NoIndex_True"
page = requests.get(URL)

volkswagen_soup11 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
vk_prc11 = volkswagen_soup11.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
vk_precio11 = list()

for i in vk_prc11:
    vk_precio11.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
vk_inf11 = volkswagen_soup11.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
vk_info11 = list()

for i in vk_inf11:
    vk_info11.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
vk_mdl11 = volkswagen_soup11.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
vk_modelo11 = list()

for i in vk_mdl11:
    vk_modelo11.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
volkswagen_soup11 = BeautifulSoup(page.content, "lxml")

vk_cd11 = volkswagen_soup11.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
vk_ciudad11 = list()

for i in vk_cd11:
    vk_ciudad11.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/volkswagen/_Desde_529_NoIndex_True"
page = requests.get(URL)

volkswagen_soup12 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
vk_prc12 = volkswagen_soup12.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
vk_precio12 = list()

for i in vk_prc12:
    vk_precio12.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
vk_inf12 = volkswagen_soup12.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
vk_info12 = list()

for i in vk_inf12:
    vk_info12.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
vk_mdl12 = volkswagen_soup12.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
vk_modelo12 = list()

for i in vk_mdl12:
    vk_modelo12.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
volkswagen_soup12 = BeautifulSoup(page.content, "lxml")

vk_cd12 = volkswagen_soup12.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
vk_ciudad12 = list()

for i in vk_cd12:
    vk_ciudad12.append(i.text.strip())

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(vk_precio1, vk_info1, vk_modelo1, vk_ciudad1))
list_tuples2= list(zip(vk_precio2, vk_info2, vk_modelo2, vk_ciudad2))
list_tuples3= list(zip(vk_precio3, vk_info3, vk_modelo3, vk_ciudad3))
list_tuples4= list(zip(vk_precio4, vk_info4, vk_modelo4, vk_ciudad4))
list_tuples5= list(zip(vk_precio5, vk_info5, vk_modelo5, vk_ciudad5))
list_tuples6= list(zip(vk_precio6, vk_info6, vk_modelo6, vk_ciudad6))
list_tuples7= list(zip(vk_precio7, vk_info7, vk_modelo7, vk_ciudad7))
list_tuples8= list(zip(vk_precio8, vk_info8, vk_modelo8, vk_ciudad8))
list_tuples9= list(zip(vk_precio9, vk_info9, vk_modelo9, vk_ciudad9))
list_tuples10= list(zip(vk_precio10, vk_info10, vk_modelo10, vk_ciudad10))
list_tuples11= list(zip(vk_precio11, vk_info11, vk_modelo11, vk_ciudad11))
list_tuples12= list(zip(vk_precio12, vk_info12, vk_modelo12, vk_ciudad12))


# Agrego las tuplas y nombro las columnas
volkswagen_df1 = pd.DataFrame(list_tuples1, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
volkswagen_df2 = pd.DataFrame(list_tuples2, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
volkswagen_df3 = pd.DataFrame(list_tuples3, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
volkswagen_df4 = pd.DataFrame(list_tuples4, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
volkswagen_df5 = pd.DataFrame(list_tuples5, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
volkswagen_df6 = pd.DataFrame(list_tuples6, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
volkswagen_df7 = pd.DataFrame(list_tuples7, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
volkswagen_df8 = pd.DataFrame(list_tuples8, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
volkswagen_df9 = pd.DataFrame(list_tuples9, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
volkswagen_df10 = pd.DataFrame(list_tuples10, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
volkswagen_df11 = pd.DataFrame(list_tuples11, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
volkswagen_df12 = pd.DataFrame(list_tuples12, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])

# Agrego los otros DataFrames 
volkswagen_df = volkswagen_df1.append([volkswagen_df2, volkswagen_df3, volkswagen_df4, volkswagen_df5, volkswagen_df6, volkswagen_df7, volkswagen_df8, volkswagen_df9, volkswagen_df10, volkswagen_df11, volkswagen_df12], ignore_index = True)

# %%
volkswagen_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Volkswagen_mercadolibre Ventas.csv', index = False, header=True)

# %% [markdown]
# ### Nissan

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/nissan/#applied_filter_id%3DBRAND%26applied_filter_name%3DMarca%26applied_filter_order%3D4%26applied_value_id%3D60505%26applied_value_name%3DNissan%26applied_value_order%3D31%26applied_value_results%3D5820%26is_custom%3Dfalse"
page = requests.get(URL)

nissan_soup1 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
ns_prc1 = nissan_soup1.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
ns_precio1 = list()

for i in ns_prc1:
    ns_precio1.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
ns_inf1 = nissan_soup1.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
ns_info1 = list()

for i in ns_inf1:
    ns_info1.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
ns_mdl1 = nissan_soup1.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
ns_modelo1 = list()

for i in ns_mdl1:
    ns_modelo1.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
nissan_soup1 = BeautifulSoup(page.content, "lxml")

ns_cd1 = nissan_soup1.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
ns_ciudad1 = list()

for i in ns_cd1:
    ns_ciudad1.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/nissan/_Desde_49_NoIndex_True"
page = requests.get(URL)

nissan_soup2 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
ns_prc2 = nissan_soup2.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
ns_precio2 = list()

for i in ns_prc2:
    ns_precio2.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
ns_inf2 = nissan_soup2.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
ns_info2 = list()

for i in ns_inf2:
    ns_info2.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
ns_mdl2 = nissan_soup2.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
ns_modelo2 = list()

for i in ns_mdl2:
    ns_modelo2.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
nissan_soup2 = BeautifulSoup(page.content, "lxml")

ns_cd2 = nissan_soup2.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
ns_ciudad2 = list()

for i in ns_cd2:
    ns_ciudad2.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/nissan/_Desde_97_NoIndex_True"
page = requests.get(URL)

nissan_soup3 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
ns_prc3 = nissan_soup3.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
ns_precio3 = list()

for i in ns_prc3:
    ns_precio3.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
ns_inf3 = nissan_soup3.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
ns_info3 = list()

for i in ns_inf3:
    ns_info3.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
ns_mdl3 = nissan_soup3.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
ns_modelo3 = list()

for i in ns_mdl3:
    ns_modelo3.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
nissan_soup3 = BeautifulSoup(page.content, "lxml")

ns_cd3 = nissan_soup3.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
ns_ciudad3 = list()

for i in ns_cd3:
    ns_ciudad3.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/nissan/_Desde_145_NoIndex_True"
page = requests.get(URL)

nissan_soup4 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
ns_prc4 = nissan_soup4.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
ns_precio4 = list()

for i in ns_prc4:
    ns_precio4.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
ns_inf4 = nissan_soup4.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
ns_info4 = list()

for i in ns_inf4:
    ns_info4.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
ns_mdl4 = nissan_soup4.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
ns_modelo4 = list()

for i in ns_mdl4:
    ns_modelo4.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
nissan_soup4 = BeautifulSoup(page.content, "lxml")

ns_cd4 = nissan_soup4.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
ns_ciudad4 = list()

for i in ns_cd4:
    ns_ciudad4.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/nissan/_Desde_193_NoIndex_True"
page = requests.get(URL)

nissan_soup5 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
ns_prc5 = nissan_soup5.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
ns_precio5 = list()

for i in ns_prc5:
    ns_precio5.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
ns_inf5 = nissan_soup5.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
ns_info5 = list()

for i in ns_inf5:
    ns_info5.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
ns_mdl5 = nissan_soup5.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
ns_modelo5 = list()

for i in ns_mdl5:
    ns_modelo5.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
nissan_soup5 = BeautifulSoup(page.content, "lxml")

ns_cd5 = nissan_soup5.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
ns_ciudad5 = list()

for i in ns_cd5:
    ns_ciudad5.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/nissan/_Desde_241_NoIndex_True"
page = requests.get(URL)

nissan_soup6 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
ns_prc6 = nissan_soup6.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
ns_precio6 = list()

for i in ns_prc6:
    ns_precio6.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
ns_inf6 = nissan_soup6.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
ns_info6 = list()

for i in ns_inf6:
    ns_info6.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
ns_mdl6 = nissan_soup6.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
ns_modelo6 = list()

for i in ns_mdl6:
    ns_modelo6.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
nissan_soup6 = BeautifulSoup(page.content, "lxml")

ns_cd6 = nissan_soup6.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
ns_ciudad6 = list()

for i in ns_cd6:
    ns_ciudad6.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/nissan/_Desde_289_NoIndex_True"
page = requests.get(URL)

nissan_soup7 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
ns_prc7 = nissan_soup7.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
ns_precio7 = list()

for i in ns_prc7:
    ns_precio7.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
ns_inf7 = nissan_soup7.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
ns_info7 = list()

for i in ns_inf7:
    ns_info7.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
ns_mdl7 = nissan_soup7.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
ns_modelo7 = list()

for i in ns_mdl7:
    ns_modelo7.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
nissan_soup7 = BeautifulSoup(page.content, "lxml")

ns_cd7 = nissan_soup7.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
ns_ciudad7 = list()

for i in ns_cd7:
    ns_ciudad7.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/nissan/_Desde_337_NoIndex_True"
page = requests.get(URL)

nissan_soup8 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
ns_prc8 = nissan_soup8.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
ns_precio8 = list()

for i in ns_prc8:
    ns_precio8.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
ns_inf8 = nissan_soup8.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
ns_info8 = list()

for i in ns_inf8:
    ns_info8.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
ns_mdl8 = nissan_soup8.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
ns_modelo8 = list()

for i in ns_mdl8:
    ns_modelo8.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
nissan_soup8 = BeautifulSoup(page.content, "lxml")

ns_cd8 = nissan_soup8.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
ns_ciudad8 = list()

for i in ns_cd8:
    ns_ciudad8.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/nissan/_Desde_385_NoIndex_True"
page = requests.get(URL)

nissan_soup9 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
ns_prc9 = nissan_soup9.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
ns_precio9 = list()

for i in ns_prc9:
    ns_precio9.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
ns_inf9 = nissan_soup9.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
ns_info9 = list()

for i in ns_inf9:
    ns_info9.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
ns_mdl9 = nissan_soup9.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
ns_modelo9 = list()

for i in ns_mdl9:
    ns_modelo9.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
nissan_soup9 = BeautifulSoup(page.content, "lxml")

ns_cd9 = nissan_soup9.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
ns_ciudad9 = list()

for i in ns_cd9:
    ns_ciudad9.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/nissan/_Desde_433_NoIndex_True"
page = requests.get(URL)

nissan_soup10 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
ns_prc10 = nissan_soup10.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
ns_precio10 = list()

for i in ns_prc10:
    ns_precio10.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
ns_inf10 = nissan_soup10.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
ns_info10 = list()

for i in ns_inf10:
    ns_info10.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
ns_mdl10 = nissan_soup10.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
ns_modelo10 = list()

for i in ns_mdl10:
    ns_modelo10.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
nissan_soup10 = BeautifulSoup(page.content, "lxml")

ns_cd10 = nissan_soup10.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
ns_ciudad10 = list()

for i in ns_cd10:
    ns_ciudad10.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/nissan/_Desde_481_NoIndex_True"
page = requests.get(URL)

nissan_soup11 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
ns_prc11 = nissan_soup11.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
ns_precio11 = list()

for i in ns_prc11:
    ns_precio11.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
ns_inf11 = nissan_soup11.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
ns_info11 = list()

for i in ns_inf11:
    ns_info11.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
ns_mdl11 = nissan_soup11.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
ns_modelo11 = list()

for i in ns_mdl11:
    ns_modelo11.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
nissan_soup11 = BeautifulSoup(page.content, "lxml")

ns_cd11 = nissan_soup11.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
ns_ciudad11 = list()

for i in ns_cd11:
    ns_ciudad11.append(i.text.strip())

# %%
# Hago la sopa
URL = "https://autos.mercadolibre.com.mx/nissan/_Desde_529_NoIndex_True"
page = requests.get(URL)

nissan_soup12 = BeautifulSoup(page.content, "html.parser")

# Scrapeamos la información de precio
ns_prc12 = nissan_soup12.find_all('div', class_ = 'ui-search-price ui-search-price--size-medium')
ns_precio12 = list()

for i in ns_prc12:
    ns_precio12.append(i.text.strip())

    
# Scrapeamos la información de año de modelo y KM
ns_inf12 = nissan_soup12.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--attributes')
ns_info12 = list()

for i in ns_inf12:
    ns_info12.append(i.text.strip())
    
    
# Scrapeamos el nombre del modelo
ns_mdl12 = nissan_soup12.find_all('div', class_ = 'ui-search-item__group ui-search-item__group--title')
ns_modelo12 = list()

for i in ns_mdl12:
    ns_modelo12.append(i.text.strip())
    
    
# Scrapeamos la informacion del punto de venta
nissan_soup12 = BeautifulSoup(page.content, "lxml")

ns_cd12 = nissan_soup12.find_all('span', {'class' : 'ui-search-item__group__element ui-search-item__location'})
ns_ciudad12 = list()

for i in ns_cd12:
    ns_ciudad12.append(i.text.strip())

# %%
# Creo las tuplas usando las listas con la información scrapeada
list_tuples1= list(zip(ns_precio1, ns_info1, ns_modelo1, ns_ciudad1))
list_tuples2= list(zip(ns_precio2, ns_info2, ns_modelo2, ns_ciudad2))
list_tuples3= list(zip(ns_precio3, ns_info3, ns_modelo3, ns_ciudad3))
list_tuples4= list(zip(ns_precio4, ns_info4, ns_modelo4, ns_ciudad4))
list_tuples5= list(zip(ns_precio5, ns_info5, ns_modelo5, ns_ciudad5))
list_tuples6= list(zip(ns_precio6, ns_info6, ns_modelo6, ns_ciudad6))
list_tuples7= list(zip(ns_precio7, ns_info7, ns_modelo7, ns_ciudad7))
list_tuples8= list(zip(ns_precio8, ns_info8, ns_modelo8, ns_ciudad8))
list_tuples9= list(zip(ns_precio9, ns_info9, ns_modelo9, ns_ciudad9))
list_tuples10= list(zip(ns_precio10, ns_info10, ns_modelo10, ns_ciudad10))
list_tuples11= list(zip(ns_precio11, ns_info11, ns_modelo11, ns_ciudad11))
list_tuples12= list(zip(ns_precio12, ns_info12, ns_modelo12, ns_ciudad12))


# Agrego las tuplas y nombro las columnas
nissan_df1 = pd.DataFrame(list_tuples1, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
nissan_df2 = pd.DataFrame(list_tuples2, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
nissan_df3 = pd.DataFrame(list_tuples3, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
nissan_df4 = pd.DataFrame(list_tuples4, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
nissan_df5 = pd.DataFrame(list_tuples5, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
nissan_df6 = pd.DataFrame(list_tuples6, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
nissan_df7 = pd.DataFrame(list_tuples7, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
nissan_df8 = pd.DataFrame(list_tuples8, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
nissan_df9 = pd.DataFrame(list_tuples9, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
nissan_df10 = pd.DataFrame(list_tuples10, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
nissan_df11 = pd.DataFrame(list_tuples11, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])
nissan_df12 = pd.DataFrame(list_tuples12, columns= ['Precio', 'Información', 'Modelo', 'Punto de Venta'])

# Agrego los otros DataFrames 
nissan_df = nissan_df1.append([nissan_df2, nissan_df3, nissan_df4, nissan_df5, nissan_df6, nissan_df7, nissan_df8, nissan_df9, nissan_df10, nissan_df11, nissan_df12], ignore_index = True)

# %%
nissan_df.to_csv (r'C:\Users\marti\OneDrive\Documents\Anahuac Masters Program\Proyeccto de Ingenieria\DataFrame\Nissan_mercadolibre Ventas.csv', index = False, header=True)
